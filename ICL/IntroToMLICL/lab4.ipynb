# %% [markdown]
# # Lab 4: Simple Linear Regression

# %% [markdown]
# ## Version history
#
# | Date | Author | Description |
# |:----:|:------:|:------------|
# 2021-02-03 | Josiah Wang | First version |
# 2021-11-13 | Josiah Wang | Optimisation with derivatives: $x$ should be $x^{(i)}$ |
# 2022-11-02 | Josiah Wang | Updated to `ax = fig.add_subplot(projection='3d')`. The original `fig.gca(projection='3d')` is deprecated.

# %% [markdown]
# ## Introduction
#
# The aim of this lab exercise is for you to gain some experience implementing and training a simple linear regression model from scratch. This will help you improve your understanding of linear regression and machine learning optimisation.
#
# By the end of this lab exercise, you will have
# - implemented a simple linear regression model
# - defined and implemented a loss function
# - optimised the parameters of your model using gradient descent
#
# There will be a bit less coding required on your side in this exercise compared to previous exercises. The aim is for you to try to really understand linear regression at implementation level to complement the lectures, which will help you in future weeks as you move on to Neural Networks in your coursework assignments.

# %% [markdown]
# ## Simple Linear Regression
#
# In this tutorial, we will focus on the **regression task**. For simplicity, we will implement a *simple linear regression* model with one input variable and one output variable. More specifically, our task is to predict the value of $y$ given the input $x$.
#
# Let us develop our simple linear regressor with a simple toy example to make sure that our model works correctly. You can later apply it to a bigger dataset if desired.

# %%
import numpy as np
import matplotlib.pyplot as plt

# toy dataset
x_train = np.array([1.0, 1.2, 2.0, 3.5, 4.0, 5.0])
y_train = np.array([3.1, 3.5, 5.0, 7.9, 9.1, 10.9])
x_test = np.array([2.5, 3.0, 4.5])
y_test = np.array([6.0, 7.0, 10.1])

# plot toy data
plt.scatter(x_train, y_train, c="blue")
plt.scatter(x_test, y_test, c="red")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ### Model
#
# As you should be able to see from the plot, the toy dataset can almost be perfectly modelled with a straight line. The model should also be able to pretty accurately predict the value of $y$ of the test set.
#
# Assuming you still remember your high school Maths, a straight line is represented as $y = wx + b$, where $w$ is the slope and $b$ the intercept/bias. Our objective is to find the line that best fits our training data. More specifically, we want our regressor to automatically learn the parameters $w$ and $b$ such that we can accurately predict the real-valued label ${\hat y}$ given an example $x$. The objective is to get ${\hat y}$ to be as close as possible to the values of $y$ of the training data (and presumably the true $y$).
#
# Let us now build our simple linear regression model. Complete the `forward()` method of the `SimpleLinearRegression` class below to return the value of the output $y$ given an input `x` and the current weight `w` and bias `b` of the model.

# %%
from numpy.random import default_rng

class SimpleLinearRegression:
    def __init__(self, random_generator=default_rng()):
        # initialise the slope with a random value drawn from a standard normal
        # distribution (mean=0, stddev=1)
        self.w = random_generator.standard_normal()

        # initialise bias to 0
        self.b = 0

    def forward(self, x):
        """ Perform forward pass given an input x

        Args:
            x (float): input instance

        Returns:
            float: the output of the model given the current weights
        """

        # TODO: Complete this
        return self.w * x + self.b

    def loss(self, x, y):
        """ Placeholder for later"""
        pass

    def gradient(self, x, y):
        """ Placeholder for later"""
        pass


## Quick test: This should return 8
model = SimpleLinearRegression()
model.w = 3
model.b = 2
x = 2
y_hat = model.forward(x)
print(y_hat) # should print 8
# Out:
# 8

# %% [markdown]
# ### Loss function
#
# From the plot and the numbers, you may have manually worked out that the 'best' line would be $\hat{y} \approx 2x+1$, that is, the optimal parameter values are $w \approx 2$ and $b \approx 1$.
#
# What constitutes the 'best' line? We will first have to define what 'best' actually means. Intuitively, the 'best' line would be the one that goes through all training points as closely as possible.
#
# To enable our model to automatically learn what the parameter values of the 'best' line are from training examples, we will have to formally define that we mean by 'best'. We define this via a *loss function* (or cost function). For this tutorial, we will use the loss function as in the lectures - the **sum of squared differences** between the predicted label vs. the ground truth label across the training instances.
#
# $$L = \frac{1}{2} \sum_{i=1}^{N} \left(\hat{y}^{(i)} - y^{(i)}\right)^2 = \frac{1}{2} \sum_{i=1}^{N} \left(wx^{(i)} + b - y^{(i)}\right)^2$$
#
# Our objective is to select the parameters $\theta = \{ w, b \}$ that **minimise** the loss (or error).
#
# $$\theta = argmin_{\theta} \, L$$
#
# To make things easy, let us implement the loss function for a **single** instance $x$:
#
# $$L^{(i)} = \left(\hat{y}^{(i)} - y^{(i)}\right)^2$$
#
# Complete the `loss()` method of `SimpleLinearRegression` below to return the individual loss for an instance `x`.

# %%
# Loss method for SimpleLinearRegression
def loss(self, x, y):
    """ Compute the loss for an input x

    Args:
        x (float): input instance
        y (float): ground truth output

    Returns:
        float: the model loss for an instance x
    """

    # TODO: Complete this

    return (self.forward(x) - y) ** 2


# A quick hack to bind this function as the SimpleLinearRegression.loss() method
SimpleLinearRegression.loss = loss


## Quick test: This should return 0.25
model = SimpleLinearRegression()
model.w = 3
model.b = 2
x = 2.0
y = 8.5
test_loss = model.loss(x, y)
print(test_loss) # should print 0.25
# Out:
# 0.25

# %% [markdown]
# ### Optimisation by brute force search
#
# Now, how do we get the model to automatically figure out the optimal parameters from training data? Remember that the optimal parameter values are the ones that minimise the loss function. A naive approach would be to compute the loss for different combinations of $w$ and $b$ and selecting the combination that results in the smallest loss.
#
# The code below will search for $w$ between $0$ and $4$, and for $b$ between $0$ and $2$ to find the best combination of $w$ and $b$. Examine the code, and try to understand what it is doing, then run the code.

# %%
model = SimpleLinearRegression()

# to store all losses for later use
losses = []

# the parameters to search
weights = np.arange(0, 4.1, 0.2)
biases = np.arange(0, 2.1, 0.2)

# for storing the loss in a matrix for visualisation later
loss_matrix = np.zeros((len(weights), len(biases)))

# compute loss for each (w,b) combination
for i, w in enumerate(weights):
    for j, b in enumerate(biases):
        print(f"(w={w:.1f}, b={b:.1f})")

        # setup weights of model
        model.w = w
        model.b = b

        sum_loss = 0
        # for each example
        for (x, y) in zip(x_train, y_train):
            # compute the loss for this example
            single_loss = model.loss(x, y)

            # and add it to the sum
            sum_loss += single_loss

            # print out the values just to make sure everything is working correctly
            y_hat = model.forward(x)
            print(f"    x: {x}, y: {y}, y_hat: {y_hat:.1f}, loss: {single_loss:.2f}")

        # print out the sum of individual losses
        # I multiplied by 0.5 to be consistent with the equation earlier,
        # but this is not necessary in practice as this is a constant
        print(f"    Loss = {(0.5 * sum_loss):.4f}\n")

        # store the losses and the corresponding (w,b) for later use
        losses.append((0.5*sum_loss, w, b))

        # store the losses in a matrix form for visualisation later
        loss_matrix[i,j] = 0.5 * sum_loss

# find combination with minimum loss
(min_loss, best_w, best_b) = min(losses, key=lambda x:x[0])
print("BEST:")
print(f"w={best_w}, b={best_b}, loss={min_loss:.4f}")
# Out:
# (w=0.0, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 0.0, loss: 9.61
#     x: 1.2, y: 3.5, y_hat: 0.0, loss: 12.25
#     x: 2.0, y: 5.0, y_hat: 0.0, loss: 25.00
#     x: 3.5, y: 7.9, y_hat: 0.0, loss: 62.41
#     x: 4.0, y: 9.1, y_hat: 0.0, loss: 82.81
#     x: 5.0, y: 10.9, y_hat: 0.0, loss: 118.81
#     Loss = 155.4450
#
# (w=0.0, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 0.2, loss: 8.41
#     x: 1.2, y: 3.5, y_hat: 0.2, loss: 10.89
#     x: 2.0, y: 5.0, y_hat: 0.2, loss: 23.04
#     x: 3.5, y: 7.9, y_hat: 0.2, loss: 59.29
#     x: 4.0, y: 9.1, y_hat: 0.2, loss: 79.21
#     x: 5.0, y: 10.9, y_hat: 0.2, loss: 114.49
#     Loss = 147.6650
#
# (w=0.0, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 0.4, loss: 7.29
#     x: 1.2, y: 3.5, y_hat: 0.4, loss: 9.61
#     x: 2.0, y: 5.0, y_hat: 0.4, loss: 21.16
#     x: 3.5, y: 7.9, y_hat: 0.4, loss: 56.25
#     x: 4.0, y: 9.1, y_hat: 0.4, loss: 75.69
#     x: 5.0, y: 10.9, y_hat: 0.4, loss: 110.25
#     Loss = 140.1250
#
# (w=0.0, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 0.6, loss: 6.25
#     x: 1.2, y: 3.5, y_hat: 0.6, loss: 8.41
#     x: 2.0, y: 5.0, y_hat: 0.6, loss: 19.36
#     x: 3.5, y: 7.9, y_hat: 0.6, loss: 53.29
#     x: 4.0, y: 9.1, y_hat: 0.6, loss: 72.25
#     x: 5.0, y: 10.9, y_hat: 0.6, loss: 106.09
#     Loss = 132.8250
#
# (w=0.0, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 0.8, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 0.8, loss: 7.29
#     x: 2.0, y: 5.0, y_hat: 0.8, loss: 17.64
#     x: 3.5, y: 7.9, y_hat: 0.8, loss: 50.41
#     x: 4.0, y: 9.1, y_hat: 0.8, loss: 68.89
#     x: 5.0, y: 10.9, y_hat: 0.8, loss: 102.01
#     Loss = 125.7650
#
# (w=0.0, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 1.0, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 1.0, loss: 6.25
#     x: 2.0, y: 5.0, y_hat: 1.0, loss: 16.00
#     x: 3.5, y: 7.9, y_hat: 1.0, loss: 47.61
#     x: 4.0, y: 9.1, y_hat: 1.0, loss: 65.61
#     x: 5.0, y: 10.9, y_hat: 1.0, loss: 98.01
#     Loss = 118.9450
#
# (w=0.0, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 1.2, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 1.2, loss: 5.29
#     x: 2.0, y: 5.0, y_hat: 1.2, loss: 14.44
#     x: 3.5, y: 7.9, y_hat: 1.2, loss: 44.89
#     x: 4.0, y: 9.1, y_hat: 1.2, loss: 62.41
#     x: 5.0, y: 10.9, y_hat: 1.2, loss: 94.09
#     Loss = 112.3650
#
# (w=0.0, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 1.4, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 1.4, loss: 4.41
#     x: 2.0, y: 5.0, y_hat: 1.4, loss: 12.96
#     x: 3.5, y: 7.9, y_hat: 1.4, loss: 42.25
#     x: 4.0, y: 9.1, y_hat: 1.4, loss: 59.29
#     x: 5.0, y: 10.9, y_hat: 1.4, loss: 90.25
#     Loss = 106.0250
#
# (w=0.0, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.6, loss: 3.61
#     x: 2.0, y: 5.0, y_hat: 1.6, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 1.6, loss: 39.69
#     x: 4.0, y: 9.1, y_hat: 1.6, loss: 56.25
#     x: 5.0, y: 10.9, y_hat: 1.6, loss: 86.49
#     Loss = 99.9250
#
# (w=0.0, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 1.8, loss: 2.89
#     x: 2.0, y: 5.0, y_hat: 1.8, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 1.8, loss: 37.21
#     x: 4.0, y: 9.1, y_hat: 1.8, loss: 53.29
#     x: 5.0, y: 10.9, y_hat: 1.8, loss: 82.81
#     Loss = 94.0650
#
# (w=0.0, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.0, loss: 2.25
#     x: 2.0, y: 5.0, y_hat: 2.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 2.0, loss: 34.81
#     x: 4.0, y: 9.1, y_hat: 2.0, loss: 50.41
#     x: 5.0, y: 10.9, y_hat: 2.0, loss: 79.21
#     Loss = 88.4450
#
# (w=0.2, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 0.2, loss: 8.41
#     x: 1.2, y: 3.5, y_hat: 0.2, loss: 10.63
#     x: 2.0, y: 5.0, y_hat: 0.4, loss: 21.16
#     x: 3.5, y: 7.9, y_hat: 0.7, loss: 51.84
#     x: 4.0, y: 9.1, y_hat: 0.8, loss: 68.89
#     x: 5.0, y: 10.9, y_hat: 1.0, loss: 98.01
#     Loss = 129.4688
#
# (w=0.2, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 0.4, loss: 7.29
#     x: 1.2, y: 3.5, y_hat: 0.4, loss: 9.36
#     x: 2.0, y: 5.0, y_hat: 0.6, loss: 19.36
#     x: 3.5, y: 7.9, y_hat: 0.9, loss: 49.00
#     x: 4.0, y: 9.1, y_hat: 1.0, loss: 65.61
#     x: 5.0, y: 10.9, y_hat: 1.2, loss: 94.09
#     Loss = 122.3568
#
# (w=0.2, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 0.6, loss: 6.25
#     x: 1.2, y: 3.5, y_hat: 0.6, loss: 8.18
#     x: 2.0, y: 5.0, y_hat: 0.8, loss: 17.64
#     x: 3.5, y: 7.9, y_hat: 1.1, loss: 46.24
#     x: 4.0, y: 9.1, y_hat: 1.2, loss: 62.41
#     x: 5.0, y: 10.9, y_hat: 1.4, loss: 90.25
#     Loss = 115.4848
#
# (w=0.2, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 0.8, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 0.8, loss: 7.08
#     x: 2.0, y: 5.0, y_hat: 1.0, loss: 16.00
#     x: 3.5, y: 7.9, y_hat: 1.3, loss: 43.56
#     x: 4.0, y: 9.1, y_hat: 1.4, loss: 59.29
#     x: 5.0, y: 10.9, y_hat: 1.6, loss: 86.49
#     Loss = 108.8528
#
# (w=0.2, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 1.0, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 1.0, loss: 6.05
#     x: 2.0, y: 5.0, y_hat: 1.2, loss: 14.44
#     x: 3.5, y: 7.9, y_hat: 1.5, loss: 40.96
#     x: 4.0, y: 9.1, y_hat: 1.6, loss: 56.25
#     x: 5.0, y: 10.9, y_hat: 1.8, loss: 82.81
#     Loss = 102.4608
#
# (w=0.2, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 1.2, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 1.2, loss: 5.11
#     x: 2.0, y: 5.0, y_hat: 1.4, loss: 12.96
#     x: 3.5, y: 7.9, y_hat: 1.7, loss: 38.44
#     x: 4.0, y: 9.1, y_hat: 1.8, loss: 53.29
#     x: 5.0, y: 10.9, y_hat: 2.0, loss: 79.21
#     Loss = 96.3088
#
# (w=0.2, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 1.4, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 1.4, loss: 4.24
#     x: 2.0, y: 5.0, y_hat: 1.6, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 1.9, loss: 36.00
#     x: 4.0, y: 9.1, y_hat: 2.0, loss: 50.41
#     x: 5.0, y: 10.9, y_hat: 2.2, loss: 75.69
#     Loss = 90.3968
#
# (w=0.2, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.6, loss: 3.46
#     x: 2.0, y: 5.0, y_hat: 1.8, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 2.1, loss: 33.64
#     x: 4.0, y: 9.1, y_hat: 2.2, loss: 47.61
#     x: 5.0, y: 10.9, y_hat: 2.4, loss: 72.25
#     Loss = 84.7248
#
# (w=0.2, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 1.8, loss: 2.76
#     x: 2.0, y: 5.0, y_hat: 2.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 2.3, loss: 31.36
#     x: 4.0, y: 9.1, y_hat: 2.4, loss: 44.89
#     x: 5.0, y: 10.9, y_hat: 2.6, loss: 68.89
#     Loss = 79.2928
#
# (w=0.2, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.0, loss: 2.13
#     x: 2.0, y: 5.0, y_hat: 2.2, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 2.5, loss: 29.16
#     x: 4.0, y: 9.1, y_hat: 2.6, loss: 42.25
#     x: 5.0, y: 10.9, y_hat: 2.8, loss: 65.61
#     Loss = 74.1008
#
# (w=0.2, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.2, loss: 1.59
#     x: 2.0, y: 5.0, y_hat: 2.4, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 2.7, loss: 27.04
#     x: 4.0, y: 9.1, y_hat: 2.8, loss: 39.69
#     x: 5.0, y: 10.9, y_hat: 3.0, loss: 62.41
#     Loss = 69.1488
#
# (w=0.4, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 0.4, loss: 7.29
#     x: 1.2, y: 3.5, y_hat: 0.5, loss: 9.12
#     x: 2.0, y: 5.0, y_hat: 0.8, loss: 17.64
#     x: 3.5, y: 7.9, y_hat: 1.4, loss: 42.25
#     x: 4.0, y: 9.1, y_hat: 1.6, loss: 56.25
#     x: 5.0, y: 10.9, y_hat: 2.0, loss: 79.21
#     Loss = 105.8802
#
# (w=0.4, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 0.6, loss: 6.25
#     x: 1.2, y: 3.5, y_hat: 0.7, loss: 7.95
#     x: 2.0, y: 5.0, y_hat: 1.0, loss: 16.00
#     x: 3.5, y: 7.9, y_hat: 1.6, loss: 39.69
#     x: 4.0, y: 9.1, y_hat: 1.8, loss: 53.29
#     x: 5.0, y: 10.9, y_hat: 2.2, loss: 75.69
#     Loss = 99.4362
#
# (w=0.4, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 0.8, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 0.9, loss: 6.86
#     x: 2.0, y: 5.0, y_hat: 1.2, loss: 14.44
#     x: 3.5, y: 7.9, y_hat: 1.8, loss: 37.21
#     x: 4.0, y: 9.1, y_hat: 2.0, loss: 50.41
#     x: 5.0, y: 10.9, y_hat: 2.4, loss: 72.25
#     Loss = 93.2322
#
# (w=0.4, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 1.0, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 1.1, loss: 5.86
#     x: 2.0, y: 5.0, y_hat: 1.4, loss: 12.96
#     x: 3.5, y: 7.9, y_hat: 2.0, loss: 34.81
#     x: 4.0, y: 9.1, y_hat: 2.2, loss: 47.61
#     x: 5.0, y: 10.9, y_hat: 2.6, loss: 68.89
#     Loss = 87.2682
#
# (w=0.4, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 1.2, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 1.3, loss: 4.93
#     x: 2.0, y: 5.0, y_hat: 1.6, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 2.2, loss: 32.49
#     x: 4.0, y: 9.1, y_hat: 2.4, loss: 44.89
#     x: 5.0, y: 10.9, y_hat: 2.8, loss: 65.61
#     Loss = 81.5442
#
# (w=0.4, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 1.4, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 1.5, loss: 4.08
#     x: 2.0, y: 5.0, y_hat: 1.8, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 2.4, loss: 30.25
#     x: 4.0, y: 9.1, y_hat: 2.6, loss: 42.25
#     x: 5.0, y: 10.9, y_hat: 3.0, loss: 62.41
#     Loss = 76.0602
#
# (w=0.4, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.7, loss: 3.31
#     x: 2.0, y: 5.0, y_hat: 2.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 2.6, loss: 28.09
#     x: 4.0, y: 9.1, y_hat: 2.8, loss: 39.69
#     x: 5.0, y: 10.9, y_hat: 3.2, loss: 59.29
#     Loss = 70.8162
#
# (w=0.4, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 1.9, loss: 2.62
#     x: 2.0, y: 5.0, y_hat: 2.2, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 2.8, loss: 26.01
#     x: 4.0, y: 9.1, y_hat: 3.0, loss: 37.21
#     x: 5.0, y: 10.9, y_hat: 3.4, loss: 56.25
#     Loss = 65.8122
#
# (w=0.4, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.1, loss: 2.02
#     x: 2.0, y: 5.0, y_hat: 2.4, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 3.0, loss: 24.01
#     x: 4.0, y: 9.1, y_hat: 3.2, loss: 34.81
#     x: 5.0, y: 10.9, y_hat: 3.6, loss: 53.29
#     Loss = 61.0482
#
# (w=0.4, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.3, loss: 1.49
#     x: 2.0, y: 5.0, y_hat: 2.6, loss: 5.76
#     x: 3.5, y: 7.9, y_hat: 3.2, loss: 22.09
#     x: 4.0, y: 9.1, y_hat: 3.4, loss: 32.49
#     x: 5.0, y: 10.9, y_hat: 3.8, loss: 50.41
#     Loss = 56.5242
#
# (w=0.4, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.5, loss: 1.04
#     x: 2.0, y: 5.0, y_hat: 2.8, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 3.4, loss: 20.25
#     x: 4.0, y: 9.1, y_hat: 3.6, loss: 30.25
#     x: 5.0, y: 10.9, y_hat: 4.0, loss: 47.61
#     Loss = 52.2402
#
# (w=0.6, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 0.6, loss: 6.25
#     x: 1.2, y: 3.5, y_hat: 0.7, loss: 7.73
#     x: 2.0, y: 5.0, y_hat: 1.2, loss: 14.44
#     x: 3.5, y: 7.9, y_hat: 2.1, loss: 33.64
#     x: 4.0, y: 9.1, y_hat: 2.4, loss: 44.89
#     x: 5.0, y: 10.9, y_hat: 3.0, loss: 62.41
#     Loss = 84.6792
#
# (w=0.6, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 0.8, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 0.9, loss: 6.66
#     x: 2.0, y: 5.0, y_hat: 1.4, loss: 12.96
#     x: 3.5, y: 7.9, y_hat: 2.3, loss: 31.36
#     x: 4.0, y: 9.1, y_hat: 2.6, loss: 42.25
#     x: 5.0, y: 10.9, y_hat: 3.2, loss: 59.29
#     Loss = 78.9032
#
# (w=0.6, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 1.0, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 1.1, loss: 5.66
#     x: 2.0, y: 5.0, y_hat: 1.6, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 2.5, loss: 29.16
#     x: 4.0, y: 9.1, y_hat: 2.8, loss: 39.69
#     x: 5.0, y: 10.9, y_hat: 3.4, loss: 56.25
#     Loss = 73.3672
#
# (w=0.6, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 1.2, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 1.3, loss: 4.75
#     x: 2.0, y: 5.0, y_hat: 1.8, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 2.7, loss: 27.04
#     x: 4.0, y: 9.1, y_hat: 3.0, loss: 37.21
#     x: 5.0, y: 10.9, y_hat: 3.6, loss: 53.29
#     Loss = 68.0712
#
# (w=0.6, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 1.4, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 1.5, loss: 3.92
#     x: 2.0, y: 5.0, y_hat: 2.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 2.9, loss: 25.00
#     x: 4.0, y: 9.1, y_hat: 3.2, loss: 34.81
#     x: 5.0, y: 10.9, y_hat: 3.8, loss: 50.41
#     Loss = 63.0152
#
# (w=0.6, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.7, loss: 3.17
#     x: 2.0, y: 5.0, y_hat: 2.2, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 3.1, loss: 23.04
#     x: 4.0, y: 9.1, y_hat: 3.4, loss: 32.49
#     x: 5.0, y: 10.9, y_hat: 4.0, loss: 47.61
#     Loss = 58.1992
#
# (w=0.6, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 1.9, loss: 2.50
#     x: 2.0, y: 5.0, y_hat: 2.4, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 3.3, loss: 21.16
#     x: 4.0, y: 9.1, y_hat: 3.6, loss: 30.25
#     x: 5.0, y: 10.9, y_hat: 4.2, loss: 44.89
#     Loss = 53.6232
#
# (w=0.6, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.1, loss: 1.90
#     x: 2.0, y: 5.0, y_hat: 2.6, loss: 5.76
#     x: 3.5, y: 7.9, y_hat: 3.5, loss: 19.36
#     x: 4.0, y: 9.1, y_hat: 3.8, loss: 28.09
#     x: 5.0, y: 10.9, y_hat: 4.4, loss: 42.25
#     Loss = 49.2872
#
# (w=0.6, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.3, loss: 1.39
#     x: 2.0, y: 5.0, y_hat: 2.8, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 3.7, loss: 17.64
#     x: 4.0, y: 9.1, y_hat: 4.0, loss: 26.01
#     x: 5.0, y: 10.9, y_hat: 4.6, loss: 39.69
#     Loss = 45.1912
#
# (w=0.6, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.5, loss: 0.96
#     x: 2.0, y: 5.0, y_hat: 3.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 3.9, loss: 16.00
#     x: 4.0, y: 9.1, y_hat: 4.2, loss: 24.01
#     x: 5.0, y: 10.9, y_hat: 4.8, loss: 37.21
#     Loss = 41.3352
#
# (w=0.6, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 2.7, loss: 0.61
#     x: 2.0, y: 5.0, y_hat: 3.2, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 4.1, loss: 14.44
#     x: 4.0, y: 9.1, y_hat: 4.4, loss: 22.09
#     x: 5.0, y: 10.9, y_hat: 5.0, loss: 34.81
#     Loss = 37.7192
#
# (w=0.8, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 0.8, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 1.0, loss: 6.45
#     x: 2.0, y: 5.0, y_hat: 1.6, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 2.8, loss: 26.01
#     x: 4.0, y: 9.1, y_hat: 3.2, loss: 34.81
#     x: 5.0, y: 10.9, y_hat: 4.0, loss: 47.61
#     Loss = 65.8658
#
# (w=0.8, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 1.0, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 1.2, loss: 5.48
#     x: 2.0, y: 5.0, y_hat: 1.8, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 3.0, loss: 24.01
#     x: 4.0, y: 9.1, y_hat: 3.4, loss: 32.49
#     x: 5.0, y: 10.9, y_hat: 4.2, loss: 44.89
#     Loss = 60.7578
#
# (w=0.8, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 1.2, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 1.4, loss: 4.58
#     x: 2.0, y: 5.0, y_hat: 2.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 3.2, loss: 22.09
#     x: 4.0, y: 9.1, y_hat: 3.6, loss: 30.25
#     x: 5.0, y: 10.9, y_hat: 4.4, loss: 42.25
#     Loss = 55.8898
#
# (w=0.8, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 1.4, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 1.6, loss: 3.76
#     x: 2.0, y: 5.0, y_hat: 2.2, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 3.4, loss: 20.25
#     x: 4.0, y: 9.1, y_hat: 3.8, loss: 28.09
#     x: 5.0, y: 10.9, y_hat: 4.6, loss: 39.69
#     Loss = 51.2618
#
# (w=0.8, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.8, loss: 3.03
#     x: 2.0, y: 5.0, y_hat: 2.4, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 3.6, loss: 18.49
#     x: 4.0, y: 9.1, y_hat: 4.0, loss: 26.01
#     x: 5.0, y: 10.9, y_hat: 4.8, loss: 37.21
#     Loss = 46.8738
#
# (w=0.8, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 2.0, loss: 2.37
#     x: 2.0, y: 5.0, y_hat: 2.6, loss: 5.76
#     x: 3.5, y: 7.9, y_hat: 3.8, loss: 16.81
#     x: 4.0, y: 9.1, y_hat: 4.2, loss: 24.01
#     x: 5.0, y: 10.9, y_hat: 5.0, loss: 34.81
#     Loss = 42.7258
#
# (w=0.8, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.2, loss: 1.80
#     x: 2.0, y: 5.0, y_hat: 2.8, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 4.0, loss: 15.21
#     x: 4.0, y: 9.1, y_hat: 4.4, loss: 22.09
#     x: 5.0, y: 10.9, y_hat: 5.2, loss: 32.49
#     Loss = 38.8178
#
# (w=0.8, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.4, loss: 1.30
#     x: 2.0, y: 5.0, y_hat: 3.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 4.2, loss: 13.69
#     x: 4.0, y: 9.1, y_hat: 4.6, loss: 20.25
#     x: 5.0, y: 10.9, y_hat: 5.4, loss: 30.25
#     Loss = 35.1498
#
# (w=0.8, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.6, loss: 0.88
#     x: 2.0, y: 5.0, y_hat: 3.2, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 4.4, loss: 12.25
#     x: 4.0, y: 9.1, y_hat: 4.8, loss: 18.49
#     x: 5.0, y: 10.9, y_hat: 5.6, loss: 28.09
#     Loss = 31.7218
#
# (w=0.8, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 2.8, loss: 0.55
#     x: 2.0, y: 5.0, y_hat: 3.4, loss: 2.56
#     x: 3.5, y: 7.9, y_hat: 4.6, loss: 10.89
#     x: 4.0, y: 9.1, y_hat: 5.0, loss: 16.81
#     x: 5.0, y: 10.9, y_hat: 5.8, loss: 26.01
#     Loss = 28.5338
#
# (w=0.8, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.0, loss: 0.29
#     x: 2.0, y: 5.0, y_hat: 3.6, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 4.8, loss: 9.61
#     x: 4.0, y: 9.1, y_hat: 5.2, loss: 15.21
#     x: 5.0, y: 10.9, y_hat: 6.0, loss: 24.01
#     Loss = 25.5858
#
# (w=1.0, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 1.0, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 1.2, loss: 5.29
#     x: 2.0, y: 5.0, y_hat: 2.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 3.5, loss: 19.36
#     x: 4.0, y: 9.1, y_hat: 4.0, loss: 26.01
#     x: 5.0, y: 10.9, y_hat: 5.0, loss: 34.81
#     Loss = 49.4400
#
# (w=1.0, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 1.2, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 1.4, loss: 4.41
#     x: 2.0, y: 5.0, y_hat: 2.2, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 3.7, loss: 17.64
#     x: 4.0, y: 9.1, y_hat: 4.2, loss: 24.01
#     x: 5.0, y: 10.9, y_hat: 5.2, loss: 32.49
#     Loss = 45.0000
#
# (w=1.0, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 1.4, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 1.6, loss: 3.61
#     x: 2.0, y: 5.0, y_hat: 2.4, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 3.9, loss: 16.00
#     x: 4.0, y: 9.1, y_hat: 4.4, loss: 22.09
#     x: 5.0, y: 10.9, y_hat: 5.4, loss: 30.25
#     Loss = 40.8000
#
# (w=1.0, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.8, loss: 2.89
#     x: 2.0, y: 5.0, y_hat: 2.6, loss: 5.76
#     x: 3.5, y: 7.9, y_hat: 4.1, loss: 14.44
#     x: 4.0, y: 9.1, y_hat: 4.6, loss: 20.25
#     x: 5.0, y: 10.9, y_hat: 5.6, loss: 28.09
#     Loss = 36.8400
#
# (w=1.0, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 2.0, loss: 2.25
#     x: 2.0, y: 5.0, y_hat: 2.8, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 4.3, loss: 12.96
#     x: 4.0, y: 9.1, y_hat: 4.8, loss: 18.49
#     x: 5.0, y: 10.9, y_hat: 5.8, loss: 26.01
#     Loss = 33.1200
#
# (w=1.0, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.2, loss: 1.69
#     x: 2.0, y: 5.0, y_hat: 3.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 4.5, loss: 11.56
#     x: 4.0, y: 9.1, y_hat: 5.0, loss: 16.81
#     x: 5.0, y: 10.9, y_hat: 6.0, loss: 24.01
#     Loss = 29.6400
#
# (w=1.0, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.4, loss: 1.21
#     x: 2.0, y: 5.0, y_hat: 3.2, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 4.7, loss: 10.24
#     x: 4.0, y: 9.1, y_hat: 5.2, loss: 15.21
#     x: 5.0, y: 10.9, y_hat: 6.2, loss: 22.09
#     Loss = 26.4000
#
# (w=1.0, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.6, loss: 0.81
#     x: 2.0, y: 5.0, y_hat: 3.4, loss: 2.56
#     x: 3.5, y: 7.9, y_hat: 4.9, loss: 9.00
#     x: 4.0, y: 9.1, y_hat: 5.4, loss: 13.69
#     x: 5.0, y: 10.9, y_hat: 6.4, loss: 20.25
#     Loss = 23.4000
#
# (w=1.0, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 2.8, loss: 0.49
#     x: 2.0, y: 5.0, y_hat: 3.6, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 5.1, loss: 7.84
#     x: 4.0, y: 9.1, y_hat: 5.6, loss: 12.25
#     x: 5.0, y: 10.9, y_hat: 6.6, loss: 18.49
#     Loss = 20.6400
#
# (w=1.0, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.0, loss: 0.25
#     x: 2.0, y: 5.0, y_hat: 3.8, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 5.3, loss: 6.76
#     x: 4.0, y: 9.1, y_hat: 5.8, loss: 10.89
#     x: 5.0, y: 10.9, y_hat: 6.8, loss: 16.81
#     Loss = 18.1200
#
# (w=1.0, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.2, loss: 0.09
#     x: 2.0, y: 5.0, y_hat: 4.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 5.5, loss: 5.76
#     x: 4.0, y: 9.1, y_hat: 6.0, loss: 9.61
#     x: 5.0, y: 10.9, y_hat: 7.0, loss: 15.21
#     Loss = 15.8400
#
# (w=1.2, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 1.2, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 1.4, loss: 4.24
#     x: 2.0, y: 5.0, y_hat: 2.4, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 4.2, loss: 13.69
#     x: 4.0, y: 9.1, y_hat: 4.8, loss: 18.49
#     x: 5.0, y: 10.9, y_hat: 6.0, loss: 24.01
#     Loss = 35.4018
#
# (w=1.2, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 1.4, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 1.6, loss: 3.46
#     x: 2.0, y: 5.0, y_hat: 2.6, loss: 5.76
#     x: 3.5, y: 7.9, y_hat: 4.4, loss: 12.25
#     x: 4.0, y: 9.1, y_hat: 5.0, loss: 16.81
#     x: 5.0, y: 10.9, y_hat: 6.2, loss: 22.09
#     Loss = 31.6298
#
# (w=1.2, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.8, loss: 2.76
#     x: 2.0, y: 5.0, y_hat: 2.8, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 4.6, loss: 10.89
#     x: 4.0, y: 9.1, y_hat: 5.2, loss: 15.21
#     x: 5.0, y: 10.9, y_hat: 6.4, loss: 20.25
#     Loss = 28.0978
#
# (w=1.2, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 2.0, loss: 2.13
#     x: 2.0, y: 5.0, y_hat: 3.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 4.8, loss: 9.61
#     x: 4.0, y: 9.1, y_hat: 5.4, loss: 13.69
#     x: 5.0, y: 10.9, y_hat: 6.6, loss: 18.49
#     Loss = 24.8058
#
# (w=1.2, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.2, loss: 1.59
#     x: 2.0, y: 5.0, y_hat: 3.2, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 5.0, loss: 8.41
#     x: 4.0, y: 9.1, y_hat: 5.6, loss: 12.25
#     x: 5.0, y: 10.9, y_hat: 6.8, loss: 16.81
#     Loss = 21.7538
#
# (w=1.2, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.4, loss: 1.12
#     x: 2.0, y: 5.0, y_hat: 3.4, loss: 2.56
#     x: 3.5, y: 7.9, y_hat: 5.2, loss: 7.29
#     x: 4.0, y: 9.1, y_hat: 5.8, loss: 10.89
#     x: 5.0, y: 10.9, y_hat: 7.0, loss: 15.21
#     Loss = 18.9418
#
# (w=1.2, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.6, loss: 0.74
#     x: 2.0, y: 5.0, y_hat: 3.6, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 5.4, loss: 6.25
#     x: 4.0, y: 9.1, y_hat: 6.0, loss: 9.61
#     x: 5.0, y: 10.9, y_hat: 7.2, loss: 13.69
#     Loss = 16.3698
#
# (w=1.2, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 2.8, loss: 0.44
#     x: 2.0, y: 5.0, y_hat: 3.8, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 5.6, loss: 5.29
#     x: 4.0, y: 9.1, y_hat: 6.2, loss: 8.41
#     x: 5.0, y: 10.9, y_hat: 7.4, loss: 12.25
#     Loss = 14.0378
#
# (w=1.2, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.0, loss: 0.21
#     x: 2.0, y: 5.0, y_hat: 4.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 5.8, loss: 4.41
#     x: 4.0, y: 9.1, y_hat: 6.4, loss: 7.29
#     x: 5.0, y: 10.9, y_hat: 7.6, loss: 10.89
#     Loss = 11.9458
#
# (w=1.2, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.2, loss: 0.07
#     x: 2.0, y: 5.0, y_hat: 4.2, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 6.0, loss: 3.61
#     x: 4.0, y: 9.1, y_hat: 6.6, loss: 6.25
#     x: 5.0, y: 10.9, y_hat: 7.8, loss: 9.61
#     Loss = 10.0938
#
# (w=1.2, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.4, loss: 0.00
#     x: 2.0, y: 5.0, y_hat: 4.4, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 6.2, loss: 2.89
#     x: 4.0, y: 9.1, y_hat: 6.8, loss: 5.29
#     x: 5.0, y: 10.9, y_hat: 8.0, loss: 8.41
#     Loss = 8.4818
#
# (w=1.4, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 1.4, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 1.7, loss: 3.31
#     x: 2.0, y: 5.0, y_hat: 2.8, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 4.9, loss: 9.00
#     x: 4.0, y: 9.1, y_hat: 5.6, loss: 12.25
#     x: 5.0, y: 10.9, y_hat: 7.0, loss: 15.21
#     Loss = 23.7512
#
# (w=1.4, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.9, loss: 2.62
#     x: 2.0, y: 5.0, y_hat: 3.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 5.1, loss: 7.84
#     x: 4.0, y: 9.1, y_hat: 5.8, loss: 10.89
#     x: 5.0, y: 10.9, y_hat: 7.2, loss: 13.69
#     Loss = 20.6472
#
# (w=1.4, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 2.1, loss: 2.02
#     x: 2.0, y: 5.0, y_hat: 3.2, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 5.3, loss: 6.76
#     x: 4.0, y: 9.1, y_hat: 6.0, loss: 9.61
#     x: 5.0, y: 10.9, y_hat: 7.4, loss: 12.25
#     Loss = 17.7832
#
# (w=1.4, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.3, loss: 1.49
#     x: 2.0, y: 5.0, y_hat: 3.4, loss: 2.56
#     x: 3.5, y: 7.9, y_hat: 5.5, loss: 5.76
#     x: 4.0, y: 9.1, y_hat: 6.2, loss: 8.41
#     x: 5.0, y: 10.9, y_hat: 7.6, loss: 10.89
#     Loss = 15.1592
#
# (w=1.4, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.5, loss: 1.04
#     x: 2.0, y: 5.0, y_hat: 3.6, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 5.7, loss: 4.84
#     x: 4.0, y: 9.1, y_hat: 6.4, loss: 7.29
#     x: 5.0, y: 10.9, y_hat: 7.8, loss: 9.61
#     Loss = 12.7752
#
# (w=1.4, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.7, loss: 0.67
#     x: 2.0, y: 5.0, y_hat: 3.8, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 5.9, loss: 4.00
#     x: 4.0, y: 9.1, y_hat: 6.6, loss: 6.25
#     x: 5.0, y: 10.9, y_hat: 8.0, loss: 8.41
#     Loss = 10.6312
#
# (w=1.4, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 2.9, loss: 0.38
#     x: 2.0, y: 5.0, y_hat: 4.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 6.1, loss: 3.24
#     x: 4.0, y: 9.1, y_hat: 6.8, loss: 5.29
#     x: 5.0, y: 10.9, y_hat: 8.2, loss: 7.29
#     Loss = 8.7272
#
# (w=1.4, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.1, loss: 0.18
#     x: 2.0, y: 5.0, y_hat: 4.2, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 6.3, loss: 2.56
#     x: 4.0, y: 9.1, y_hat: 7.0, loss: 4.41
#     x: 5.0, y: 10.9, y_hat: 8.4, loss: 6.25
#     Loss = 7.0632
#
# (w=1.4, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.3, loss: 0.05
#     x: 2.0, y: 5.0, y_hat: 4.4, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 6.5, loss: 1.96
#     x: 4.0, y: 9.1, y_hat: 7.2, loss: 3.61
#     x: 5.0, y: 10.9, y_hat: 8.6, loss: 5.29
#     Loss = 5.6392
#
# (w=1.4, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.5, loss: 0.00
#     x: 2.0, y: 5.0, y_hat: 4.6, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 6.7, loss: 1.44
#     x: 4.0, y: 9.1, y_hat: 7.4, loss: 2.89
#     x: 5.0, y: 10.9, y_hat: 8.8, loss: 4.41
#     Loss = 4.4552
#
# (w=1.4, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.7, loss: 0.03
#     x: 2.0, y: 5.0, y_hat: 4.8, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 6.9, loss: 1.00
#     x: 4.0, y: 9.1, y_hat: 7.6, loss: 2.25
#     x: 5.0, y: 10.9, y_hat: 9.0, loss: 3.61
#     Loss = 3.5112
#
# (w=1.6, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 1.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 1.9, loss: 2.50
#     x: 2.0, y: 5.0, y_hat: 3.2, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 5.6, loss: 5.29
#     x: 4.0, y: 9.1, y_hat: 6.4, loss: 7.29
#     x: 5.0, y: 10.9, y_hat: 8.0, loss: 8.41
#     Loss = 14.4882
#
# (w=1.6, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 2.1, loss: 1.90
#     x: 2.0, y: 5.0, y_hat: 3.4, loss: 2.56
#     x: 3.5, y: 7.9, y_hat: 5.8, loss: 4.41
#     x: 4.0, y: 9.1, y_hat: 6.6, loss: 6.25
#     x: 5.0, y: 10.9, y_hat: 8.2, loss: 7.29
#     Loss = 12.0522
#
# (w=1.6, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.3, loss: 1.39
#     x: 2.0, y: 5.0, y_hat: 3.6, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 6.0, loss: 3.61
#     x: 4.0, y: 9.1, y_hat: 6.8, loss: 5.29
#     x: 5.0, y: 10.9, y_hat: 8.4, loss: 6.25
#     Loss = 9.8562
#
# (w=1.6, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.5, loss: 0.96
#     x: 2.0, y: 5.0, y_hat: 3.8, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 6.2, loss: 2.89
#     x: 4.0, y: 9.1, y_hat: 7.0, loss: 4.41
#     x: 5.0, y: 10.9, y_hat: 8.6, loss: 5.29
#     Loss = 7.9002
#
# (w=1.6, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.7, loss: 0.61
#     x: 2.0, y: 5.0, y_hat: 4.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 6.4, loss: 2.25
#     x: 4.0, y: 9.1, y_hat: 7.2, loss: 3.61
#     x: 5.0, y: 10.9, y_hat: 8.8, loss: 4.41
#     Loss = 6.1842
#
# (w=1.6, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 2.9, loss: 0.34
#     x: 2.0, y: 5.0, y_hat: 4.2, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 6.6, loss: 1.69
#     x: 4.0, y: 9.1, y_hat: 7.4, loss: 2.89
#     x: 5.0, y: 10.9, y_hat: 9.0, loss: 3.61
#     Loss = 4.7082
#
# (w=1.6, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.1, loss: 0.14
#     x: 2.0, y: 5.0, y_hat: 4.4, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 6.8, loss: 1.21
#     x: 4.0, y: 9.1, y_hat: 7.6, loss: 2.25
#     x: 5.0, y: 10.9, y_hat: 9.2, loss: 2.89
#     Loss = 3.4722
#
# (w=1.6, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.3, loss: 0.03
#     x: 2.0, y: 5.0, y_hat: 4.6, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 7.0, loss: 0.81
#     x: 4.0, y: 9.1, y_hat: 7.8, loss: 1.69
#     x: 5.0, y: 10.9, y_hat: 9.4, loss: 2.25
#     Loss = 2.4762
#
# (w=1.6, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.5, loss: 0.00
#     x: 2.0, y: 5.0, y_hat: 4.8, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 7.2, loss: 0.49
#     x: 4.0, y: 9.1, y_hat: 8.0, loss: 1.21
#     x: 5.0, y: 10.9, y_hat: 9.6, loss: 1.69
#     Loss = 1.7202
#
# (w=1.6, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.7, loss: 0.05
#     x: 2.0, y: 5.0, y_hat: 5.0, loss: 0.00
#     x: 3.5, y: 7.9, y_hat: 7.4, loss: 0.25
#     x: 4.0, y: 9.1, y_hat: 8.2, loss: 0.81
#     x: 5.0, y: 10.9, y_hat: 9.8, loss: 1.21
#     Loss = 1.2042
#
# (w=1.6, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 3.9, loss: 0.18
#     x: 2.0, y: 5.0, y_hat: 5.2, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 7.6, loss: 0.09
#     x: 4.0, y: 9.1, y_hat: 8.4, loss: 0.49
#     x: 5.0, y: 10.9, y_hat: 10.0, loss: 0.81
#     Loss = 0.9282
#
# (w=1.8, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 1.8, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 2.2, loss: 1.80
#     x: 2.0, y: 5.0, y_hat: 3.6, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 6.3, loss: 2.56
#     x: 4.0, y: 9.1, y_hat: 7.2, loss: 3.61
#     x: 5.0, y: 10.9, y_hat: 9.0, loss: 3.61
#     Loss = 7.6128
#
# (w=1.8, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.4, loss: 1.30
#     x: 2.0, y: 5.0, y_hat: 3.8, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 6.5, loss: 1.96
#     x: 4.0, y: 9.1, y_hat: 7.4, loss: 2.89
#     x: 5.0, y: 10.9, y_hat: 9.2, loss: 2.89
#     Loss = 5.8448
#
# (w=1.8, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.6, loss: 0.88
#     x: 2.0, y: 5.0, y_hat: 4.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 6.7, loss: 1.44
#     x: 4.0, y: 9.1, y_hat: 7.6, loss: 2.25
#     x: 5.0, y: 10.9, y_hat: 9.4, loss: 2.25
#     Loss = 4.3168
#
# (w=1.8, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.8, loss: 0.55
#     x: 2.0, y: 5.0, y_hat: 4.2, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 6.9, loss: 1.00
#     x: 4.0, y: 9.1, y_hat: 7.8, loss: 1.69
#     x: 5.0, y: 10.9, y_hat: 9.6, loss: 1.69
#     Loss = 3.0288
#
# (w=1.8, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 3.0, loss: 0.29
#     x: 2.0, y: 5.0, y_hat: 4.4, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 7.1, loss: 0.64
#     x: 4.0, y: 9.1, y_hat: 8.0, loss: 1.21
#     x: 5.0, y: 10.9, y_hat: 9.8, loss: 1.21
#     Loss = 1.9808
#
# (w=1.8, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.2, loss: 0.12
#     x: 2.0, y: 5.0, y_hat: 4.6, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 7.3, loss: 0.36
#     x: 4.0, y: 9.1, y_hat: 8.2, loss: 0.81
#     x: 5.0, y: 10.9, y_hat: 10.0, loss: 0.81
#     Loss = 1.1728
#
# (w=1.8, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.4, loss: 0.02
#     x: 2.0, y: 5.0, y_hat: 4.8, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 7.5, loss: 0.16
#     x: 4.0, y: 9.1, y_hat: 8.4, loss: 0.49
#     x: 5.0, y: 10.9, y_hat: 10.2, loss: 0.49
#     Loss = 0.6048
#
# (w=1.8, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.6, loss: 0.00
#     x: 2.0, y: 5.0, y_hat: 5.0, loss: 0.00
#     x: 3.5, y: 7.9, y_hat: 7.7, loss: 0.04
#     x: 4.0, y: 9.1, y_hat: 8.6, loss: 0.25
#     x: 5.0, y: 10.9, y_hat: 10.4, loss: 0.25
#     Loss = 0.2768
#
# (w=1.8, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.8, loss: 0.07
#     x: 2.0, y: 5.0, y_hat: 5.2, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 7.9, loss: 0.00
#     x: 4.0, y: 9.1, y_hat: 8.8, loss: 0.09
#     x: 5.0, y: 10.9, y_hat: 10.6, loss: 0.09
#     Loss = 0.1888
#
# (w=1.8, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.0, loss: 0.21
#     x: 2.0, y: 5.0, y_hat: 5.4, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 8.1, loss: 0.04
#     x: 4.0, y: 9.1, y_hat: 9.0, loss: 0.01
#     x: 5.0, y: 10.9, y_hat: 10.8, loss: 0.01
#     Loss = 0.3408
#
# (w=1.8, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.2, loss: 0.44
#     x: 2.0, y: 5.0, y_hat: 5.6, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 8.3, loss: 0.16
#     x: 4.0, y: 9.1, y_hat: 9.2, loss: 0.01
#     x: 5.0, y: 10.9, y_hat: 11.0, loss: 0.01
#     Loss = 0.7328
#
# (w=2.0, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 2.0, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 2.4, loss: 1.21
#     x: 2.0, y: 5.0, y_hat: 4.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 7.0, loss: 0.81
#     x: 4.0, y: 9.1, y_hat: 8.0, loss: 1.21
#     x: 5.0, y: 10.9, y_hat: 10.0, loss: 0.81
#     Loss = 3.1250
#
# (w=2.0, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.6, loss: 0.81
#     x: 2.0, y: 5.0, y_hat: 4.2, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 7.2, loss: 0.49
#     x: 4.0, y: 9.1, y_hat: 8.2, loss: 0.81
#     x: 5.0, y: 10.9, y_hat: 10.2, loss: 0.49
#     Loss = 2.0250
#
# (w=2.0, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.8, loss: 0.49
#     x: 2.0, y: 5.0, y_hat: 4.4, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 7.4, loss: 0.25
#     x: 4.0, y: 9.1, y_hat: 8.4, loss: 0.49
#     x: 5.0, y: 10.9, y_hat: 10.4, loss: 0.25
#     Loss = 1.1650
#
# (w=2.0, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 3.0, loss: 0.25
#     x: 2.0, y: 5.0, y_hat: 4.6, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 7.6, loss: 0.09
#     x: 4.0, y: 9.1, y_hat: 8.6, loss: 0.25
#     x: 5.0, y: 10.9, y_hat: 10.6, loss: 0.09
#     Loss = 0.5450
#
# (w=2.0, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.2, loss: 0.09
#     x: 2.0, y: 5.0, y_hat: 4.8, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 7.8, loss: 0.01
#     x: 4.0, y: 9.1, y_hat: 8.8, loss: 0.09
#     x: 5.0, y: 10.9, y_hat: 10.8, loss: 0.01
#     Loss = 0.1650
#
# (w=2.0, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.4, loss: 0.01
#     x: 2.0, y: 5.0, y_hat: 5.0, loss: 0.00
#     x: 3.5, y: 7.9, y_hat: 8.0, loss: 0.01
#     x: 4.0, y: 9.1, y_hat: 9.0, loss: 0.01
#     x: 5.0, y: 10.9, y_hat: 11.0, loss: 0.01
#     Loss = 0.0250
#
# (w=2.0, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.6, loss: 0.01
#     x: 2.0, y: 5.0, y_hat: 5.2, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 8.2, loss: 0.09
#     x: 4.0, y: 9.1, y_hat: 9.2, loss: 0.01
#     x: 5.0, y: 10.9, y_hat: 11.2, loss: 0.09
#     Loss = 0.1250
#
# (w=2.0, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.8, loss: 0.09
#     x: 2.0, y: 5.0, y_hat: 5.4, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 8.4, loss: 0.25
#     x: 4.0, y: 9.1, y_hat: 9.4, loss: 0.09
#     x: 5.0, y: 10.9, y_hat: 11.4, loss: 0.25
#     Loss = 0.4650
#
# (w=2.0, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.0, loss: 0.25
#     x: 2.0, y: 5.0, y_hat: 5.6, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 8.6, loss: 0.49
#     x: 4.0, y: 9.1, y_hat: 9.6, loss: 0.25
#     x: 5.0, y: 10.9, y_hat: 11.6, loss: 0.49
#     Loss = 1.0450
#
# (w=2.0, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.2, loss: 0.49
#     x: 2.0, y: 5.0, y_hat: 5.8, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 8.8, loss: 0.81
#     x: 4.0, y: 9.1, y_hat: 9.8, loss: 0.49
#     x: 5.0, y: 10.9, y_hat: 11.8, loss: 0.81
#     Loss = 1.8650
#
# (w=2.0, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.4, loss: 0.81
#     x: 2.0, y: 5.0, y_hat: 6.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 9.0, loss: 1.21
#     x: 4.0, y: 9.1, y_hat: 10.0, loss: 0.81
#     x: 5.0, y: 10.9, y_hat: 12.0, loss: 1.21
#     Loss = 2.9250
#
# (w=2.2, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 2.2, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 2.6, loss: 0.74
#     x: 2.0, y: 5.0, y_hat: 4.4, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 7.7, loss: 0.04
#     x: 4.0, y: 9.1, y_hat: 8.8, loss: 0.09
#     x: 5.0, y: 10.9, y_hat: 11.0, loss: 0.01
#     Loss = 1.0248
#
# (w=2.2, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.8, loss: 0.44
#     x: 2.0, y: 5.0, y_hat: 4.6, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 7.9, loss: 0.00
#     x: 4.0, y: 9.1, y_hat: 9.0, loss: 0.01
#     x: 5.0, y: 10.9, y_hat: 11.2, loss: 0.09
#     Loss = 0.5928
#
# (w=2.2, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 3.0, loss: 0.21
#     x: 2.0, y: 5.0, y_hat: 4.8, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 8.1, loss: 0.04
#     x: 4.0, y: 9.1, y_hat: 9.2, loss: 0.01
#     x: 5.0, y: 10.9, y_hat: 11.4, loss: 0.25
#     Loss = 0.4008
#
# (w=2.2, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.2, loss: 0.07
#     x: 2.0, y: 5.0, y_hat: 5.0, loss: 0.00
#     x: 3.5, y: 7.9, y_hat: 8.3, loss: 0.16
#     x: 4.0, y: 9.1, y_hat: 9.4, loss: 0.09
#     x: 5.0, y: 10.9, y_hat: 11.6, loss: 0.49
#     Loss = 0.4488
#
# (w=2.2, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.4, loss: 0.00
#     x: 2.0, y: 5.0, y_hat: 5.2, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 8.5, loss: 0.36
#     x: 4.0, y: 9.1, y_hat: 9.6, loss: 0.25
#     x: 5.0, y: 10.9, y_hat: 11.8, loss: 0.81
#     Loss = 0.7368
#
# (w=2.2, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.6, loss: 0.02
#     x: 2.0, y: 5.0, y_hat: 5.4, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 8.7, loss: 0.64
#     x: 4.0, y: 9.1, y_hat: 9.8, loss: 0.49
#     x: 5.0, y: 10.9, y_hat: 12.0, loss: 1.21
#     Loss = 1.2648
#
# (w=2.2, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.8, loss: 0.12
#     x: 2.0, y: 5.0, y_hat: 5.6, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 8.9, loss: 1.00
#     x: 4.0, y: 9.1, y_hat: 10.0, loss: 0.81
#     x: 5.0, y: 10.9, y_hat: 12.2, loss: 1.69
#     Loss = 2.0328
#
# (w=2.2, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.0, loss: 0.29
#     x: 2.0, y: 5.0, y_hat: 5.8, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 9.1, loss: 1.44
#     x: 4.0, y: 9.1, y_hat: 10.2, loss: 1.21
#     x: 5.0, y: 10.9, y_hat: 12.4, loss: 2.25
#     Loss = 3.0408
#
# (w=2.2, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.2, loss: 0.55
#     x: 2.0, y: 5.0, y_hat: 6.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 9.3, loss: 1.96
#     x: 4.0, y: 9.1, y_hat: 10.4, loss: 1.69
#     x: 5.0, y: 10.9, y_hat: 12.6, loss: 2.89
#     Loss = 4.2888
#
# (w=2.2, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.4, loss: 0.88
#     x: 2.0, y: 5.0, y_hat: 6.2, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 9.5, loss: 2.56
#     x: 4.0, y: 9.1, y_hat: 10.6, loss: 2.25
#     x: 5.0, y: 10.9, y_hat: 12.8, loss: 3.61
#     Loss = 5.7768
#
# (w=2.2, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 4.6, loss: 1.30
#     x: 2.0, y: 5.0, y_hat: 6.4, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 9.7, loss: 3.24
#     x: 4.0, y: 9.1, y_hat: 10.8, loss: 2.89
#     x: 5.0, y: 10.9, y_hat: 13.0, loss: 4.41
#     Loss = 7.5048
#
# (w=2.4, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 2.4, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 2.9, loss: 0.38
#     x: 2.0, y: 5.0, y_hat: 4.8, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 8.4, loss: 0.25
#     x: 4.0, y: 9.1, y_hat: 9.6, loss: 0.25
#     x: 5.0, y: 10.9, y_hat: 12.0, loss: 1.21
#     Loss = 1.3122
#
# (w=2.4, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 3.1, loss: 0.18
#     x: 2.0, y: 5.0, y_hat: 5.0, loss: 0.00
#     x: 3.5, y: 7.9, y_hat: 8.6, loss: 0.49
#     x: 4.0, y: 9.1, y_hat: 9.8, loss: 0.49
#     x: 5.0, y: 10.9, y_hat: 12.2, loss: 1.69
#     Loss = 1.5482
#
# (w=2.4, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.3, loss: 0.05
#     x: 2.0, y: 5.0, y_hat: 5.2, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 8.8, loss: 0.81
#     x: 4.0, y: 9.1, y_hat: 10.0, loss: 0.81
#     x: 5.0, y: 10.9, y_hat: 12.4, loss: 2.25
#     Loss = 2.0242
#
# (w=2.4, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.5, loss: 0.00
#     x: 2.0, y: 5.0, y_hat: 5.4, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 9.0, loss: 1.21
#     x: 4.0, y: 9.1, y_hat: 10.2, loss: 1.21
#     x: 5.0, y: 10.9, y_hat: 12.6, loss: 2.89
#     Loss = 2.7402
#
# (w=2.4, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.7, loss: 0.03
#     x: 2.0, y: 5.0, y_hat: 5.6, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 9.2, loss: 1.69
#     x: 4.0, y: 9.1, y_hat: 10.4, loss: 1.69
#     x: 5.0, y: 10.9, y_hat: 12.8, loss: 3.61
#     Loss = 3.6962
#
# (w=2.4, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.9, loss: 0.14
#     x: 2.0, y: 5.0, y_hat: 5.8, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 9.4, loss: 2.25
#     x: 4.0, y: 9.1, y_hat: 10.6, loss: 2.25
#     x: 5.0, y: 10.9, y_hat: 13.0, loss: 4.41
#     Loss = 4.8922
#
# (w=2.4, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.1, loss: 0.34
#     x: 2.0, y: 5.0, y_hat: 6.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 9.6, loss: 2.89
#     x: 4.0, y: 9.1, y_hat: 10.8, loss: 2.89
#     x: 5.0, y: 10.9, y_hat: 13.2, loss: 5.29
#     Loss = 6.3282
#
# (w=2.4, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.3, loss: 0.61
#     x: 2.0, y: 5.0, y_hat: 6.2, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 9.8, loss: 3.61
#     x: 4.0, y: 9.1, y_hat: 11.0, loss: 3.61
#     x: 5.0, y: 10.9, y_hat: 13.4, loss: 6.25
#     Loss = 8.0042
#
# (w=2.4, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.5, loss: 0.96
#     x: 2.0, y: 5.0, y_hat: 6.4, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 10.0, loss: 4.41
#     x: 4.0, y: 9.1, y_hat: 11.2, loss: 4.41
#     x: 5.0, y: 10.9, y_hat: 13.6, loss: 7.29
#     Loss = 9.9202
#
# (w=2.4, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 4.7, loss: 1.39
#     x: 2.0, y: 5.0, y_hat: 6.6, loss: 2.56
#     x: 3.5, y: 7.9, y_hat: 10.2, loss: 5.29
#     x: 4.0, y: 9.1, y_hat: 11.4, loss: 5.29
#     x: 5.0, y: 10.9, y_hat: 13.8, loss: 8.41
#     Loss = 12.0762
#
# (w=2.4, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 4.4, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 4.9, loss: 1.90
#     x: 2.0, y: 5.0, y_hat: 6.8, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 10.4, loss: 6.25
#     x: 4.0, y: 9.1, y_hat: 11.6, loss: 6.25
#     x: 5.0, y: 10.9, y_hat: 14.0, loss: 9.61
#     Loss = 14.4722
#
# (w=2.6, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 2.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 3.1, loss: 0.14
#     x: 2.0, y: 5.0, y_hat: 5.2, loss: 0.04
#     x: 3.5, y: 7.9, y_hat: 9.1, loss: 1.44
#     x: 4.0, y: 9.1, y_hat: 10.4, loss: 1.69
#     x: 5.0, y: 10.9, y_hat: 13.0, loss: 4.41
#     Loss = 3.9872
#
# (w=2.6, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.3, loss: 0.03
#     x: 2.0, y: 5.0, y_hat: 5.4, loss: 0.16
#     x: 3.5, y: 7.9, y_hat: 9.3, loss: 1.96
#     x: 4.0, y: 9.1, y_hat: 10.6, loss: 2.25
#     x: 5.0, y: 10.9, y_hat: 13.2, loss: 5.29
#     Loss = 4.8912
#
# (w=2.6, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.5, loss: 0.00
#     x: 2.0, y: 5.0, y_hat: 5.6, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 9.5, loss: 2.56
#     x: 4.0, y: 9.1, y_hat: 10.8, loss: 2.89
#     x: 5.0, y: 10.9, y_hat: 13.4, loss: 6.25
#     Loss = 6.0352
#
# (w=2.6, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.7, loss: 0.05
#     x: 2.0, y: 5.0, y_hat: 5.8, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 9.7, loss: 3.24
#     x: 4.0, y: 9.1, y_hat: 11.0, loss: 3.61
#     x: 5.0, y: 10.9, y_hat: 13.6, loss: 7.29
#     Loss = 7.4192
#
# (w=2.6, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.9, loss: 0.18
#     x: 2.0, y: 5.0, y_hat: 6.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 9.9, loss: 4.00
#     x: 4.0, y: 9.1, y_hat: 11.2, loss: 4.41
#     x: 5.0, y: 10.9, y_hat: 13.8, loss: 8.41
#     Loss = 9.0432
#
# (w=2.6, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.1, loss: 0.38
#     x: 2.0, y: 5.0, y_hat: 6.2, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 10.1, loss: 4.84
#     x: 4.0, y: 9.1, y_hat: 11.4, loss: 5.29
#     x: 5.0, y: 10.9, y_hat: 14.0, loss: 9.61
#     Loss = 10.9072
#
# (w=2.6, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.3, loss: 0.67
#     x: 2.0, y: 5.0, y_hat: 6.4, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 10.3, loss: 5.76
#     x: 4.0, y: 9.1, y_hat: 11.6, loss: 6.25
#     x: 5.0, y: 10.9, y_hat: 14.2, loss: 10.89
#     Loss = 13.0112
#
# (w=2.6, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.5, loss: 1.04
#     x: 2.0, y: 5.0, y_hat: 6.6, loss: 2.56
#     x: 3.5, y: 7.9, y_hat: 10.5, loss: 6.76
#     x: 4.0, y: 9.1, y_hat: 11.8, loss: 7.29
#     x: 5.0, y: 10.9, y_hat: 14.4, loss: 12.25
#     Loss = 15.3552
#
# (w=2.6, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 4.7, loss: 1.49
#     x: 2.0, y: 5.0, y_hat: 6.8, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 10.7, loss: 7.84
#     x: 4.0, y: 9.1, y_hat: 12.0, loss: 8.41
#     x: 5.0, y: 10.9, y_hat: 14.6, loss: 13.69
#     Loss = 17.9392
#
# (w=2.6, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 4.4, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 4.9, loss: 2.02
#     x: 2.0, y: 5.0, y_hat: 7.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 10.9, loss: 9.00
#     x: 4.0, y: 9.1, y_hat: 12.2, loss: 9.61
#     x: 5.0, y: 10.9, y_hat: 14.8, loss: 15.21
#     Loss = 20.7632
#
# (w=2.6, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 4.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 5.1, loss: 2.62
#     x: 2.0, y: 5.0, y_hat: 7.2, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 11.1, loss: 10.24
#     x: 4.0, y: 9.1, y_hat: 12.4, loss: 10.89
#     x: 5.0, y: 10.9, y_hat: 15.0, loss: 16.81
#     Loss = 23.8272
#
# (w=2.8, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 2.8, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 3.4, loss: 0.02
#     x: 2.0, y: 5.0, y_hat: 5.6, loss: 0.36
#     x: 3.5, y: 7.9, y_hat: 9.8, loss: 3.61
#     x: 4.0, y: 9.1, y_hat: 11.2, loss: 4.41
#     x: 5.0, y: 10.9, y_hat: 14.0, loss: 9.61
#     Loss = 9.0498
#
# (w=2.8, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 3.0, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.6, loss: 0.00
#     x: 2.0, y: 5.0, y_hat: 5.8, loss: 0.64
#     x: 3.5, y: 7.9, y_hat: 10.0, loss: 4.41
#     x: 4.0, y: 9.1, y_hat: 11.4, loss: 5.29
#     x: 5.0, y: 10.9, y_hat: 14.2, loss: 10.89
#     Loss = 10.6218
#
# (w=2.8, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 3.2, loss: 0.01
#     x: 1.2, y: 3.5, y_hat: 3.8, loss: 0.07
#     x: 2.0, y: 5.0, y_hat: 6.0, loss: 1.00
#     x: 3.5, y: 7.9, y_hat: 10.2, loss: 5.29
#     x: 4.0, y: 9.1, y_hat: 11.6, loss: 6.25
#     x: 5.0, y: 10.9, y_hat: 14.4, loss: 12.25
#     Loss = 12.4338
#
# (w=2.8, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 4.0, loss: 0.21
#     x: 2.0, y: 5.0, y_hat: 6.2, loss: 1.44
#     x: 3.5, y: 7.9, y_hat: 10.4, loss: 6.25
#     x: 4.0, y: 9.1, y_hat: 11.8, loss: 7.29
#     x: 5.0, y: 10.9, y_hat: 14.6, loss: 13.69
#     Loss = 14.4858
#
# (w=2.8, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.2, loss: 0.44
#     x: 2.0, y: 5.0, y_hat: 6.4, loss: 1.96
#     x: 3.5, y: 7.9, y_hat: 10.6, loss: 7.29
#     x: 4.0, y: 9.1, y_hat: 12.0, loss: 8.41
#     x: 5.0, y: 10.9, y_hat: 14.8, loss: 15.21
#     Loss = 16.7778
#
# (w=2.8, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.4, loss: 0.74
#     x: 2.0, y: 5.0, y_hat: 6.6, loss: 2.56
#     x: 3.5, y: 7.9, y_hat: 10.8, loss: 8.41
#     x: 4.0, y: 9.1, y_hat: 12.2, loss: 9.61
#     x: 5.0, y: 10.9, y_hat: 15.0, loss: 16.81
#     Loss = 19.3098
#
# (w=2.8, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.6, loss: 1.12
#     x: 2.0, y: 5.0, y_hat: 6.8, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 11.0, loss: 9.61
#     x: 4.0, y: 9.1, y_hat: 12.4, loss: 10.89
#     x: 5.0, y: 10.9, y_hat: 15.2, loss: 18.49
#     Loss = 22.0818
#
# (w=2.8, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 4.8, loss: 1.59
#     x: 2.0, y: 5.0, y_hat: 7.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 11.2, loss: 10.89
#     x: 4.0, y: 9.1, y_hat: 12.6, loss: 12.25
#     x: 5.0, y: 10.9, y_hat: 15.4, loss: 20.25
#     Loss = 25.0938
#
# (w=2.8, b=1.6)
# ...
#
# (w=3.2, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.2, loss: 0.55
#     x: 2.0, y: 5.0, y_hat: 6.8, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 11.6, loss: 13.69
#     x: 4.0, y: 9.1, y_hat: 13.2, loss: 16.81
#     x: 5.0, y: 10.9, y_hat: 16.4, loss: 30.25
#     Loss = 32.3938
#
# (w=3.2, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.4, loss: 0.88
#     x: 2.0, y: 5.0, y_hat: 7.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 11.8, loss: 15.21
#     x: 4.0, y: 9.1, y_hat: 13.4, loss: 18.49
#     x: 5.0, y: 10.9, y_hat: 16.6, loss: 32.49
#     Loss = 35.7818
#
# (w=3.2, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.6, loss: 1.30
#     x: 2.0, y: 5.0, y_hat: 7.2, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 12.0, loss: 16.81
#     x: 4.0, y: 9.1, y_hat: 13.6, loss: 20.25
#     x: 5.0, y: 10.9, y_hat: 16.8, loss: 34.81
#     Loss = 39.4098
#
# (w=3.2, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 4.8, loss: 1.80
#     x: 2.0, y: 5.0, y_hat: 7.4, loss: 5.76
#     x: 3.5, y: 7.9, y_hat: 12.2, loss: 18.49
#     x: 4.0, y: 9.1, y_hat: 13.8, loss: 22.09
#     x: 5.0, y: 10.9, y_hat: 17.0, loss: 37.21
#     Loss = 43.2778
#
# (w=3.2, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 4.4, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 5.0, loss: 2.37
#     x: 2.0, y: 5.0, y_hat: 7.6, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 12.4, loss: 20.25
#     x: 4.0, y: 9.1, y_hat: 14.0, loss: 24.01
#     x: 5.0, y: 10.9, y_hat: 17.2, loss: 39.69
#     Loss = 47.3858
#
# (w=3.2, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 4.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 5.2, loss: 3.03
#     x: 2.0, y: 5.0, y_hat: 7.8, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 12.6, loss: 22.09
#     x: 4.0, y: 9.1, y_hat: 14.2, loss: 26.01
#     x: 5.0, y: 10.9, y_hat: 17.4, loss: 42.25
#     Loss = 51.7338
#
# (w=3.2, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 4.8, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 5.4, loss: 3.76
#     x: 2.0, y: 5.0, y_hat: 8.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 12.8, loss: 24.01
#     x: 4.0, y: 9.1, y_hat: 14.4, loss: 28.09
#     x: 5.0, y: 10.9, y_hat: 17.6, loss: 44.89
#     Loss = 56.3218
#
# (w=3.2, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 5.0, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 5.6, loss: 4.58
#     x: 2.0, y: 5.0, y_hat: 8.2, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 13.0, loss: 26.01
#     x: 4.0, y: 9.1, y_hat: 14.6, loss: 30.25
#     x: 5.0, y: 10.9, y_hat: 17.8, loss: 47.61
#     Loss = 61.1498
#
# (w=3.2, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 5.2, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 5.8, loss: 5.48
#     x: 2.0, y: 5.0, y_hat: 8.4, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 13.2, loss: 28.09
#     x: 4.0, y: 9.1, y_hat: 14.8, loss: 32.49
#     x: 5.0, y: 10.9, y_hat: 18.0, loss: 50.41
#     Loss = 66.2178
#
# (w=3.4, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 3.4, loss: 0.09
#     x: 1.2, y: 3.5, y_hat: 4.1, loss: 0.34
#     x: 2.0, y: 5.0, y_hat: 6.8, loss: 3.24
#     x: 3.5, y: 7.9, y_hat: 11.9, loss: 16.00
#     x: 4.0, y: 9.1, y_hat: 13.6, loss: 20.25
#     x: 5.0, y: 10.9, y_hat: 17.0, loss: 37.21
#     Loss = 38.5632
#
# (w=3.4, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.3, loss: 0.61
#     x: 2.0, y: 5.0, y_hat: 7.0, loss: 4.00
#     x: 3.5, y: 7.9, y_hat: 12.1, loss: 17.64
#     x: 4.0, y: 9.1, y_hat: 13.8, loss: 22.09
#     x: 5.0, y: 10.9, y_hat: 17.2, loss: 39.69
#     Loss = 42.1392
#
# (w=3.4, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.5, loss: 0.96
#     x: 2.0, y: 5.0, y_hat: 7.2, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 12.3, loss: 19.36
#     x: 4.0, y: 9.1, y_hat: 14.0, loss: 24.01
#     x: 5.0, y: 10.9, y_hat: 17.4, loss: 42.25
#     Loss = 45.9552
#
# (w=3.4, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.7, loss: 1.39
#     x: 2.0, y: 5.0, y_hat: 7.4, loss: 5.76
#     x: 3.5, y: 7.9, y_hat: 12.5, loss: 21.16
#     x: 4.0, y: 9.1, y_hat: 14.2, loss: 26.01
#     x: 5.0, y: 10.9, y_hat: 17.6, loss: 44.89
#     Loss = 50.0112
#
# (w=3.4, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 4.9, loss: 1.90
#     x: 2.0, y: 5.0, y_hat: 7.6, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 12.7, loss: 23.04
#     x: 4.0, y: 9.1, y_hat: 14.4, loss: 28.09
#     x: 5.0, y: 10.9, y_hat: 17.8, loss: 47.61
#     Loss = 54.3072
#
# (w=3.4, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 4.4, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 5.1, loss: 2.50
#     x: 2.0, y: 5.0, y_hat: 7.8, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 12.9, loss: 25.00
#     x: 4.0, y: 9.1, y_hat: 14.6, loss: 30.25
#     x: 5.0, y: 10.9, y_hat: 18.0, loss: 50.41
#     Loss = 58.8432
#
# (w=3.4, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 4.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 5.3, loss: 3.17
#     x: 2.0, y: 5.0, y_hat: 8.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 13.1, loss: 27.04
#     x: 4.0, y: 9.1, y_hat: 14.8, loss: 32.49
#     x: 5.0, y: 10.9, y_hat: 18.2, loss: 53.29
#     Loss = 63.6192
#
# (w=3.4, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 4.8, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 5.5, loss: 3.92
#     x: 2.0, y: 5.0, y_hat: 8.2, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 13.3, loss: 29.16
#     x: 4.0, y: 9.1, y_hat: 15.0, loss: 34.81
#     x: 5.0, y: 10.9, y_hat: 18.4, loss: 56.25
#     Loss = 68.6352
#
# (w=3.4, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 5.0, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 5.7, loss: 4.75
#     x: 2.0, y: 5.0, y_hat: 8.4, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 13.5, loss: 31.36
#     x: 4.0, y: 9.1, y_hat: 15.2, loss: 37.21
#     x: 5.0, y: 10.9, y_hat: 18.6, loss: 59.29
#     Loss = 73.8912
#
# (w=3.4, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 5.2, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 5.9, loss: 5.66
#     x: 2.0, y: 5.0, y_hat: 8.6, loss: 12.96
#     x: 3.5, y: 7.9, y_hat: 13.7, loss: 33.64
#     x: 4.0, y: 9.1, y_hat: 15.4, loss: 39.69
#     x: 5.0, y: 10.9, y_hat: 18.8, loss: 62.41
#     Loss = 79.3872
#
# (w=3.4, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 5.4, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 6.1, loss: 6.66
#     x: 2.0, y: 5.0, y_hat: 8.8, loss: 14.44
#     x: 3.5, y: 7.9, y_hat: 13.9, loss: 36.00
#     x: 4.0, y: 9.1, y_hat: 15.6, loss: 42.25
#     x: 5.0, y: 10.9, y_hat: 19.0, loss: 65.61
#     Loss = 85.1232
#
# (w=3.6, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 3.6, loss: 0.25
#     x: 1.2, y: 3.5, y_hat: 4.3, loss: 0.67
#     x: 2.0, y: 5.0, y_hat: 7.2, loss: 4.84
#     x: 3.5, y: 7.9, y_hat: 12.6, loss: 22.09
#     x: 4.0, y: 9.1, y_hat: 14.4, loss: 28.09
#     x: 5.0, y: 10.9, y_hat: 18.0, loss: 50.41
#     Loss = 53.1762
#
# (w=3.6, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.5, loss: 1.04
#     x: 2.0, y: 5.0, y_hat: 7.4, loss: 5.76
#     x: 3.5, y: 7.9, y_hat: 12.8, loss: 24.01
#     x: 4.0, y: 9.1, y_hat: 14.6, loss: 30.25
#     x: 5.0, y: 10.9, y_hat: 18.2, loss: 53.29
#     Loss = 57.4202
#
# (w=3.6, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.7, loss: 1.49
#     x: 2.0, y: 5.0, y_hat: 7.6, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 13.0, loss: 26.01
#     x: 4.0, y: 9.1, y_hat: 14.8, loss: 32.49
#     x: 5.0, y: 10.9, y_hat: 18.4, loss: 56.25
#     Loss = 61.9042
#
# (w=3.6, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 4.9, loss: 2.02
#     x: 2.0, y: 5.0, y_hat: 7.8, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 13.2, loss: 28.09
#     x: 4.0, y: 9.1, y_hat: 15.0, loss: 34.81
#     x: 5.0, y: 10.9, y_hat: 18.6, loss: 59.29
#     Loss = 66.6282
#
# (w=3.6, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 4.4, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 5.1, loss: 2.62
#     x: 2.0, y: 5.0, y_hat: 8.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 13.4, loss: 30.25
#     x: 4.0, y: 9.1, y_hat: 15.2, loss: 37.21
#     x: 5.0, y: 10.9, y_hat: 18.8, loss: 62.41
#     Loss = 71.5922
#
# (w=3.6, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 4.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 5.3, loss: 3.31
#     x: 2.0, y: 5.0, y_hat: 8.2, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 13.6, loss: 32.49
#     x: 4.0, y: 9.1, y_hat: 15.4, loss: 39.69
#     x: 5.0, y: 10.9, y_hat: 19.0, loss: 65.61
#     Loss = 76.7962
#
# (w=3.6, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 4.8, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 5.5, loss: 4.08
#     x: 2.0, y: 5.0, y_hat: 8.4, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 13.8, loss: 34.81
#     x: 4.0, y: 9.1, y_hat: 15.6, loss: 42.25
#     x: 5.0, y: 10.9, y_hat: 19.2, loss: 68.89
#     Loss = 82.2402
#
# (w=3.6, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 5.0, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 5.7, loss: 4.93
#     x: 2.0, y: 5.0, y_hat: 8.6, loss: 12.96
#     x: 3.5, y: 7.9, y_hat: 14.0, loss: 37.21
#     x: 4.0, y: 9.1, y_hat: 15.8, loss: 44.89
#     x: 5.0, y: 10.9, y_hat: 19.4, loss: 72.25
#     Loss = 87.9242
#
# (w=3.6, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 5.2, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 5.9, loss: 5.86
#     x: 2.0, y: 5.0, y_hat: 8.8, loss: 14.44
#     x: 3.5, y: 7.9, y_hat: 14.2, loss: 39.69
#     x: 4.0, y: 9.1, y_hat: 16.0, loss: 47.61
#     x: 5.0, y: 10.9, y_hat: 19.6, loss: 75.69
#     Loss = 93.8482
#
# (w=3.6, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 5.4, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 6.1, loss: 6.86
#     x: 2.0, y: 5.0, y_hat: 9.0, loss: 16.00
#     x: 3.5, y: 7.9, y_hat: 14.4, loss: 42.25
#     x: 4.0, y: 9.1, y_hat: 16.2, loss: 50.41
#     x: 5.0, y: 10.9, y_hat: 19.8, loss: 79.21
#     Loss = 100.0122
#
# (w=3.6, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 5.6, loss: 6.25
#     x: 1.2, y: 3.5, y_hat: 6.3, loss: 7.95
#     x: 2.0, y: 5.0, y_hat: 9.2, loss: 17.64
#     x: 3.5, y: 7.9, y_hat: 14.6, loss: 44.89
#     x: 4.0, y: 9.1, y_hat: 16.4, loss: 53.29
#     x: 5.0, y: 10.9, y_hat: 20.0, loss: 82.81
#     Loss = 106.4162
#
# (w=3.8, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 3.8, loss: 0.49
#     x: 1.2, y: 3.5, y_hat: 4.6, loss: 1.12
#     x: 2.0, y: 5.0, y_hat: 7.6, loss: 6.76
#     x: 3.5, y: 7.9, y_hat: 13.3, loss: 29.16
#     x: 4.0, y: 9.1, y_hat: 15.2, loss: 37.21
#     x: 5.0, y: 10.9, y_hat: 19.0, loss: 65.61
#     Loss = 70.1768
#
# (w=3.8, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.8, loss: 1.59
#     x: 2.0, y: 5.0, y_hat: 7.8, loss: 7.84
#     x: 3.5, y: 7.9, y_hat: 13.5, loss: 31.36
#     x: 4.0, y: 9.1, y_hat: 15.4, loss: 39.69
#     x: 5.0, y: 10.9, y_hat: 19.2, loss: 68.89
#     Loss = 75.0888
#
# (w=3.8, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 5.0, loss: 2.13
#     x: 2.0, y: 5.0, y_hat: 8.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 13.7, loss: 33.64
#     x: 4.0, y: 9.1, y_hat: 15.6, loss: 42.25
#     x: 5.0, y: 10.9, y_hat: 19.4, loss: 72.25
#     Loss = 80.2408
#
# (w=3.8, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 4.4, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 5.2, loss: 2.76
#     x: 2.0, y: 5.0, y_hat: 8.2, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 13.9, loss: 36.00
#     x: 4.0, y: 9.1, y_hat: 15.8, loss: 44.89
#     x: 5.0, y: 10.9, y_hat: 19.6, loss: 75.69
#     Loss = 85.6328
#
# (w=3.8, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 4.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 5.4, loss: 3.46
#     x: 2.0, y: 5.0, y_hat: 8.4, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 14.1, loss: 38.44
#     x: 4.0, y: 9.1, y_hat: 16.0, loss: 47.61
#     x: 5.0, y: 10.9, y_hat: 19.8, loss: 79.21
#     Loss = 91.2648
#
# (w=3.8, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 4.8, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 5.6, loss: 4.24
#     x: 2.0, y: 5.0, y_hat: 8.6, loss: 12.96
#     x: 3.5, y: 7.9, y_hat: 14.3, loss: 40.96
#     x: 4.0, y: 9.1, y_hat: 16.2, loss: 50.41
#     x: 5.0, y: 10.9, y_hat: 20.0, loss: 82.81
#     Loss = 97.1368
#
# (w=3.8, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 5.0, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 5.8, loss: 5.11
#     x: 2.0, y: 5.0, y_hat: 8.8, loss: 14.44
#     x: 3.5, y: 7.9, y_hat: 14.5, loss: 43.56
#     x: 4.0, y: 9.1, y_hat: 16.4, loss: 53.29
#     x: 5.0, y: 10.9, y_hat: 20.2, loss: 86.49
#     Loss = 103.2488
#
# (w=3.8, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 5.2, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 6.0, loss: 6.05
#     x: 2.0, y: 5.0, y_hat: 9.0, loss: 16.00
#     x: 3.5, y: 7.9, y_hat: 14.7, loss: 46.24
#     x: 4.0, y: 9.1, y_hat: 16.6, loss: 56.25
#     x: 5.0, y: 10.9, y_hat: 20.4, loss: 90.25
#     Loss = 109.6008
#
# (w=3.8, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 5.4, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 6.2, loss: 7.08
#     x: 2.0, y: 5.0, y_hat: 9.2, loss: 17.64
#     x: 3.5, y: 7.9, y_hat: 14.9, loss: 49.00
#     x: 4.0, y: 9.1, y_hat: 16.8, loss: 59.29
#     x: 5.0, y: 10.9, y_hat: 20.6, loss: 94.09
#     Loss = 116.1928
#
# (w=3.8, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 5.6, loss: 6.25
#     x: 1.2, y: 3.5, y_hat: 6.4, loss: 8.18
#     x: 2.0, y: 5.0, y_hat: 9.4, loss: 19.36
#     x: 3.5, y: 7.9, y_hat: 15.1, loss: 51.84
#     x: 4.0, y: 9.1, y_hat: 17.0, loss: 62.41
#     x: 5.0, y: 10.9, y_hat: 20.8, loss: 98.01
#     Loss = 123.0248
#
# (w=3.8, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 5.8, loss: 7.29
#     x: 1.2, y: 3.5, y_hat: 6.6, loss: 9.36
#     x: 2.0, y: 5.0, y_hat: 9.6, loss: 21.16
#     x: 3.5, y: 7.9, y_hat: 15.3, loss: 54.76
#     x: 4.0, y: 9.1, y_hat: 17.2, loss: 65.61
#     x: 5.0, y: 10.9, y_hat: 21.0, loss: 102.01
#     Loss = 130.0968
#
# (w=4.0, b=0.0)
#     x: 1.0, y: 3.1, y_hat: 4.0, loss: 0.81
#     x: 1.2, y: 3.5, y_hat: 4.8, loss: 1.69
#     x: 2.0, y: 5.0, y_hat: 8.0, loss: 9.00
#     x: 3.5, y: 7.9, y_hat: 14.0, loss: 37.21
#     x: 4.0, y: 9.1, y_hat: 16.0, loss: 47.61
#     x: 5.0, y: 10.9, y_hat: 20.0, loss: 82.81
#     Loss = 89.5650
#
# (w=4.0, b=0.2)
#     x: 1.0, y: 3.1, y_hat: 4.2, loss: 1.21
#     x: 1.2, y: 3.5, y_hat: 5.0, loss: 2.25
#     x: 2.0, y: 5.0, y_hat: 8.2, loss: 10.24
#     x: 3.5, y: 7.9, y_hat: 14.2, loss: 39.69
#     x: 4.0, y: 9.1, y_hat: 16.2, loss: 50.41
#     x: 5.0, y: 10.9, y_hat: 20.2, loss: 86.49
#     Loss = 95.1450
#
# (w=4.0, b=0.4)
#     x: 1.0, y: 3.1, y_hat: 4.4, loss: 1.69
#     x: 1.2, y: 3.5, y_hat: 5.2, loss: 2.89
#     x: 2.0, y: 5.0, y_hat: 8.4, loss: 11.56
#     x: 3.5, y: 7.9, y_hat: 14.4, loss: 42.25
#     x: 4.0, y: 9.1, y_hat: 16.4, loss: 53.29
#     x: 5.0, y: 10.9, y_hat: 20.4, loss: 90.25
#     Loss = 100.9650
#
# (w=4.0, b=0.6)
#     x: 1.0, y: 3.1, y_hat: 4.6, loss: 2.25
#     x: 1.2, y: 3.5, y_hat: 5.4, loss: 3.61
#     x: 2.0, y: 5.0, y_hat: 8.6, loss: 12.96
#     x: 3.5, y: 7.9, y_hat: 14.6, loss: 44.89
#     x: 4.0, y: 9.1, y_hat: 16.6, loss: 56.25
#     x: 5.0, y: 10.9, y_hat: 20.6, loss: 94.09
#     Loss = 107.0250
#
# (w=4.0, b=0.8)
#     x: 1.0, y: 3.1, y_hat: 4.8, loss: 2.89
#     x: 1.2, y: 3.5, y_hat: 5.6, loss: 4.41
#     x: 2.0, y: 5.0, y_hat: 8.8, loss: 14.44
#     x: 3.5, y: 7.9, y_hat: 14.8, loss: 47.61
#     x: 4.0, y: 9.1, y_hat: 16.8, loss: 59.29
#     x: 5.0, y: 10.9, y_hat: 20.8, loss: 98.01
#     Loss = 113.3250
#
# (w=4.0, b=1.0)
#     x: 1.0, y: 3.1, y_hat: 5.0, loss: 3.61
#     x: 1.2, y: 3.5, y_hat: 5.8, loss: 5.29
#     x: 2.0, y: 5.0, y_hat: 9.0, loss: 16.00
#     x: 3.5, y: 7.9, y_hat: 15.0, loss: 50.41
#     x: 4.0, y: 9.1, y_hat: 17.0, loss: 62.41
#     x: 5.0, y: 10.9, y_hat: 21.0, loss: 102.01
#     Loss = 119.8650
#
# (w=4.0, b=1.2)
#     x: 1.0, y: 3.1, y_hat: 5.2, loss: 4.41
#     x: 1.2, y: 3.5, y_hat: 6.0, loss: 6.25
#     x: 2.0, y: 5.0, y_hat: 9.2, loss: 17.64
#     x: 3.5, y: 7.9, y_hat: 15.2, loss: 53.29
#     x: 4.0, y: 9.1, y_hat: 17.2, loss: 65.61
#     x: 5.0, y: 10.9, y_hat: 21.2, loss: 106.09
#     Loss = 126.6450
#
# (w=4.0, b=1.4)
#     x: 1.0, y: 3.1, y_hat: 5.4, loss: 5.29
#     x: 1.2, y: 3.5, y_hat: 6.2, loss: 7.29
#     x: 2.0, y: 5.0, y_hat: 9.4, loss: 19.36
#     x: 3.5, y: 7.9, y_hat: 15.4, loss: 56.25
#     x: 4.0, y: 9.1, y_hat: 17.4, loss: 68.89
#     x: 5.0, y: 10.9, y_hat: 21.4, loss: 110.25
#     Loss = 133.6650
#
# (w=4.0, b=1.6)
#     x: 1.0, y: 3.1, y_hat: 5.6, loss: 6.25
#     x: 1.2, y: 3.5, y_hat: 6.4, loss: 8.41
#     x: 2.0, y: 5.0, y_hat: 9.6, loss: 21.16
#     x: 3.5, y: 7.9, y_hat: 15.6, loss: 59.29
#     x: 4.0, y: 9.1, y_hat: 17.6, loss: 72.25
#     x: 5.0, y: 10.9, y_hat: 21.6, loss: 114.49
#     Loss = 140.9250
#
# (w=4.0, b=1.8)
#     x: 1.0, y: 3.1, y_hat: 5.8, loss: 7.29
#     x: 1.2, y: 3.5, y_hat: 6.6, loss: 9.61
#     x: 2.0, y: 5.0, y_hat: 9.8, loss: 23.04
#     x: 3.5, y: 7.9, y_hat: 15.8, loss: 62.41
#     x: 4.0, y: 9.1, y_hat: 17.8, loss: 75.69
#     x: 5.0, y: 10.9, y_hat: 21.8, loss: 118.81
#     Loss = 148.4250
#
# (w=4.0, b=2.0)
#     x: 1.0, y: 3.1, y_hat: 6.0, loss: 8.41
#     x: 1.2, y: 3.5, y_hat: 6.8, loss: 10.89
#     x: 2.0, y: 5.0, y_hat: 10.0, loss: 25.00
#     x: 3.5, y: 7.9, y_hat: 16.0, loss: 65.61
#     x: 4.0, y: 9.1, y_hat: 18.0, loss: 79.21
#     x: 5.0, y: 10.9, y_hat: 22.0, loss: 123.21
#     Loss = 156.1650
#
# BEST:
# w=2.0, b=1.0, loss=0.0250

# %% [markdown]
# Plotting the loss values as a surface graph gives you a picture of the "optimisation landscape" for the parameter values. The loss is minimum at $w=2$, $b=1$ (it might be hard to see this clearly from the 3D diagram, but you can trust the numbers).

# %%
fig = plt.figure()

# enable 3D
ax = fig.add_subplot(projection='3d')

 # generate combinations of weights and biases
(w_list, b_list) = np.meshgrid(weights, biases)

# plot loss across weights and bias values
surf = ax.plot_surface(w_list.T, b_list.T, loss_matrix,
                       linewidth=0, antialiased=False)

ax.set_xlabel('w')
ax.set_ylabel('b')
ax.set_zlabel('Loss')
plt.show()

# %% [markdown]
# ### Optimisation with derivatives
#
# Obviously, the brute force search method above is really computationally expensive (very slow!), especially when there are more parameters and more values to search. A more efficient approach is to start from a random set of parameter values, and then try to "move down" the loss graph to the point with a minimum loss. So, in the plot above, you can start at some random $w$ and $b$, and try to move towards the minimum point.
#
# The problem is: from where you are, you actually do not know where the minimum point is. You only know that there *is* a minimum point. The question is: how do you know towards which direction you should move (and how far) so that you can get to the minimum point as fast as possible? The answer is downwards (obviously!) and where the slope is steepest.
#
# Fortunately, calculus saves us from guessing, and provides us a way to compute the direction of the slope at any point. This is called the *derivative* (or gradient). Intuitively, the derivative $\frac{\partial L}{\partial w}$ tells us by how much $L$ changes when $w$ changes. Similarly, $\frac{\partial L}{\partial b}$ tells us by how much $L$ changes when $b$ changes. So if we move in these directions, we hope that we can ultimately reach a minimum point.
#
# If you are well-versed with calculus, you can compute $\frac{\partial L}{\partial w}$ and $\frac{\partial L}{\partial b}$ by hand. Otherwise, you can get help from a derivative calculator (e.g. https://www.derivative-calculator.net)
#
# As presented in the lectures, the partial derivatives of the loss function with respect to $w$ and to $b$ are:
#
# $\frac{\partial L}{\partial w} = \sum_{i=1}^{N} \left(\hat{y}^{(i)} - y^{(i)}\right)x^{(i)}$
#
# $\frac{\partial L}{\partial b} = \sum_{i=1}^{N} \left(\hat{y}^{(i)} - y^{(i)}\right)$
#
# Thus, for a *single* point, the partial derivatives are:
#
# $\frac{\partial L^{(i)}}{\partial w} = \left(\hat{y}^{(i)} - y^{(i)}\right)x^{(i)}$
#
# $\frac{\partial L^{(i)}}{\partial b} = \left(\hat{y}^{(i)} - y^{(i)}\right)$
#
# Now, complete the `gradient()` method for `SimpleLinearRegression` below to compute the partial derivatives wrt $w$ and $b$ at a given point. To make life easier, just compute and return both $\frac{\partial L^{(i)}}{\partial w}$ and $\frac{\partial L^{(i)}}{\partial b}$ at the same time.

# %%
def gradient(self, x, y):
    """ Compute partial derivatives wrt w and b

    Args:
        x (float): input instance
        y (float): ground truth output

    Returns:
        tuple: (float, float)
            - the first element will be dL/dw
            - the second element will be dL/db
    """
    # TODO: Complete this

    return x * (self.forward(x) - y), self.forward(x) - y


# A quick hack to bind this function as the SimpleLinearRegression.gradient() method
SimpleLinearRegression.gradient = gradient


## Quick test: This should return (6.0, 3.0)
model = SimpleLinearRegression()
model.w = 3
model.b = 2
x = 2.0
y = 5.0
(dLdw, dLdb) = model.gradient(x, y)
print(dLdw) # should print 6.0
print(dLdb) # should print 3.0
# Out:
# 6.0
# 3.0

# %% [markdown]
# So, in this example, $\frac{\partial L}{\partial w}=6.0$ suggests that when $w$ increases by a very tiny amount, $L$ will increase by 6.0 times that amount.

# %% [markdown]
# #### Gradient descent
#
# Now that we have our gradients, let us try to optimise the parameters $w$ and $b$ of our model to minimise the loss. We will use the gradient descent algorithm for this, as discussed in the lectures.
#
# You may reimplement the code provided in the lectures, replacing some of the code by reusing the `forward()`, `loss()` and `gradient()` methods of `SimpleLinearRegression` that you implemented earlier. This will help make your code more modular and readable, and help to improve your understanding of gradient descent at a more abstract level.
#
# You should be able to obtain $w \approx 2$ and $b \approx 1$ by the end of training if you have implemented everything correctly. Also experiment with the learning rate and the number of epochs and observe the effects.

# %%
model = SimpleLinearRegression()

learning_rate = 0.01
n_epochs = 100

for epoch in range(n_epochs):
    error = 0.0
    grad_w = 0.0
    grad_b = 0.0
    for (x, y) in zip(x_train, y_train):
        ### TODO: Complete this
        ### 1. Compute the gradients for w and b for this example
        grad_w_cur, grad_b_cur = model.gradient(x, y)

        ### 2. Add the gradients to grad_w and grad_b
        grad_w += grad_w_cur
        grad_b += grad_b_cur

        ### 3. Add the "local" loss to the global error (Loss) for analysis
        error = model.loss(x, y)

    # TODO: Update the weights using the (summed) gradients
    model.w -= learning_rate * grad_w
    model.b -= learning_rate * grad_b

    print(f"Epoch: {epoch}\t w: {model.w:.2f}\t b: {model.b:.2f}\t L: {error:.4f}")
# Out:
# Epoch: 0	 w: 0.60	 b: 0.71	 L: 413.1134
# Epoch: 1	 w: 1.48	 b: 0.96	 L: 51.7967
# Epoch: 2	 w: 1.79	 b: 1.05	 L: 6.4079
# Epoch: 3	 w: 1.91	 b: 1.08	 L: 0.7627
# Epoch: 4	 w: 1.95	 b: 1.10	 L: 0.0807
# Epoch: 5	 w: 1.96	 b: 1.10	 L: 0.0056
# Epoch: 6	 w: 1.96	 b: 1.10	 L: 0.0000
# Epoch: 7	 w: 1.97	 b: 1.10	 L: 0.0007
# Epoch: 8	 w: 1.97	 b: 1.10	 L: 0.0012
# Epoch: 9	 w: 1.97	 b: 1.10	 L: 0.0015
# Epoch: 10	 w: 1.97	 b: 1.10	 L: 0.0016
# Epoch: 11	 w: 1.97	 b: 1.10	 L: 0.0016
# Epoch: 12	 w: 1.97	 b: 1.10	 L: 0.0016
# Epoch: 13	 w: 1.97	 b: 1.10	 L: 0.0016
# Epoch: 14	 w: 1.97	 b: 1.10	 L: 0.0016
# Epoch: 15	 w: 1.97	 b: 1.10	 L: 0.0016
# Epoch: 16	 w: 1.97	 b: 1.11	 L: 0.0016
# Epoch: 17	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 18	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 19	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 20	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 21	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 22	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 23	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 24	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 25	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 26	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 27	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 28	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 29	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 30	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 31	 w: 1.97	 b: 1.11	 L: 0.0015
# Epoch: 32	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 33	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 34	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 35	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 36	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 37	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 38	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 39	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 40	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 41	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 42	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 43	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 44	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 45	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 46	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 47	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 48	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 49	 w: 1.97	 b: 1.11	 L: 0.0014
# Epoch: 50	 w: 1.97	 b: 1.11	 L: 0.0013
# Epoch: 51	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 52	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 53	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 54	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 55	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 56	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 57	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 58	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 59	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 60	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 61	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 62	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 63	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 64	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 65	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 66	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 67	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 68	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 69	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 70	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 71	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 72	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 73	 w: 1.96	 b: 1.11	 L: 0.0013
# Epoch: 74	 w: 1.96	 b: 1.11	 L: 0.0012
# Epoch: 75	 w: 1.96	 b: 1.11	 L: 0.0012
# Epoch: 76	 w: 1.96	 b: 1.11	 L: 0.0012
# Epoch: 77	 w: 1.96	 b: 1.11	 L: 0.0012
# Epoch: 78	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 79	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 80	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 81	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 82	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 83	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 84	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 85	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 86	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 87	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 88	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 89	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 90	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 91	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 92	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 93	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 94	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 95	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 96	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 97	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 98	 w: 1.96	 b: 1.12	 L: 0.0012
# Epoch: 99	 w: 1.96	 b: 1.12	 L: 0.0012

# %% [markdown]
# ### Predictions
#
# Now that your model is trained, you can use it to predict some unknown test instances. Complete the code below to predict the output of the test set.

# %%
y_predictions = np.zeros((len(y_test),))
for (i, x) in enumerate(x_test):
    # TODO: Complete this
    y_predictions[i] = model.forward(x)

print(y_predictions)
# Out:
# [6.02565576 7.00736986 9.95251216]

# %% [markdown]
# ### Evaluation
#
# Finally, let us evaluate the linear regression model you developed. Unlike classification, we will need a different metric for regression. Recall from Lecture 3, a common evaluation metric for regression is the Mean Squared Error (MSE). We will use that for this tutorial.
#
# Complete the `mse()` function below to compute the MSE.

# %%
def mse(y_gold, y_prediction):
    """ Compute the MSE given the ground truth and predictions

    Args:
        y_gold (np.ndarray): the correct ground truth values of y
        y_prediction (np.ndarray): the predicted values of y

    Returns:
        float : MSE
    """

    assert len(y_gold) == len(y_prediction)

    # TODO: Complete this
    return np.mean((y_gold - y_prediction) ** 2)


# Compute the MSE on model predictions on our toy test data
# You should be able to obtain a very small MSE rate
print(mse(y_test, y_predictions))
# Out:
# 0.007488398568227455

# %% [markdown]
# ## Iris Dataset (Extra exercise)
#
# Here is an extra optional exercise for you: try to get your simple linear regression model working on a (slightly) larger and noisier dataset.
#
# For this, we will convert the Iris dataset to use as a regression task. More specifically, our task is to predict the *petal width* of a flower (`y`) given the *sepal length* as input (`x`). The code below will give you the dataset in this format.

# %%
import os

# Download iris data if it does not exist
if not os.path.exists("iris.data"):
    # !wget -O iris.data https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

def read_dataset_as_regression(filepath):
    """ Read in the dataset from the specified filepath

    Args:
        filepath (str): The filepath to the dataset file

    Returns:
        tuple: returns a tuple of (x, y), each being a numpy array.
               - x is a numpy array with shape (N, ),
                   where N is the number of instances
               - y is a numpy array with shape (N, ), where each element is a
                real-valued float, and N is the number of instances
    """

    x = []
    y = []
    for line in open(filepath):
        if line.strip() != "": # handle empty rows in file
            row = line.strip().split(",")
            # extract columns 0 as x.
            x.append(float(row[0]))

            # extract column 3 as y
            y.append(float(row[3]))

    return (np.array(x), np.array(y))


def split_dataset(x, y, test_proportion, random_generator=default_rng()):
    """ Split dataset into training and test sets, according to the given
        test set proportion.

    Args:
        x (np.ndarray): Instances, numpy array with shape (N,K)
        y (np.ndarray): Output label, numpy array with shape (N,)
        test_proprotion (float): the desired proportion of test examples
                                 (0.0-1.0)
        random_generator (np.random.Generator): A random generator

    Returns:
        tuple: returns a tuple of (x_train, x_test, y_train, y_test)
               - x_train (np.ndarray): Training instances shape (N_train, K)
               - x_test (np.ndarray): Test instances shape (N_test, K)
               - y_train (np.ndarray): Training labels, shape (N_train, )
               - y_test (np.ndarray): Test labels, shape (N_test, )
    """

    shuffled_indices = random_generator.permutation(len(x))
    n_test = round(len(x) * test_proportion)
    n_train = len(x) - n_test
    x_train = x[shuffled_indices[:n_train]]
    y_train = y[shuffled_indices[:n_train]]
    x_test = x[shuffled_indices[n_train:]]
    y_test = y[shuffled_indices[n_train:]]
    return (x_train, x_test, y_train, y_test)


(x, y) = read_dataset_as_regression("iris.data")
print(x.shape)  # (150,)
print(y.shape)  # (150,)

seed = 60012
rg = default_rng(seed)
x_train, x_test, y_train, y_test = split_dataset(x, y,
                                                 test_proportion=0.2,
                                                 random_generator=rg)
print(x_train.shape)
print(x_test.shape)
# Out:
# (150,)
# (150,)
# (120,)
# (30,)

# %% [markdown]
# As usual, it's always a good idea to examine your data before you start:

# %%
plt.figure()
plt.scatter(x_train, y_train, c="blue", edgecolor='k')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ### Model
#
# You can copy your `SimpleLinearRegression` class from earlier, with the`forward()`, `loss()` and `gradient()` methods that you implemented earlier. This time you can put them all together in the same place.

# %%
class SimpleLinearRegression:
    def __init__(self, random_generator=default_rng()):
        self.w = random_generator.standard_normal()
        self.b = 0

    def forward(self, x):
        return self.w * x + self.b

    def loss(self, x, y):
        return (self.forward(x) - y) ** 2

    def gradient(self, x, y):
        return x * (self.forward(x) - y), self.forward(x) - y

# %% [markdown]
# ### Optimisation
#
# Again, you should not need to change much of your gradient descent implementation from earlier, so just copy it over. You may, however, need to tweak the learning rate and the number of epochs to obtain a reasonable output.

# %%
model = SimpleLinearRegression()

learning_rate = 0.0001
n_epochs = 10000

for epoch in range(n_epochs):
    error = 0.0
    grad_w = 0.0
    grad_b = 0.0
    for (x, y) in zip(x_train, y_train):
        ### TODO: Complete this
        ### 1. Compute the gradients for w and b for this example
        grad_w_cur, grad_b_cur = model.gradient(x, y)

        ### 2. Add the gradients to grad_w and grad_b
        grad_w = grad_w + grad_w_cur
        grad_b = grad_b + grad_b_cur

        ### 3. Add the "local" loss to the global error (Loss) for analysis
        error = error + model.loss(x, y)

    # TODO: Update the weights using the (summed) gradients
    model.w = model.w - learning_rate * grad_w
    model.b = model.b - learning_rate * grad_b

    print(f"Epoch: {epoch}\t w: {model.w:.2f}\t b: {model.b:.2f}\t L: {error:.4f}")
# Out:
# Epoch: 0	 w: -0.28	 b: 0.06	 L: 3126.1479
# Epoch: 1	 w: -0.08	 b: 0.09	 L: 1043.9086
# Epoch: 2	 w: 0.04	 b: 0.11	 L: 370.3915
# Epoch: 3	 w: 0.11	 b: 0.12	 L: 152.5318
# Epoch: 4	 w: 0.14	 b: 0.13	 L: 82.0567
# Epoch: 5	 w: 0.17	 b: 0.13	 L: 59.2537
# Epoch: 6	 w: 0.18	 b: 0.13	 L: 51.8705
# Epoch: 7	 w: 0.18	 b: 0.13	 L: 49.4749
# Epoch: 8	 w: 0.19	 b: 0.13	 L: 48.6926
# Epoch: 9	 w: 0.19	 b: 0.13	 L: 48.4321
# Epoch: 10	 w: 0.19	 b: 0.13	 L: 48.3404
# Epoch: 11	 w: 0.19	 b: 0.13	 L: 48.3033
# Epoch: 12	 w: 0.19	 b: 0.13	 L: 48.2838
# Epoch: 13	 w: 0.19	 b: 0.13	 L: 48.2701
# Epoch: 14	 w: 0.19	 b: 0.13	 L: 48.2582
# Epoch: 15	 w: 0.19	 b: 0.13	 L: 48.2469
# Epoch: 16	 w: 0.19	 b: 0.13	 L: 48.2358
# Epoch: 17	 w: 0.20	 b: 0.13	 L: 48.2248
# Epoch: 18	 w: 0.20	 b: 0.13	 L: 48.2138
# Epoch: 19	 w: 0.20	 b: 0.13	 L: 48.2028
# Epoch: 20	 w: 0.20	 b: 0.12	 L: 48.1919
# Epoch: 21	 w: 0.20	 b: 0.12	 L: 48.1809
# Epoch: 22	 w: 0.20	 b: 0.12	 L: 48.1699
# Epoch: 23	 w: 0.20	 b: 0.12	 L: 48.1590
# Epoch: 24	 w: 0.20	 b: 0.12	 L: 48.1480
# Epoch: 25	 w: 0.20	 b: 0.12	 L: 48.1371
# Epoch: 26	 w: 0.20	 b: 0.12	 L: 48.1261
# Epoch: 27	 w: 0.20	 b: 0.12	 L: 48.1152
# Epoch: 28	 w: 0.20	 b: 0.12	 L: 48.1043
# Epoch: 29	 w: 0.20	 b: 0.12	 L: 48.0933
# Epoch: 30	 w: 0.20	 b: 0.12	 L: 48.0824
# Epoch: 31	 w: 0.20	 b: 0.12	 L: 48.0715
# Epoch: 32	 w: 0.20	 b: 0.12	 L: 48.0606
# Epoch: 33	 w: 0.20	 b: 0.11	 L: 48.0497
# Epoch: 34	 w: 0.20	 b: 0.11	 L: 48.0388
# Epoch: 35	 w: 0.20	 b: 0.11	 L: 48.0279
# Epoch: 36	 w: 0.20	 b: 0.11	 L: 48.0170
# Epoch: 37	 w: 0.20	 b: 0.11	 L: 48.0061
# Epoch: 38	 w: 0.20	 b: 0.11	 L: 47.9952
# Epoch: 39	 w: 0.20	 b: 0.11	 L: 47.9843
# Epoch: 40	 w: 0.20	 b: 0.11	 L: 47.9734
# Epoch: 41	 w: 0.20	 b: 0.11	 L: 47.9626
# Epoch: 42	 w: 0.20	 b: 0.11	 L: 47.9517
# Epoch: 43	 w: 0.20	 b: 0.11	 L: 47.9408
# Epoch: 44	 w: 0.20	 b: 0.11	 L: 47.9300
# Epoch: 45	 w: 0.20	 b: 0.11	 L: 47.9191
# Epoch: 46	 w: 0.20	 b: 0.11	 L: 47.9083
# Epoch: 47	 w: 0.20	 b: 0.10	 L: 47.8974
# Epoch: 48	 w: 0.20	 b: 0.10	 L: 47.8866
# Epoch: 49	 w: 0.20	 b: 0.10	 L: 47.8758
# Epoch: 50	 w: 0.20	 b: 0.10	 L: 47.8649
# Epoch: 51	 w: 0.20	 b: 0.10	 L: 47.8541
# Epoch: 52	 w: 0.20	 b: 0.10	 L: 47.8433
# Epoch: 53	 w: 0.20	 b: 0.10	 L: 47.8325
# Epoch: 54	 w: 0.20	 b: 0.10	 L: 47.8216
# Epoch: 55	 w: 0.20	 b: 0.10	 L: 47.8108
# Epoch: 56	 w: 0.20	 b: 0.10	 L: 47.8000
# Epoch: 57	 w: 0.20	 b: 0.10	 L: 47.7892
# Epoch: 58	 w: 0.20	 b: 0.10	 L: 47.7784
# Epoch: 59	 w: 0.20	 b: 0.10	 L: 47.7676
# Epoch: 60	 w: 0.20	 b: 0.10	 L: 47.7569
# Epoch: 61	 w: 0.20	 b: 0.09	 L: 47.7461
# Epoch: 62	 w: 0.20	 b: 0.09	 L: 47.7353
# Epoch: 63	 w: 0.20	 b: 0.09	 L: 47.7245
# Epoch: 64	 w: 0.20	 b: 0.09	 L: 47.7138
# Epoch: 65	 w: 0.20	 b: 0.09	 L: 47.7030
# Epoch: 66	 w: 0.20	 b: 0.09	 L: 47.6922
# Epoch: 67	 w: 0.20	 b: 0.09	 L: 47.6815
# Epoch: 68	 w: 0.20	 b: 0.09	 L: 47.6707
# Epoch: 69	 w: 0.20	 b: 0.09	 L: 47.6600
# Epoch: 70	 w: 0.20	 b: 0.09	 L: 47.6493
# Epoch: 71	 w: 0.20	 b: 0.09	 L: 47.6385
# Epoch: 72	 w: 0.20	 b: 0.09	 L: 47.6278
# Epoch: 73	 w: 0.20	 b: 0.09	 L: 47.6171
# Epoch: 74	 w: 0.20	 b: 0.09	 L: 47.6063
# Epoch: 75	 w: 0.20	 b: 0.08	 L: 47.5956
# Epoch: 76	 w: 0.20	 b: 0.08	 L: 47.5849
# Epoch: 77	 w: 0.20	 b: 0.08	 L: 47.5742
# Epoch: 78	 w: 0.20	 b: 0.08	 L: 47.5635
# Epoch: 79	 w: 0.20	 b: 0.08	 L: 47.5528
# Epoch: 80	 w: 0.20	 b: 0.08	 L: 47.5421
# Epoch: 81	 w: 0.20	 b: 0.08	 L: 47.5314
# Epoch: 82	 w: 0.20	 b: 0.08	 L: 47.5207
# Epoch: 83	 w: 0.20	 b: 0.08	 L: 47.5101
# Epoch: 84	 w: 0.20	 b: 0.08	 L: 47.4994
# Epoch: 85	 w: 0.20	 b: 0.08	 L: 47.4887
# Epoch: 86	 w: 0.20	 b: 0.08	 L: 47.4780
# Epoch: 87	 w: 0.20	 b: 0.08	 L: 47.4674
# Epoch: 88	 w: 0.20	 b: 0.08	 L: 47.4567
# Epoch: 89	 w: 0.20	 b: 0.07	 L: 47.4461
# Epoch: 90	 w: 0.20	 b: 0.07	 L: 47.4354
# Epoch: 91	 w: 0.20	 b: 0.07	 L: 47.4248
# Epoch: 92	 w: 0.20	 b: 0.07	 L: 47.4141
# Epoch: 93	 w: 0.20	 b: 0.07	 L: 47.4035
# Epoch: 94	 w: 0.20	 b: 0.07	 L: 47.3929
# Epoch: 95	 w: 0.20	 b: 0.07	 L: 47.3822
# Epoch: 96	 w: 0.20	 b: 0.07	 L: 47.3716
# Epoch: 97	 w: 0.20	 b: 0.07	 L: 47.3610
# Epoch: 98	 w: 0.20	 b: 0.07	 L: 47.3504
# Epoch: 99	 w: 0.21	 b: 0.07	 L: 47.3398
# Epoch: 100	 w: 0.21	 b: 0.07	 L: 47.3292
# Epoch: 101	 w: 0.21	 b: 0.07	 L: 47.3186
# Epoch: 102	 w: 0.21	 b: 0.06	 L: 47.3080
# Epoch: 103	 w: 0.21	 b: 0.06	 L: 47.2974
# Epoch: 104	 w: 0.21	 b: 0.06	 L: 47.2868
# Epoch: 105	 w: 0.21	 b: 0.06	 L: 47.2762
# Epoch: 106	 w: 0.21	 b: 0.06	 L: 47.2657
# Epoch: 107	 w: 0.21	 b: 0.06	 L: 47.2551
# Epoch: 108	 w: 0.21	 b: 0.06	 L: 47.2445
# Epoch: 109	 w: 0.21	 b: 0.06	 L: 47.2340
# Epoch: 110	 w: 0.21	 b: 0.06	 L: 47.2234
# Epoch: 111	 w: 0.21	 b: 0.06	 L: 47.2128
# Epoch: 112	 w: 0.21	 b: 0.06	 L: 47.2023
# Epoch: 113	 w: 0.21	 b: 0.06	 L: 47.1917
# Epoch: 114	 w: 0.21	 b: 0.06	 L: 47.1812
# Epoch: 115	 w: 0.21	 b: 0.06	 L: 47.1707
# Epoch: 116	 w: 0.21	 b: 0.05	 L: 47.1601
# Epoch: 117	 w: 0.21	 b: 0.05	 L: 47.1496
# Epoch: 118	 w: 0.21	 b: 0.05	 L: 47.1391
# Epoch: 119	 w: 0.21	 b: 0.05	 L: 47.1286
# Epoch: 120	 w: 0.21	 b: 0.05	 L: 47.1181
# Epoch: 121	 w: 0.21	 b: 0.05	 L: 47.1076
# Epoch: 122	 w: 0.21	 b: 0.05	 L: 47.0970
# Epoch: 123	 w: 0.21	 b: 0.05	 L: 47.0865
# Epoch: 124	 w: 0.21	 b: 0.05	 L: 47.0760
# Epoch: 125	 w: 0.21	 b: 0.05	 L: 47.0656
# Epoch: 126	 w: 0.21	 b: 0.05	 L: 47.0551
# Epoch: 127	 w: 0.21	 b: 0.05	 L: 47.0446
# Epoch: 128	 w: 0.21	 b: 0.05	 L: 47.0341
# Epoch: 129	 w: 0.21	 b: 0.05	 L: 47.0236
# Epoch: 130	 w: 0.21	 b: 0.04	 L: 47.0132
# Epoch: 131	 w: 0.21	 b: 0.04	 L: 47.0027
# Epoch: 132	 w: 0.21	 b: 0.04	 L: 46.9922
# Epoch: 133	 w: 0.21	 b: 0.04	 L: 46.9818
# Epoch: 134	 w: 0.21	 b: 0.04	 L: 46.9713
# Epoch: 135	 w: 0.21	 b: 0.04	 L: 46.9609
# Epoch: 136	 w: 0.21	 b: 0.04	 L: 46.9504
# Epoch: 137	 w: 0.21	 b: 0.04	 L: 46.9400
# Epoch: 138	 w: 0.21	 b: 0.04	 L: 46.9296
# Epoch: 139	 w: 0.21	 b: 0.04	 L: 46.9191
# Epoch: 140	 w: 0.21	 b: 0.04	 L: 46.9087
# Epoch: 141	 w: 0.21	 b: 0.04	 L: 46.8983
# Epoch: 142	 w: 0.21	 b: 0.04	 L: 46.8879
# Epoch: 143	 w: 0.21	 b: 0.04	 L: 46.8775
# Epoch: 144	 w: 0.21	 b: 0.03	 L: 46.8671
# Epoch: 145	 w: 0.21	 b: 0.03	 L: 46.8567
# Epoch: 146	 w: 0.21	 b: 0.03	 L: 46.8463
# Epoch: 147	 w: 0.21	 b: 0.03	 L: 46.8359
# Epoch: 148	 w: 0.21	 b: 0.03	 L: 46.8255
# Epoch: 149	 w: 0.21	 b: 0.03	 L: 46.8151
# Epoch: 150	 w: 0.21	 b: 0.03	 L: 46.8047
# Epoch: 151	 w: 0.21	 b: 0.03	 L: 46.7943
# Epoch: 152	 w: 0.21	 b: 0.03	 L: 46.7840
# Epoch: 153	 w: 0.21	 b: 0.03	 L: 46.7736
# Epoch: 154	 w: 0.21	 b: 0.03	 L: 46.7632
# Epoch: 155	 w: 0.21	 b: 0.03	 L: 46.7529
# Epoch: 156	 w: 0.21	 b: 0.03	 L: 46.7425
# Epoch: 157	 w: 0.21	 b: 0.03	 L: 46.7322
# Epoch: 158	 w: 0.21	 b: 0.03	 L: 46.7218
# Epoch: 159	 w: 0.21	 b: 0.02	 L: 46.7115
# Epoch: 160	 w: 0.21	 b: 0.02	 L: 46.7012
# Epoch: 161	 w: 0.21	 b: 0.02	 L: 46.6908
# Epoch: 162	 w: 0.21	 b: 0.02	 L: 46.6805
# Epoch: 163	 w: 0.21	 b: 0.02	 L: 46.6702
# Epoch: 164	 w: 0.21	 b: 0.02	 L: 46.6599
# Epoch: 165	 w: 0.21	 b: 0.02	 L: 46.6495
# Epoch: 166	 w: 0.21	 b: 0.02	 L: 46.6392
# Epoch: 167	 w: 0.21	 b: 0.02	 L: 46.6289
# Epoch: 168	 w: 0.21	 b: 0.02	 L: 46.6186
# Epoch: 169	 w: 0.21	 b: 0.02	 L: 46.6083
# Epoch: 170	 w: 0.21	 b: 0.02	 L: 46.5980
# Epoch: 171	 w: 0.21	 b: 0.02	 L: 46.5877
# Epoch: 172	 w: 0.21	 b: 0.02	 L: 46.5775
# Epoch: 173	 w: 0.21	 b: 0.01	 L: 46.5672
# Epoch: 174	 w: 0.21	 b: 0.01	 L: 46.5569
# Epoch: 175	 w: 0.21	 b: 0.01	 L: 46.5466
# Epoch: 176	 w: 0.21	 b: 0.01	 L: 46.5364
# Epoch: 177	 w: 0.21	 b: 0.01	 L: 46.5261
# Epoch: 178	 w: 0.21	 b: 0.01	 L: 46.5159
# Epoch: 179	 w: 0.21	 b: 0.01	 L: 46.5056
# Epoch: 180	 w: 0.21	 b: 0.01	 L: 46.4954
# Epoch: 181	 w: 0.21	 b: 0.01	 L: 46.4851
# Epoch: 182	 w: 0.21	 b: 0.01	 L: 46.4749
# Epoch: 183	 w: 0.22	 b: 0.01	 L: 46.4646
# Epoch: 184	 w: 0.22	 b: 0.01	 L: 46.4544
# Epoch: 185	 w: 0.22	 b: 0.01	 L: 46.4442
# Epoch: 186	 w: 0.22	 b: 0.01	 L: 46.4340
# Epoch: 187	 w: 0.22	 b: 0.00	 L: 46.4237
# Epoch: 188	 w: 0.22	 b: 0.00	 L: 46.4135
# Epoch: 189	 w: 0.22	 b: 0.00	 L: 46.4033
# Epoch: 190	 w: 0.22	 b: 0.00	 L: 46.3931
# Epoch: 191	 w: 0.22	 b: 0.00	 L: 46.3829
# Epoch: 192	 w: 0.22	 b: 0.00	 L: 46.3727
# Epoch: 193	 w: 0.22	 b: 0.00	 L: 46.3625
# Epoch: 194	 w: 0.22	 b: -0.00	 L: 46.3523
# Epoch: 195	 w: 0.22	 b: -0.00	 L: 46.3421
# Epoch: 196	 w: 0.22	 b: -0.00	 L: 46.3320
# Epoch: 197	 w: 0.22	 b: -0.00	 L: 46.3218
# Epoch: 198	 w: 0.22	 b: -0.00	 L: 46.3116
# Epoch: 199	 w: 0.22	 b: -0.00	 L: 46.3015
# Epoch: 200	 w: 0.22	 b: -0.00	 L: 46.2913
# Epoch: 201	 w: 0.22	 b: -0.01	 L: 46.2811
# Epoch: 202	 w: 0.22	 b: -0.01	 L: 46.2710
# Epoch: 203	 w: 0.22	 b: -0.01	 L: 46.2608
# Epoch: 204	 w: 0.22	 b: -0.01	 L: 46.2507
# Epoch: 205	 w: 0.22	 b: -0.01	 L: 46.2405
# Epoch: 206	 w: 0.22	 b: -0.01	 L: 46.2304
# Epoch: 207	 w: 0.22	 b: -0.01	 L: 46.2203
# Epoch: 208	 w: 0.22	 b: -0.01	 L: 46.2102
# Epoch: 209	 w: 0.22	 b: -0.01	 L: 46.2000
# Epoch: 210	 w: 0.22	 b: -0.01	 L: 46.1899
# Epoch: 211	 w: 0.22	 b: -0.01	 L: 46.1798
# Epoch: 212	 w: 0.22	 b: -0.01	 L: 46.1697
# Epoch: 213	 w: 0.22	 b: -0.01	 L: 46.1596
# Epoch: 214	 w: 0.22	 b: -0.01	 L: 46.1495
# Epoch: 215	 w: 0.22	 b: -0.02	 L: 46.1394
# Epoch: 216	 w: 0.22	 b: -0.02	 L: 46.1293
# Epoch: 217	 w: 0.22	 b: -0.02	 L: 46.1192
# Epoch: 218	 w: 0.22	 b: -0.02	 L: 46.1091
# Epoch: 219	 w: 0.22	 b: -0.02	 L: 46.0990
# Epoch: 220	 w: 0.22	 b: -0.02	 L: 46.0890
# Epoch: 221	 w: 0.22	 b: -0.02	 L: 46.0789
# Epoch: 222	 w: 0.22	 b: -0.02	 L: 46.0688
# Epoch: 223	 w: 0.22	 b: -0.02	 L: 46.0588
# Epoch: 224	 w: 0.22	 b: -0.02	 L: 46.0487
# Epoch: 225	 w: 0.22	 b: -0.02	 L: 46.0386
# Epoch: 226	 w: 0.22	 b: -0.02	 L: 46.0286
# Epoch: 227	 w: 0.22	 b: -0.02	 L: 46.0185
# Epoch: 228	 w: 0.22	 b: -0.02	 L: 46.0085
# Epoch: 229	 w: 0.22	 b: -0.02	 L: 45.9985
# Epoch: 230	 w: 0.22	 b: -0.03	 L: 45.9884
# Epoch: 231	 w: 0.22	 b: -0.03	 L: 45.9784
# Epoch: 232	 w: 0.22	 b: -0.03	 L: 45.9684
# Epoch: 233	 w: 0.22	 b: -0.03	 L: 45.9584
# Epoch: 234	 w: 0.22	 b: -0.03	 L: 45.9483
# Epoch: 235	 w: 0.22	 b: -0.03	 L: 45.9383
# Epoch: 236	 w: 0.22	 b: -0.03	 L: 45.9283
# Epoch: 237	 w: 0.22	 b: -0.03	 L: 45.9183
# Epoch: 238	 w: 0.22	 b: -0.03	 L: 45.9083
# Epoch: 239	 w: 0.22	 b: -0.03	 L: 45.8983
# Epoch: 240	 w: 0.22	 b: -0.03	 L: 45.8883
# Epoch: 241	 w: 0.22	 b: -0.03	 L: 45.8783
# Epoch: 242	 w: 0.22	 b: -0.03	 L: 45.8684
# Epoch: 243	 w: 0.22	 b: -0.03	 L: 45.8584
# Epoch: 244	 w: 0.22	 b: -0.04	 L: 45.8484
# Epoch: 245	 w: 0.22	 b: -0.04	 L: 45.8384
# Epoch: 246	 w: 0.22	 b: -0.04	 L: 45.8285
# Epoch: 247	 w: 0.22	 b: -0.04	 L: 45.8185
# Epoch: 248	 w: 0.22	 b: -0.04	 L: 45.8086
# Epoch: 249	 w: 0.22	 b: -0.04	 L: 45.7986
# Epoch: 250	 w: 0.22	 b: -0.04	 L: 45.7887
# Epoch: 251	 w: 0.22	 b: -0.04	 L: 45.7787
# Epoch: 252	 w: 0.22	 b: -0.04	 L: 45.7688
# Epoch: 253	 w: 0.22	 b: -0.04	 L: 45.7588
# Epoch: 254	 w: 0.22	 b: -0.04	 L: 45.7489
# Epoch: 255	 w: 0.22	 b: -0.04	 L: 45.7390
# Epoch: 256	 w: 0.22	 b: -0.04	 L: 45.7291
# Epoch: 257	 w: 0.22	 b: -0.04	 L: 45.7191
# Epoch: 258	 w: 0.22	 b: -0.05	 L: 45.7092
# Epoch: 259	 w: 0.22	 b: -0.05	 L: 45.6993
# Epoch: 260	 w: 0.22	 b: -0.05	 L: 45.6894
# Epoch: 261	 w: 0.22	 b: -0.05	 L: 45.6795
# Epoch: 262	 w: 0.22	 b: -0.05	 L: 45.6696
# Epoch: 263	 w: 0.22	 b: -0.05	 L: 45.6597
# Epoch: 264	 w: 0.22	 b: -0.05	 L: 45.6498
# Epoch: 265	 w: 0.22	 b: -0.05	 L: 45.6399
# Epoch: 266	 w: 0.22	 b: -0.05	 L: 45.6301
# Epoch: 267	 w: 0.22	 b: -0.05	 L: 45.6202
# Epoch: 268	 w: 0.23	 b: -0.05	 L: 45.6103
# Epoch: 269	 w: 0.23	 b: -0.05	 L: 45.6005
# Epoch: 270	 w: 0.23	 b: -0.05	 L: 45.5906
# Epoch: 271	 w: 0.23	 b: -0.05	 L: 45.5807
# Epoch: 272	 w: 0.23	 b: -0.05	 L: 45.5709
# Epoch: 273	 w: 0.23	 b: -0.06	 L: 45.5610
# Epoch: 274	 w: 0.23	 b: -0.06	 L: 45.5512
# Epoch: 275	 w: 0.23	 b: -0.06	 L: 45.5413
# Epoch: 276	 w: 0.23	 b: -0.06	 L: 45.5315
# Epoch: 277	 w: 0.23	 b: -0.06	 L: 45.5217
# Epoch: 278	 w: 0.23	 b: -0.06	 L: 45.5118
# Epoch: 279	 w: 0.23	 b: -0.06	 L: 45.5020
# Epoch: 280	 w: 0.23	 b: -0.06	 L: 45.4922
# Epoch: 281	 w: 0.23	 b: -0.06	 L: 45.4824
# Epoch: 282	 w: 0.23	 b: -0.06	 L: 45.4725
# Epoch: 283	 w: 0.23	 b: -0.06	 L: 45.4627
# Epoch: 284	 w: 0.23	 b: -0.06	 L: 45.4529
# Epoch: 285	 w: 0.23	 b: -0.06	 L: 45.4431
# Epoch: 286	 w: 0.23	 b: -0.06	 L: 45.4333
# Epoch: 287	 w: 0.23	 b: -0.07	 L: 45.4235
# Epoch: 288	 w: 0.23	 b: -0.07	 L: 45.4138
# Epoch: 289	 w: 0.23	 b: -0.07	 L: 45.4040
# Epoch: 290	 w: 0.23	 b: -0.07	 L: 45.3942
# Epoch: 291	 w: 0.23	 b: -0.07	 L: 45.3844
# Epoch: 292	 w: 0.23	 b: -0.07	 L: 45.3746
# Epoch: 293	 w: 0.23	 b: -0.07	 L: 45.3649
# Epoch: 294	 w: 0.23	 b: -0.07	 L: 45.3551
# Epoch: 295	 w: 0.23	 b: -0.07	 L: 45.3453
# Epoch: 296	 w: 0.23	 b: -0.07	 L: 45.3356
# Epoch: 297	 w: 0.23	 b: -0.07	 L: 45.3258
# Epoch: 298	 w: 0.23	 b: -0.07	 L: 45.3161
# Epoch: 299	 w: 0.23	 b: -0.07	 L: 45.3064
# Epoch: 300	 w: 0.23	 b: -0.07	 L: 45.2966
# Epoch: 301	 w: 0.23	 b: -0.07	 L: 45.2869
# Epoch: 302	 w: 0.23	 b: -0.08	 L: 45.2771
# Epoch: 303	 w: 0.23	 b: -0.08	 L: 45.2674
# Epoch: 304	 w: 0.23	 b: -0.08	 L: 45.2577
# Epoch: 305	 w: 0.23	 b: -0.08	 L: 45.2480
# Epoch: 306	 w: 0.23	 b: -0.08	 L: 45.2383
# Epoch: 307	 w: 0.23	 b: -0.08	 L: 45.2286
# Epoch: 308	 w: 0.23	 b: -0.08	 L: 45.2188
# Epoch: 309	 w: 0.23	 b: -0.08	 L: 45.2091
# Epoch: 310	 w: 0.23	 b: -0.08	 L: 45.1995
# Epoch: 311	 w: 0.23	 b: -0.08	 L: 45.1898
# Epoch: 312	 w: 0.23	 b: -0.08	 L: 45.1801
# Epoch: 313	 w: 0.23	 b: -0.08	 L: 45.1704
# Epoch: 314	 w: 0.23	 b: -0.08	 L: 45.1607
# Epoch: 315	 w: 0.23	 b: -0.08	 L: 45.1510
# Epoch: 316	 w: 0.23	 b: -0.09	 L: 45.1414
# Epoch: 317	 w: 0.23	 b: -0.09	 L: 45.1317
# Epoch: 318	 w: 0.23	 b: -0.09	 L: 45.1220
# Epoch: 319	 w: 0.23	 b: -0.09	 L: 45.1124
# Epoch: 320	 w: 0.23	 b: -0.09	 L: 45.1027
# Epoch: 321	 w: 0.23	 b: -0.09	 L: 45.0930
# Epoch: 322	 w: 0.23	 b: -0.09	 L: 45.0834
# Epoch: 323	 w: 0.23	 b: -0.09	 L: 45.0738
# Epoch: 324	 w: 0.23	 b: -0.09	 L: 45.0641
# Epoch: 325	 w: 0.23	 b: -0.09	 L: 45.0545
# Epoch: 326	 w: 0.23	 b: -0.09	 L: 45.0448
# Epoch: 327	 w: 0.23	 b: -0.09	 L: 45.0352
# Epoch: 328	 w: 0.23	 b: -0.09	 L: 45.0256
# Epoch: 329	 w: 0.23	 b: -0.09	 L: 45.0160
# Epoch: 330	 w: 0.23	 b: -0.09	 L: 45.0064
# Epoch: 331	 w: 0.23	 b: -0.10	 L: 44.9968
# Epoch: 332	 w: 0.23	 b: -0.10	 L: 44.9871
# Epoch: 333	 w: 0.23	 b: -0.10	 L: 44.9775
# Epoch: 334	 w: 0.23	 b: -0.10	 L: 44.9679
# Epoch: 335	 w: 0.23	 b: -0.10	 L: 44.9583
# Epoch: 336	 w: 0.23	 b: -0.10	 L: 44.9488
# Epoch: 337	 w: 0.23	 b: -0.10	 L: 44.9392
# Epoch: 338	 w: 0.23	 b: -0.10	 L: 44.9296
# Epoch: 339	 w: 0.23	 b: -0.10	 L: 44.9200
# Epoch: 340	 w: 0.23	 b: -0.10	 L: 44.9104
# Epoch: 341	 w: 0.23	 b: -0.10	 L: 44.9009
# Epoch: 342	 w: 0.23	 b: -0.10	 L: 44.8913
# Epoch: 343	 w: 0.23	 b: -0.10	 L: 44.8817
# Epoch: 344	 w: 0.23	 b: -0.10	 L: 44.8722
# Epoch: 345	 w: 0.23	 b: -0.10	 L: 44.8626
# Epoch: 346	 w: 0.23	 b: -0.11	 L: 44.8531
# Epoch: 347	 w: 0.23	 b: -0.11	 L: 44.8435
# Epoch: 348	 w: 0.23	 b: -0.11	 L: 44.8340
# Epoch: 349	 w: 0.23	 b: -0.11	 L: 44.8244
# Epoch: 350	 w: 0.23	 b: -0.11	 L: 44.8149
# Epoch: 351	 w: 0.23	 b: -0.11	 L: 44.8054
# Epoch: 352	 w: 0.23	 b: -0.11	 L: 44.7959
# Epoch: 353	 w: 0.23	 b: -0.11	 L: 44.7863
# Epoch: 354	 w: 0.23	 b: -0.11	 L: 44.7768
# Epoch: 355	 w: 0.24	 b: -0.11	 L: 44.7673
# Epoch: 356	 w: 0.24	 b: -0.11	 L: 44.7578
# Epoch: 357	 w: 0.24	 b: -0.11	 L: 44.7483
# Epoch: 358	 w: 0.24	 b: -0.11	 L: 44.7388
# Epoch: 359	 w: 0.24	 b: -0.11	 L: 44.7293
# Epoch: 360	 w: 0.24	 b: -0.12	 L: 44.7198
# Epoch: 361	 w: 0.24	 b: -0.12	 L: 44.7103
# Epoch: 362	 w: 0.24	 b: -0.12	 L: 44.7008
# Epoch: 363	 w: 0.24	 b: -0.12	 L: 44.6913
# Epoch: 364	 w: 0.24	 b: -0.12	 L: 44.6819
# Epoch: 365	 w: 0.24	 b: -0.12	 L: 44.6724
# Epoch: 366	 w: 0.24	 b: -0.12	 L: 44.6629
# Epoch: 367	 w: 0.24	 b: -0.12	 L: 44.6535
# Epoch: 368	 w: 0.24	 b: -0.12	 L: 44.6440
# Epoch: 369	 w: 0.24	 b: -0.12	 L: 44.6345
# Epoch: 370	 w: 0.24	 b: -0.12	 L: 44.6251
# Epoch: 371	 w: 0.24	 b: -0.12	 L: 44.6156
# Epoch: 372	 w: 0.24	 b: -0.12	 L: 44.6062
# Epoch: 373	 w: 0.24	 b: -0.12	 L: 44.5967
# Epoch: 374	 w: 0.24	 b: -0.12	 L: 44.5873
# Epoch: 375	 w: 0.24	 b: -0.13	 L: 44.5779
# Epoch: 376	 w: 0.24	 b: -0.13	 L: 44.5684
# Epoch: 377	 w: 0.24	 b: -0.13	 L: 44.5590
# Epoch: 378	 w: 0.24	 b: -0.13	 L: 44.5496
# Epoch: 379	 w: 0.24	 b: -0.13	 L: 44.5402
# Epoch: 380	 w: 0.24	 b: -0.13	 L: 44.5308
# Epoch: 381	 w: 0.24	 b: -0.13	 L: 44.5214
# Epoch: 382	 w: 0.24	 b: -0.13	 L: 44.5120
# Epoch: 383	 w: 0.24	 b: -0.13	 L: 44.5026
# Epoch: 384	 w: 0.24	 b: -0.13	 L: 44.4932
# Epoch: 385	 w: 0.24	 b: -0.13	 L: 44.4838
# Epoch: 386	 w: 0.24	 b: -0.13	 L: 44.4744
# Epoch: 387	 w: 0.24	 b: -0.13	 L: 44.4650
# Epoch: 388	 w: 0.24	 b: -0.13	 L: 44.4556
# Epoch: 389	 w: 0.24	 b: -0.13	 L: 44.4462
# Epoch: 390	 w: 0.24	 b: -0.14	 L: 44.4369
# Epoch: 391	 w: 0.24	 b: -0.14	 L: 44.4275
# Epoch: 392	 w: 0.24	 b: -0.14	 L: 44.4181
# Epoch: 393	 w: 0.24	 b: -0.14	 L: 44.4088
# Epoch: 394	 w: 0.24	 b: -0.14	 L: 44.3994
# Epoch: 395	 w: 0.24	 b: -0.14	 L: 44.3901
# Epoch: 396	 w: 0.24	 b: -0.14	 L: 44.3807
# Epoch: 397	 w: 0.24	 b: -0.14	 L: 44.3714
# Epoch: 398	 w: 0.24	 b: -0.14	 L: 44.3620
# Epoch: 399	 w: 0.24	 b: -0.14	 L: 44.3527
# Epoch: 400	 w: 0.24	 b: -0.14	 L: 44.3433
# Epoch: 401	 w: 0.24	 b: -0.14	 L: 44.3340
# Epoch: 402	 w: 0.24	 b: -0.14	 L: 44.3247
# Epoch: 403	 w: 0.24	 b: -0.14	 L: 44.3154
# Epoch: 404	 w: 0.24	 b: -0.14	 L: 44.3061
# Epoch: 405	 w: 0.24	 b: -0.15	 L: 44.2967
# Epoch: 406	 w: 0.24	 b: -0.15	 L: 44.2874
# Epoch: 407	 w: 0.24	 b: -0.15	 L: 44.2781
# Epoch: 408	 w: 0.24	 b: -0.15	 L: 44.2688
# Epoch: 409	 w: 0.24	 b: -0.15	 L: 44.2595
# Epoch: 410	 w: 0.24	 b: -0.15	 L: 44.2502
# Epoch: 411	 w: 0.24	 b: -0.15	 L: 44.2409
# Epoch: 412	 w: 0.24	 b: -0.15	 L: 44.2317
# Epoch: 413	 w: 0.24	 b: -0.15	 L: 44.2224
# Epoch: 414	 w: 0.24	 b: -0.15	 L: 44.2131
# Epoch: 415	 w: 0.24	 b: -0.15	 L: 44.2038
# Epoch: 416	 w: 0.24	 b: -0.15	 L: 44.1946
# Epoch: 417	 w: 0.24	 b: -0.15	 L: 44.1853
# Epoch: 418	 w: 0.24	 b: -0.15	 L: 44.1760
# Epoch: 419	 w: 0.24	 b: -0.16	 L: 44.1668
# Epoch: 420	 w: 0.24	 b: -0.16	 L: 44.1575
# Epoch: 421	 w: 0.24	 b: -0.16	 L: 44.1483
# Epoch: 422	 w: 0.24	 b: -0.16	 L: 44.1390
# Epoch: 423	 w: 0.24	 b: -0.16	 L: 44.1298
# Epoch: 424	 w: 0.24	 b: -0.16	 L: 44.1205
# Epoch: 425	 w: 0.24	 b: -0.16	 L: 44.1113
# Epoch: 426	 w: 0.24	 b: -0.16	 L: 44.1021
# Epoch: 427	 w: 0.24	 b: -0.16	 L: 44.0928
# Epoch: 428	 w: 0.24	 b: -0.16	 L: 44.0836
# Epoch: 429	 w: 0.24	 b: -0.16	 L: 44.0744
# Epoch: 430	 w: 0.24	 b: -0.16	 L: 44.0652
# Epoch: 431	 w: 0.24	 b: -0.16	 L: 44.0560
# Epoch: 432	 w: 0.24	 b: -0.16	 L: 44.0468
# Epoch: 433	 w: 0.24	 b: -0.16	 L: 44.0376
# Epoch: 434	 w: 0.24	 b: -0.17	 L: 44.0284
# Epoch: 435	 w: 0.24	 b: -0.17	 L: 44.0192
# Epoch: 436	 w: 0.24	 b: -0.17	 L: 44.0100
# Epoch: 437	 w: 0.24	 b: -0.17	 L: 44.0008
# Epoch: 438	 w: 0.24	 b: -0.17	 L: 43.9916
# Epoch: 439	 w: 0.24	 b: -0.17	 L: 43.9824
# Epoch: 440	 w: 0.24	 b: -0.17	 L: 43.9732
# Epoch: 441	 w: 0.24	 b: -0.17	 L: 43.9641
# Epoch: 442	 w: 0.24	 b: -0.17	 L: 43.9549
# Epoch: 443	 w: 0.24	 b: -0.17	 L: 43.9457
# Epoch: 444	 w: 0.25	 b: -0.17	 L: 43.9366
# Epoch: 445	 w: 0.25	 b: -0.17	 L: 43.9274
# Epoch: 446	 w: 0.25	 b: -0.17	 L: 43.9183
# Epoch: 447	 w: 0.25	 b: -0.17	 L: 43.9091
# Epoch: 448	 w: 0.25	 b: -0.17	 L: 43.9000
# Epoch: 449	 w: 0.25	 b: -0.18	 L: 43.8908
# Epoch: 450	 w: 0.25	 b: -0.18	 L: 43.8817
# Epoch: 451	 w: 0.25	 b: -0.18	 L: 43.8726
# Epoch: 452	 w: 0.25	 b: -0.18	 L: 43.8634
# Epoch: 453	 w: 0.25	 b: -0.18	 L: 43.8543
# Epoch: 454	 w: 0.25	 b: -0.18	 L: 43.8452
# Epoch: 455	 w: 0.25	 b: -0.18	 L: 43.8361
# Epoch: 456	 w: 0.25	 b: -0.18	 L: 43.8270
# Epoch: 457	 w: 0.25	 b: -0.18	 L: 43.8179
# Epoch: 458	 w: 0.25	 b: -0.18	 L: 43.8087
# Epoch: 459	 w: 0.25	 b: -0.18	 L: 43.7996
# Epoch: 460	 w: 0.25	 b: -0.18	 L: 43.7905
# Epoch: 461	 w: 0.25	 b: -0.18	 L: 43.7815
# Epoch: 462	 w: 0.25	 b: -0.18	 L: 43.7724
# Epoch: 463	 w: 0.25	 b: -0.18	 L: 43.7633
# Epoch: 464	 w: 0.25	 b: -0.19	 L: 43.7542
# Epoch: 465	 w: 0.25	 b: -0.19	 L: 43.7451
# Epoch: 466	 w: 0.25	 b: -0.19	 L: 43.7360
# Epoch: 467	 w: 0.25	 b: -0.19	 L: 43.7270
# Epoch: 468	 w: 0.25	 b: -0.19	 L: 43.7179
# Epoch: 469	 w: 0.25	 b: -0.19	 L: 43.7088
# Epoch: 470	 w: 0.25	 b: -0.19	 L: 43.6998
# Epoch: 471	 w: 0.25	 b: -0.19	 L: 43.6907
# Epoch: 472	 w: 0.25	 b: -0.19	 L: 43.6817
# Epoch: 473	 w: 0.25	 b: -0.19	 L: 43.6726
# Epoch: 474	 w: 0.25	 b: -0.19	 L: 43.6636
# Epoch: 475	 w: 0.25	 b: -0.19	 L: 43.6545
# Epoch: 476	 w: 0.25	 b: -0.19	 L: 43.6455
# Epoch: 477	 w: 0.25	 b: -0.19	 L: 43.6365
# Epoch: 478	 w: 0.25	 b: -0.19	 L: 43.6274
# Epoch: 479	 w: 0.25	 b: -0.20	 L: 43.6184
# Epoch: 480	 w: 0.25	 b: -0.20	 L: 43.6094
# Epoch: 481	 w: 0.25	 b: -0.20	 L: 43.6004
# Epoch: 482	 w: 0.25	 b: -0.20	 L: 43.5914
# Epoch: 483	 w: 0.25	 b: -0.20	 L: 43.5824
# Epoch: 484	 w: 0.25	 b: -0.20	 L: 43.5733
# Epoch: 485	 w: 0.25	 b: -0.20	 L: 43.5643
# Epoch: 486	 w: 0.25	 b: -0.20	 L: 43.5553
# Epoch: 487	 w: 0.25	 b: -0.20	 L: 43.5464
# Epoch: 488	 w: 0.25	 b: -0.20	 L: 43.5374
# Epoch: 489	 w: 0.25	 b: -0.20	 L: 43.5284
# Epoch: 490	 w: 0.25	 b: -0.20	 L: 43.5194
# Epoch: 491	 w: 0.25	 b: -0.20	 L: 43.5104
# Epoch: 492	 w: 0.25	 b: -0.20	 L: 43.5014
# Epoch: 493	 w: 0.25	 b: -0.20	 L: 43.4925
# Epoch: 494	 w: 0.25	 b: -0.20	 L: 43.4835
# Epoch: 495	 w: 0.25	 b: -0.21	 L: 43.4745
# Epoch: 496	 w: 0.25	 b: -0.21	 L: 43.4656
# Epoch: 497	 w: 0.25	 b: -0.21	 L: 43.4566
# Epoch: 498	 w: 0.25	 b: -0.21	 L: 43.4477
# Epoch: 499	 w: 0.25	 b: -0.21	 L: 43.4387
# Epoch: 500	 w: 0.25	 b: -0.21	 L: 43.4298
# Epoch: 501	 w: 0.25	 b: -0.21	 L: 43.4208
# Epoch: 502	 w: 0.25	 b: -0.21	 L: 43.4119
# Epoch: 503	 w: 0.25	 b: -0.21	 L: 43.4030
# Epoch: 504	 w: 0.25	 b: -0.21	 L: 43.3940
# Epoch: 505	 w: 0.25	 b: -0.21	 L: 43.3851
# Epoch: 506	 w: 0.25	 b: -0.21	 L: 43.3762
# Epoch: 507	 w: 0.25	 b: -0.21	 L: 43.3673
# Epoch: 508	 w: 0.25	 b: -0.21	 L: 43.3583
# Epoch: 509	 w: 0.25	 b: -0.21	 L: 43.3494
# Epoch: 510	 w: 0.25	 b: -0.22	 L: 43.3405
# Epoch: 511	 w: 0.25	 b: -0.22	 L: 43.3316
# Epoch: 512	 w: 0.25	 b: -0.22	 L: 43.3227
# Epoch: 513	 w: 0.25	 b: -0.22	 L: 43.3138
# Epoch: 514	 w: 0.25	 b: -0.22	 L: 43.3049
# Epoch: 515	 w: 0.25	 b: -0.22	 L: 43.2961
# Epoch: 516	 w: 0.25	 b: -0.22	 L: 43.2872
# Epoch: 517	 w: 0.25	 b: -0.22	 L: 43.2783
# Epoch: 518	 w: 0.25	 b: -0.22	 L: 43.2694
# Epoch: 519	 w: 0.25	 b: -0.22	 L: 43.2605
# Epoch: 520	 w: 0.25	 b: -0.22	 L: 43.2517
# Epoch: 521	 w: 0.25	 b: -0.22	 L: 43.2428
# Epoch: 522	 w: 0.25	 b: -0.22	 L: 43.2339
# Epoch: 523	 w: 0.25	 b: -0.22	 L: 43.2251
# Epoch: 524	 w: 0.25	 b: -0.22	 L: 43.2162
# Epoch: 525	 w: 0.25	 b: -0.23	 L: 43.2074
# Epoch: 526	 w: 0.25	 b: -0.23	 L: 43.1985
# Epoch: 527	 w: 0.25	 b: -0.23	 L: 43.1897
# Epoch: 528	 w: 0.25	 b: -0.23	 L: 43.1809
# Epoch: 529	 w: 0.25	 b: -0.23	 L: 43.1720
# Epoch: 530	 w: 0.25	 b: -0.23	 L: 43.1632
# Epoch: 531	 w: 0.25	 b: -0.23	 L: 43.1544
# Epoch: 532	 w: 0.25	 b: -0.23	 L: 43.1455
# Epoch: 533	 w: 0.25	 b: -0.23	 L: 43.1367
# Epoch: 534	 w: 0.26	 b: -0.23	 L: 43.1279
# Epoch: 535	 w: 0.26	 b: -0.23	 L: 43.1191
# Epoch: 536	 w: 0.26	 b: -0.23	 L: 43.1103
# Epoch: 537	 w: 0.26	 b: -0.23	 L: 43.1015
# Epoch: 538	 w: 0.26	 b: -0.23	 L: 43.0927
# Epoch: 539	 w: 0.26	 b: -0.23	 L: 43.0839
# Epoch: 540	 w: 0.26	 b: -0.24	 L: 43.0751
# Epoch: 541	 w: 0.26	 b: -0.24	 L: 43.0663
# Epoch: 542	 w: 0.26	 b: -0.24	 L: 43.0575
# Epoch: 543	 w: 0.26	 b: -0.24	 L: 43.0487
# Epoch: 544	 w: 0.26	 b: -0.24	 L: 43.0399
# Epoch: 545	 w: 0.26	 b: -0.24	 L: 43.0312
# Epoch: 546	 w: 0.26	 b: -0.24	 L: 43.0224
# Epoch: 547	 w: 0.26	 b: -0.24	 L: 43.0136
# Epoch: 548	 w: 0.26	 b: -0.24	 L: 43.0049
# Epoch: 549	 w: 0.26	 b: -0.24	 L: 42.9961
# Epoch: 550	 w: 0.26	 b: -0.24	 L: 42.9873
# Epoch: 551	 w: 0.26	 b: -0.24	 L: 42.9786
# Epoch: 552	 w: 0.26	 b: -0.24	 L: 42.9698
# Epoch: 553	 w: 0.26	 b: -0.24	 L: 42.9611
# Epoch: 554	 w: 0.26	 b: -0.24	 L: 42.9524
# Epoch: 555	 w: 0.26	 b: -0.24	 L: 42.9436
# Epoch: 556	 w: 0.26	 b: -0.25	 L: 42.9349
# Epoch: 557	 w: 0.26	 b: -0.25	 L: 42.9262
# Epoch: 558	 w: 0.26	 b: -0.25	 L: 42.9174
# Epoch: 559	 w: 0.26	 b: -0.25	 L: 42.9087
# Epoch: 560	 w: 0.26	 b: -0.25	 L: 42.9000
# Epoch: 561	 w: 0.26	 b: -0.25	 L: 42.8913
# Epoch: 562	 w: 0.26	 b: -0.25	 L: 42.8826
# Epoch: 563	 w: 0.26	 b: -0.25	 L: 42.8739
# Epoch: 564	 w: 0.26	 b: -0.25	 L: 42.8651
# Epoch: 565	 w: 0.26	 b: -0.25	 L: 42.8564
# Epoch: 566	 w: 0.26	 b: -0.25	 L: 42.8477
# Epoch: 567	 w: 0.26	 b: -0.25	 L: 42.8391
# Epoch: 568	 w: 0.26	 b: -0.25	 L: 42.8304
# Epoch: 569	 w: 0.26	 b: -0.25	 L: 42.8217
# Epoch: 570	 w: 0.26	 b: -0.25	 L: 42.8130
# Epoch: 571	 w: 0.26	 b: -0.26	 L: 42.8043
# Epoch: 572	 w: 0.26	 b: -0.26	 L: 42.7956
# Epoch: 573	 w: 0.26	 b: -0.26	 L: 42.7870
# Epoch: 574	 w: 0.26	 b: -0.26	 L: 42.7783
# Epoch: 575	 w: 0.26	 b: -0.26	 L: 42.7696
# Epoch: 576	 w: 0.26	 b: -0.26	 L: 42.7610
# Epoch: 577	 w: 0.26	 b: -0.26	 L: 42.7523
# Epoch: 578	 w: 0.26	 b: -0.26	 L: 42.7437
# Epoch: 579	 w: 0.26	 b: -0.26	 L: 42.7350
# Epoch: 580	 w: 0.26	 b: -0.26	 L: 42.7264
# Epoch: 581	 w: 0.26	 b: -0.26	 L: 42.7177
# Epoch: 582	 w: 0.26	 b: -0.26	 L: 42.7091
# Epoch: 583	 w: 0.26	 b: -0.26	 L: 42.7005
# Epoch: 584	 w: 0.26	 b: -0.26	 L: 42.6918
# Epoch: 585	 w: 0.26	 b: -0.26	 L: 42.6832
# Epoch: 586	 w: 0.26	 b: -0.27	 L: 42.6746
# Epoch: 587	 w: 0.26	 b: -0.27	 L: 42.6660
# Epoch: 588	 w: 0.26	 b: -0.27	 L: 42.6573
# Epoch: 589	 w: 0.26	 b: -0.27	 L: 42.6487
# Epoch: 590	 w: 0.26	 b: -0.27	 L: 42.6401
# Epoch: 591	 w: 0.26	 b: -0.27	 L: 42.6315
# Epoch: 592	 w: 0.26	 b: -0.27	 L: 42.6229
# Epoch: 593	 w: 0.26	 b: -0.27	 L: 42.6143
# Epoch: 594	 w: 0.26	 b: -0.27	 L: 42.6057
# Epoch: 595	 w: 0.26	 b: -0.27	 L: 42.5971
# Epoch: 596	 w: 0.26	 b: -0.27	 L: 42.5885
# Epoch: 597	 w: 0.26	 b: -0.27	 L: 42.5800
# Epoch: 598	 w: 0.26	 b: -0.27	 L: 42.5714
# Epoch: 599	 w: 0.26	 b: -0.27	 L: 42.5628
# Epoch: 600	 w: 0.26	 b: -0.27	 L: 42.5542
# Epoch: 601	 w: 0.26	 b: -0.27	 L: 42.5457
# Epoch: 602	 w: 0.26	 b: -0.28	 L: 42.5371
# Epoch: 603	 w: 0.26	 b: -0.28	 L: 42.5285
# Epoch: 604	 w: 0.26	 b: -0.28	 L: 42.5200
# Epoch: 605	 w: 0.26	 b: -0.28	 L: 42.5114
# Epoch: 606	 w: 0.26	 b: -0.28	 L: 42.5029
# Epoch: 607	 w: 0.26	 b: -0.28	 L: 42.4943
# Epoch: 608	 w: 0.26	 b: -0.28	 L: 42.4858
# Epoch: 609	 w: 0.26	 b: -0.28	 L: 42.4772
# Epoch: 610	 w: 0.26	 b: -0.28	 L: 42.4687
# Epoch: 611	 w: 0.26	 b: -0.28	 L: 42.4602
# Epoch: 612	 w: 0.26	 b: -0.28	 L: 42.4516
# Epoch: 613	 w: 0.26	 b: -0.28	 L: 42.4431
# Epoch: 614	 w: 0.26	 b: -0.28	 L: 42.4346
# Epoch: 615	 w: 0.26	 b: -0.28	 L: 42.4261
# Epoch: 616	 w: 0.26	 b: -0.28	 L: 42.4176
# Epoch: 617	 w: 0.26	 b: -0.29	 L: 42.4091
# Epoch: 618	 w: 0.26	 b: -0.29	 L: 42.4006
# Epoch: 619	 w: 0.26	 b: -0.29	 L: 42.3920
# Epoch: 620	 w: 0.26	 b: -0.29	 L: 42.3835
# Epoch: 621	 w: 0.26	 b: -0.29	 L: 42.3751
# Epoch: 622	 w: 0.26	 b: -0.29	 L: 42.3666
# Epoch: 623	 w: 0.26	 b: -0.29	 L: 42.3581
# Epoch: 624	 w: 0.26	 b: -0.29	 L: 42.3496
# Epoch: 625	 w: 0.26	 b: -0.29	 L: 42.3411
# Epoch: 626	 w: 0.27	 b: -0.29	 L: 42.3326
# Epoch: 627	 w: 0.27	 b: -0.29	 L: 42.3242
# Epoch: 628	 w: 0.27	 b: -0.29	 L: 42.3157
# Epoch: 629	 w: 0.27	 b: -0.29	 L: 42.3072
# Epoch: 630	 w: 0.27	 b: -0.29	 L: 42.2988
# Epoch: 631	 w: 0.27	 b: -0.29	 L: 42.2903
# Epoch: 632	 w: 0.27	 b: -0.29	 L: 42.2818
# Epoch: 633	 w: 0.27	 b: -0.30	 L: 42.2734
# Epoch: 634	 w: 0.27	 b: -0.30	 L: 42.2649
# Epoch: 635	 w: 0.27	 b: -0.30	 L: 42.2565
# Epoch: 636	 w: 0.27	 b: -0.30	 L: 42.2480
# Epoch: 637	 w: 0.27	 b: -0.30	 L: 42.2396
# Epoch: 638	 w: 0.27	 b: -0.30	 L: 42.2312
# Epoch: 639	 w: 0.27	 b: -0.30	 L: 42.2227
# Epoch: 640	 w: 0.27	 b: -0.30	 L: 42.2143
# Epoch: 641	 w: 0.27	 b: -0.30	 L: 42.2059
# Epoch: 642	 w: 0.27	 b: -0.30	 L: 42.1975
# Epoch: 643	 w: 0.27	 b: -0.30	 L: 42.1890
# Epoch: 644	 w: 0.27	 b: -0.30	 L: 42.1806
# Epoch: 645	 w: 0.27	 b: -0.30	 L: 42.1722
# Epoch: 646	 w: 0.27	 b: -0.30	 L: 42.1638
# Epoch: 647	 w: 0.27	 b: -0.30	 L: 42.1554
# Epoch: 648	 w: 0.27	 b: -0.30	 L: 42.1470
# Epoch: 649	 w: 0.27	 b: -0.31	 L: 42.1386
# Epoch: 650	 w: 0.27	 b: -0.31	 L: 42.1302
# Epoch: 651	 w: 0.27	 b: -0.31	 L: 42.1218
# Epoch: 652	 w: 0.27	 b: -0.31	 L: 42.1135
# Epoch: 653	 w: 0.27	 b: -0.31	 L: 42.1051
# Epoch: 654	 w: 0.27	 b: -0.31	 L: 42.0967
# Epoch: 655	 w: 0.27	 b: -0.31	 L: 42.0883
# Epoch: 656	 w: 0.27	 b: -0.31	 L: 42.0800
# Epoch: 657	 w: 0.27	 b: -0.31	 L: 42.0716
# Epoch: 658	 w: 0.27	 b: -0.31	 L: 42.0632
# Epoch: 659	 w: 0.27	 b: -0.31	 L: 42.0549
# Epoch: 660	 w: 0.27	 b: -0.31	 L: 42.0465
# Epoch: 661	 w: 0.27	 b: -0.31	 L: 42.0382
# Epoch: 662	 w: 0.27	 b: -0.31	 L: 42.0298
# Epoch: 663	 w: 0.27	 b: -0.31	 L: 42.0215
# Epoch: 664	 w: 0.27	 b: -0.32	 L: 42.0131
# Epoch: 665	 w: 0.27	 b: -0.32	 L: 42.0048
# Epoch: 666	 w: 0.27	 b: -0.32	 L: 41.9964
# Epoch: 667	 w: 0.27	 b: -0.32	 L: 41.9881
# Epoch: 668	 w: 0.27	 b: -0.32	 L: 41.9798
# Epoch: 669	 w: 0.27	 b: -0.32	 L: 41.9715
# Epoch: 670	 w: 0.27	 b: -0.32	 L: 41.9631
# Epoch: 671	 w: 0.27	 b: -0.32	 L: 41.9548
# Epoch: 672	 w: 0.27	 b: -0.32	 L: 41.9465
# Epoch: 673	 w: 0.27	 b: -0.32	 L: 41.9382
# Epoch: 674	 w: 0.27	 b: -0.32	 L: 41.9299
# Epoch: 675	 w: 0.27	 b: -0.32	 L: 41.9216
# Epoch: 676	 w: 0.27	 b: -0.32	 L: 41.9133
# Epoch: 677	 w: 0.27	 b: -0.32	 L: 41.9050
# Epoch: 678	 w: 0.27	 b: -0.32	 L: 41.8967
# Epoch: 679	 w: 0.27	 b: -0.32	 L: 41.8884
# Epoch: 680	 w: 0.27	 b: -0.33	 L: 41.8801
# Epoch: 681	 w: 0.27	 b: -0.33	 L: 41.8718
# Epoch: 682	 w: 0.27	 b: -0.33	 L: 41.8636
# Epoch: 683	 w: 0.27	 b: -0.33	 L: 41.8553
# Epoch: 684	 w: 0.27	 b: -0.33	 L: 41.8470
# Epoch: 685	 w: 0.27	 b: -0.33	 L: 41.8387
# Epoch: 686	 w: 0.27	 b: -0.33	 L: 41.8305
# Epoch: 687	 w: 0.27	 b: -0.33	 L: 41.8222
# Epoch: 688	 w: 0.27	 b: -0.33	 L: 41.8140
# Epoch: 689	 w: 0.27	 b: -0.33	 L: 41.8057
# Epoch: 690	 w: 0.27	 b: -0.33	 L: 41.7975
# Epoch: 691	 w: 0.27	 b: -0.33	 L: 41.7892
# Epoch: 692	 w: 0.27	 b: -0.33	 L: 41.7810
# Epoch: 693	 w: 0.27	 b: -0.33	 L: 41.7727
# Epoch: 694	 w: 0.27	 b: -0.33	 L: 41.7645
# Epoch: 695	 w: 0.27	 b: -0.33	 L: 41.7563
# Epoch: 696	 w: 0.27	 b: -0.34	 L: 41.7480
# Epoch: 697	 w: 0.27	 b: -0.34	 L: 41.7398
# Epoch: 698	 w: 0.27	 b: -0.34	 L: 41.7316
# Epoch: 699	 w: 0.27	 b: -0.34	 L: 41.7234
# Epoch: 700	 w: 0.27	 b: -0.34	 L: 41.7151
# Epoch: 701	 w: 0.27	 b: -0.34	 L: 41.7069
# Epoch: 702	 w: 0.27	 b: -0.34	 L: 41.6987
# Epoch: 703	 w: 0.27	 b: -0.34	 L: 41.6905
# Epoch: 704	 w: 0.27	 b: -0.34	 L: 41.6823
# Epoch: 705	 w: 0.27	 b: -0.34	 L: 41.6741
# Epoch: 706	 w: 0.27	 b: -0.34	 L: 41.6659
# Epoch: 707	 w: 0.27	 b: -0.34	 L: 41.6577
# Epoch: 708	 w: 0.27	 b: -0.34	 L: 41.6496
# Epoch: 709	 w: 0.27	 b: -0.34	 L: 41.6414
# Epoch: 710	 w: 0.27	 b: -0.34	 L: 41.6332
# Epoch: 711	 w: 0.27	 b: -0.34	 L: 41.6250
# Epoch: 712	 w: 0.27	 b: -0.35	 L: 41.6168
# Epoch: 713	 w: 0.27	 b: -0.35	 L: 41.6087
# Epoch: 714	 w: 0.27	 b: -0.35	 L: 41.6005
# Epoch: 715	 w: 0.27	 b: -0.35	 L: 41.5923
# Epoch: 716	 w: 0.27	 b: -0.35	 L: 41.5842
# Epoch: 717	 w: 0.27	 b: -0.35	 L: 41.5760
# Epoch: 718	 w: 0.27	 b: -0.35	 L: 41.5679
# Epoch: 719	 w: 0.27	 b: -0.35	 L: 41.5597
# Epoch: 720	 w: 0.28	 b: -0.35	 L: 41.5516
# Epoch: 721	 w: 0.28	 b: -0.35	 L: 41.5434
# Epoch: 722	 w: 0.28	 b: -0.35	 L: 41.5353
# Epoch: 723	 w: 0.28	 b: -0.35	 L: 41.5272
# Epoch: 724	 w: 0.28	 b: -0.35	 L: 41.5190
# Epoch: 725	 w: 0.28	 b: -0.35	 L: 41.5109
# Epoch: 726	 w: 0.28	 b: -0.35	 L: 41.5028
# Epoch: 727	 w: 0.28	 b: -0.36	 L: 41.4946
# Epoch: 728	 w: 0.28	 b: -0.36	 L: 41.4865
# Epoch: 729	 w: 0.28	 b: -0.36	 L: 41.4784
# Epoch: 730	 w: 0.28	 b: -0.36	 L: 41.4703
# Epoch: 731	 w: 0.28	 b: -0.36	 L: 41.4622
# Epoch: 732	 w: 0.28	 b: -0.36	 L: 41.4541
# Epoch: 733	 w: 0.28	 b: -0.36	 L: 41.4460
# Epoch: 734	 w: 0.28	 b: -0.36	 L: 41.4379
# Epoch: 735	 w: 0.28	 b: -0.36	 L: 41.4298
# Epoch: 736	 w: 0.28	 b: -0.36	 L: 41.4217
# Epoch: 737	 w: 0.28	 b: -0.36	 L: 41.4136
# Epoch: 738	 w: 0.28	 b: -0.36	 L: 41.4055
# Epoch: 739	 w: 0.28	 b: -0.36	 L: 41.3975
# Epoch: 740	 w: 0.28	 b: -0.36	 L: 41.3894
# Epoch: 741	 w: 0.28	 b: -0.36	 L: 41.3813
# Epoch: 742	 w: 0.28	 b: -0.36	 L: 41.3732
# Epoch: 743	 w: 0.28	 b: -0.37	 L: 41.3652
# Epoch: 744	 w: 0.28	 b: -0.37	 L: 41.3571
# Epoch: 745	 w: 0.28	 b: -0.37	 L: 41.3490
# Epoch: 746	 w: 0.28	 b: -0.37	 L: 41.3410
# Epoch: 747	 w: 0.28	 b: -0.37	 L: 41.3329
# Epoch: 748	 w: 0.28	 b: -0.37	 L: 41.3249
# Epoch: 749	 w: 0.28	 b: -0.37	 L: 41.3168
# Epoch: 750	 w: 0.28	 b: -0.37	 L: 41.3088
# Epoch: 751	 w: 0.28	 b: -0.37	 L: 41.3008
# Epoch: 752	 w: 0.28	 b: -0.37	 L: 41.2927
# Epoch: 753	 w: 0.28	 b: -0.37	 L: 41.2847
# Epoch: 754	 w: 0.28	 b: -0.37	 L: 41.2767
# Epoch: 755	 w: 0.28	 b: -0.37	 L: 41.2686
# Epoch: 756	 w: 0.28	 b: -0.37	 L: 41.2606
# Epoch: 757	 w: 0.28	 b: -0.37	 L: 41.2526
# Epoch: 758	 w: 0.28	 b: -0.37	 L: 41.2446
# Epoch: 759	 w: 0.28	 b: -0.38	 L: 41.2366
# Epoch: 760	 w: 0.28	 b: -0.38	 L: 41.2286
# Epoch: 761	 w: 0.28	 b: -0.38	 L: 41.2206
# Epoch: 762	 w: 0.28	 b: -0.38	 L: 41.2126
# Epoch: 763	 w: 0.28	 b: -0.38	 L: 41.2046
# Epoch: 764	 w: 0.28	 b: -0.38	 L: 41.1966
# Epoch: 765	 w: 0.28	 b: -0.38	 L: 41.1886
# Epoch: 766	 w: 0.28	 b: -0.38	 L: 41.1806
# Epoch: 767	 w: 0.28	 b: -0.38	 L: 41.1726
# Epoch: 768	 w: 0.28	 b: -0.38	 L: 41.1646
# Epoch: 769	 w: 0.28	 b: -0.38	 L: 41.1566
# Epoch: 770	 w: 0.28	 b: -0.38	 L: 41.1487
# Epoch: 771	 w: 0.28	 b: -0.38	 L: 41.1407
# Epoch: 772	 w: 0.28	 b: -0.38	 L: 41.1327
# Epoch: 773	 w: 0.28	 b: -0.38	 L: 41.1248
# Epoch: 774	 w: 0.28	 b: -0.38	 L: 41.1168
# Epoch: 775	 w: 0.28	 b: -0.39	 L: 41.1088
# Epoch: 776	 w: 0.28	 b: -0.39	 L: 41.1009
# Epoch: 777	 w: 0.28	 b: -0.39	 L: 41.0929
# Epoch: 778	 w: 0.28	 b: -0.39	 L: 41.0850
# Epoch: 779	 w: 0.28	 b: -0.39	 L: 41.0770
# Epoch: 780	 w: 0.28	 b: -0.39	 L: 41.0691
# Epoch: 781	 w: 0.28	 b: -0.39	 L: 41.0612
# Epoch: 782	 w: 0.28	 b: -0.39	 L: 41.0532
# Epoch: 783	 w: 0.28	 b: -0.39	 L: 41.0453
# Epoch: 784	 w: 0.28	 b: -0.39	 L: 41.0374
# Epoch: 785	 w: 0.28	 b: -0.39	 L: 41.0295
# Epoch: 786	 w: 0.28	 b: -0.39	 L: 41.0215
# Epoch: 787	 w: 0.28	 b: -0.39	 L: 41.0136
# Epoch: 788	 w: 0.28	 b: -0.39	 L: 41.0057
# Epoch: 789	 w: 0.28	 b: -0.39	 L: 40.9978
# Epoch: 790	 w: 0.28	 b: -0.39	 L: 40.9899
# Epoch: 791	 w: 0.28	 b: -0.39	 L: 40.9820
# Epoch: 792	 w: 0.28	 b: -0.40	 L: 40.9741
# Epoch: 793	 w: 0.28	 b: -0.40	 L: 40.9662
# Epoch: 794	 w: 0.28	 b: -0.40	 L: 40.9583
# Epoch: 795	 w: 0.28	 b: -0.40	 L: 40.9504
# Epoch: 796	 w: 0.28	 b: -0.40	 L: 40.9425
# Epoch: 797	 w: 0.28	 b: -0.40	 L: 40.9346
# Epoch: 798	 w: 0.28	 b: -0.40	 L: 40.9268
# Epoch: 799	 w: 0.28	 b: -0.40	 L: 40.9189
# Epoch: 800	 w: 0.28	 b: -0.40	 L: 40.9110
# Epoch: 801	 w: 0.28	 b: -0.40	 L: 40.9031
# Epoch: 802	 w: 0.28	 b: -0.40	 L: 40.8953
# Epoch: 803	 w: 0.28	 b: -0.40	 L: 40.8874
# Epoch: 804	 w: 0.28	 b: -0.40	 L: 40.8795
# Epoch: 805	 w: 0.28	 b: -0.40	 L: 40.8717
# Epoch: 806	 w: 0.28	 b: -0.40	 L: 40.8638
# Epoch: 807	 w: 0.28	 b: -0.40	 L: 40.8560
# Epoch: 808	 w: 0.28	 b: -0.41	 L: 40.8481
# Epoch: 809	 w: 0.28	 b: -0.41	 L: 40.8403
# Epoch: 810	 w: 0.28	 b: -0.41	 L: 40.8325
# Epoch: 811	 w: 0.28	 b: -0.41	 L: 40.8246
# Epoch: 812	 w: 0.28	 b: -0.41	 L: 40.8168
# Epoch: 813	 w: 0.28	 b: -0.41	 L: 40.8090
# Epoch: 814	 w: 0.28	 b: -0.41	 L: 40.8011
# Epoch: 815	 w: 0.28	 b: -0.41	 L: 40.7933
# Epoch: 816	 w: 0.29	 b: -0.41	 L: 40.7855
# Epoch: 817	 w: 0.29	 b: -0.41	 L: 40.7777
# Epoch: 818	 w: 0.29	 b: -0.41	 L: 40.7699
# Epoch: 819	 w: 0.29	 b: -0.41	 L: 40.7620
# Epoch: 820	 w: 0.29	 b: -0.41	 L: 40.7542
# Epoch: 821	 w: 0.29	 b: -0.41	 L: 40.7464
# Epoch: 822	 w: 0.29	 b: -0.41	 L: 40.7386
# Epoch: 823	 w: 0.29	 b: -0.41	 L: 40.7308
# Epoch: 824	 w: 0.29	 b: -0.42	 L: 40.7230
# Epoch: 825	 w: 0.29	 b: -0.42	 L: 40.7152
# Epoch: 826	 w: 0.29	 b: -0.42	 L: 40.7075
# Epoch: 827	 w: 0.29	 b: -0.42	 L: 40.6997
# Epoch: 828	 w: 0.29	 b: -0.42	 L: 40.6919
# Epoch: 829	 w: 0.29	 b: -0.42	 L: 40.6841
# Epoch: 830	 w: 0.29	 b: -0.42	 L: 40.6763
# Epoch: 831	 w: 0.29	 b: -0.42	 L: 40.6686
# Epoch: 832	 w: 0.29	 b: -0.42	 L: 40.6608
# Epoch: 833	 w: 0.29	 b: -0.42	 L: 40.6530
# Epoch: 834	 w: 0.29	 b: -0.42	 L: 40.6453
# Epoch: 835	 w: 0.29	 b: -0.42	 L: 40.6375
# Epoch: 836	 w: 0.29	 b: -0.42	 L: 40.6298
# Epoch: 837	 w: 0.29	 b: -0.42	 L: 40.6220
# Epoch: 838	 w: 0.29	 b: -0.42	 L: 40.6143
# Epoch: 839	 w: 0.29	 b: -0.42	 L: 40.6065
# Epoch: 840	 w: 0.29	 b: -0.43	 L: 40.5988
# Epoch: 841	 w: 0.29	 b: -0.43	 L: 40.5911
# Epoch: 842	 w: 0.29	 b: -0.43	 L: 40.5833
# Epoch: 843	 w: 0.29	 b: -0.43	 L: 40.5756
# Epoch: 844	 w: 0.29	 b: -0.43	 L: 40.5679
# Epoch: 845	 w: 0.29	 b: -0.43	 L: 40.5601
# Epoch: 846	 w: 0.29	 b: -0.43	 L: 40.5524
# Epoch: 847	 w: 0.29	 b: -0.43	 L: 40.5447
# Epoch: 848	 w: 0.29	 b: -0.43	 L: 40.5370
# Epoch: 849	 w: 0.29	 b: -0.43	 L: 40.5293
# Epoch: 850	 w: 0.29	 b: -0.43	 L: 40.5216
# Epoch: 851	 w: 0.29	 b: -0.43	 L: 40.5139
# Epoch: 852	 w: 0.29	 b: -0.43	 L: 40.5062
# Epoch: 853	 w: 0.29	 b: -0.43	 L: 40.4985
# Epoch: 854	 w: 0.29	 b: -0.43	 L: 40.4908
# Epoch: 855	 w: 0.29	 b: -0.43	 L: 40.4831
# Epoch: 856	 w: 0.29	 b: -0.43	 L: 40.4754
# Epoch: 857	 w: 0.29	 b: -0.44	 L: 40.4677
# Epoch: 858	 w: 0.29	 b: -0.44	 L: 40.4600
# Epoch: 859	 w: 0.29	 b: -0.44	 L: 40.4523
# Epoch: 860	 w: 0.29	 b: -0.44	 L: 40.4447
# Epoch: 861	 w: 0.29	 b: -0.44	 L: 40.4370
# Epoch: 862	 w: 0.29	 b: -0.44	 L: 40.4293
# Epoch: 863	 w: 0.29	 b: -0.44	 L: 40.4217
# Epoch: 864	 w: 0.29	 b: -0.44	 L: 40.4140
# Epoch: 865	 w: 0.29	 b: -0.44	 L: 40.4063
# Epoch: 866	 w: 0.29	 b: -0.44	 L: 40.3987
# Epoch: 867	 w: 0.29	 b: -0.44	 L: 40.3910
# Epoch: 868	 w: 0.29	 b: -0.44	 L: 40.3834
# Epoch: 869	 w: 0.29	 b: -0.44	 L: 40.3757
# Epoch: 870	 w: 0.29	 b: -0.44	 L: 40.3681
# Epoch: 871	 w: 0.29	 b: -0.44	 L: 40.3605
# Epoch: 872	 w: 0.29	 b: -0.44	 L: 40.3528
# Epoch: 873	 w: 0.29	 b: -0.45	 L: 40.3452
# Epoch: 874	 w: 0.29	 b: -0.45	 L: 40.3376
# Epoch: 875	 w: 0.29	 b: -0.45	 L: 40.3299
# Epoch: 876	 w: 0.29	 b: -0.45	 L: 40.3223
# Epoch: 877	 w: 0.29	 b: -0.45	 L: 40.3147
# Epoch: 878	 w: 0.29	 b: -0.45	 L: 40.3071
# Epoch: 879	 w: 0.29	 b: -0.45	 L: 40.2995
# Epoch: 880	 w: 0.29	 b: -0.45	 L: 40.2919
# Epoch: 881	 w: 0.29	 b: -0.45	 L: 40.2842
# Epoch: 882	 w: 0.29	 b: -0.45	 L: 40.2766
# Epoch: 883	 w: 0.29	 b: -0.45	 L: 40.2690
# Epoch: 884	 w: 0.29	 b: -0.45	 L: 40.2614
# Epoch: 885	 w: 0.29	 b: -0.45	 L: 40.2539
# Epoch: 886	 w: 0.29	 b: -0.45	 L: 40.2463
# Epoch: 887	 w: 0.29	 b: -0.45	 L: 40.2387
# Epoch: 888	 w: 0.29	 b: -0.45	 L: 40.2311
# Epoch: 889	 w: 0.29	 b: -0.46	 L: 40.2235
# Epoch: 890	 w: 0.29	 b: -0.46	 L: 40.2159
# Epoch: 891	 w: 0.29	 b: -0.46	 L: 40.2084
# Epoch: 892	 w: 0.29	 b: -0.46	 L: 40.2008
# Epoch: 893	 w: 0.29	 b: -0.46	 L: 40.1932
# Epoch: 894	 w: 0.29	 b: -0.46	 L: 40.1857
# Epoch: 895	 w: 0.29	 b: -0.46	 L: 40.1781
# Epoch: 896	 w: 0.29	 b: -0.46	 L: 40.1705
# Epoch: 897	 w: 0.29	 b: -0.46	 L: 40.1630
# Epoch: 898	 w: 0.29	 b: -0.46	 L: 40.1554
# Epoch: 899	 w: 0.29	 b: -0.46	 L: 40.1479
# Epoch: 900	 w: 0.29	 b: -0.46	 L: 40.1403
# Epoch: 901	 w: 0.29	 b: -0.46	 L: 40.1328
# Epoch: 902	 w: 0.29	 b: -0.46	 L: 40.1253
# Epoch: 903	 w: 0.29	 b: -0.46	 L: 40.1177
# Epoch: 904	 w: 0.29	 b: -0.46	 L: 40.1102
# Epoch: 905	 w: 0.29	 b: -0.46	 L: 40.1027
# Epoch: 906	 w: 0.29	 b: -0.47	 L: 40.0951
# Epoch: 907	 w: 0.29	 b: -0.47	 L: 40.0876
# Epoch: 908	 w: 0.29	 b: -0.47	 L: 40.0801
# Epoch: 909	 w: 0.29	 b: -0.47	 L: 40.0726
# Epoch: 910	 w: 0.29	 b: -0.47	 L: 40.0651
# Epoch: 911	 w: 0.29	 b: -0.47	 L: 40.0575
# Epoch: 912	 w: 0.29	 b: -0.47	 L: 40.0500
# Epoch: 913	 w: 0.30	 b: -0.47	 L: 40.0425
# Epoch: 914	 w: 0.30	 b: -0.47	 L: 40.0350
# Epoch: 915	 w: 0.30	 b: -0.47	 L: 40.0275
# Epoch: 916	 w: 0.30	 b: -0.47	 L: 40.0200
# Epoch: 917	 w: 0.30	 b: -0.47	 L: 40.0125
# Epoch: 918	 w: 0.30	 b: -0.47	 L: 40.0051
# Epoch: 919	 w: 0.30	 b: -0.47	 L: 39.9976
# Epoch: 920	 w: 0.30	 b: -0.47	 L: 39.9901
# Epoch: 921	 w: 0.30	 b: -0.47	 L: 39.9826
# Epoch: 922	 w: 0.30	 b: -0.48	 L: 39.9751
# Epoch: 923	 w: 0.30	 b: -0.48	 L: 39.9677
# Epoch: 924	 w: 0.30	 b: -0.48	 L: 39.9602
# Epoch: 925	 w: 0.30	 b: -0.48	 L: 39.9527
# Epoch: 926	 w: 0.30	 b: -0.48	 L: 39.9453
# Epoch: 927	 w: 0.30	 b: -0.48	 L: 39.9378
# Epoch: 928	 w: 0.30	 b: -0.48	 L: 39.9304
# Epoch: 929	 w: 0.30	 b: -0.48	 L: 39.9229
# Epoch: 930	 w: 0.30	 b: -0.48	 L: 39.9155
# Epoch: 931	 w: 0.30	 b: -0.48	 L: 39.9080
# Epoch: 932	 w: 0.30	 b: -0.48	 L: 39.9006
# Epoch: 933	 w: 0.30	 b: -0.48	 L: 39.8931
# Epoch: 934	 w: 0.30	 b: -0.48	 L: 39.8857
# Epoch: 935	 w: 0.30	 b: -0.48	 L: 39.8782
# Epoch: 936	 w: 0.30	 b: -0.48	 L: 39.8708
# Epoch: 937	 w: 0.30	 b: -0.48	 L: 39.8634
# Epoch: 938	 w: 0.30	 b: -0.48	 L: 39.8560
# Epoch: 939	 w: 0.30	 b: -0.49	 L: 39.8485
# Epoch: 940	 w: 0.30	 b: -0.49	 L: 39.8411
# Epoch: 941	 w: 0.30	 b: -0.49	 L: 39.8337
# Epoch: 942	 w: 0.30	 b: -0.49	 L: 39.8263
# Epoch: 943	 w: 0.30	 b: -0.49	 L: 39.8189
# Epoch: 944	 w: 0.30	 b: -0.49	 L: 39.8115
# Epoch: 945	 w: 0.30	 b: -0.49	 L: 39.8041
# Epoch: 946	 w: 0.30	 b: -0.49	 L: 39.7967
# Epoch: 947	 w: 0.30	 b: -0.49	 L: 39.7893
# Epoch: 948	 w: 0.30	 b: -0.49	 L: 39.7819
# Epoch: 949	 w: 0.30	 b: -0.49	 L: 39.7745
# Epoch: 950	 w: 0.30	 b: -0.49	 L: 39.7671
# Epoch: 951	 w: 0.30	 b: -0.49	 L: 39.7597
# Epoch: 952	 w: 0.30	 b: -0.49	 L: 39.7524
# Epoch: 953	 w: 0.30	 b: -0.49	 L: 39.7450
# Epoch: 954	 w: 0.30	 b: -0.49	 L: 39.7376
# Epoch: 955	 w: 0.30	 b: -0.49	 L: 39.7302
# Epoch: 956	 w: 0.30	 b: -0.50	 L: 39.7229
# Epoch: 957	 w: 0.30	 b: -0.50	 L: 39.7155
# Epoch: 958	 w: 0.30	 b: -0.50	 L: 39.7081
# Epoch: 959	 w: 0.30	 b: -0.50	 L: 39.7008
# Epoch: 960	 w: 0.30	 b: -0.50	 L: 39.6934
# Epoch: 961	 w: 0.30	 b: -0.50	 L: 39.6861
# Epoch: 962	 w: 0.30	 b: -0.50	 L: 39.6787
# Epoch: 963	 w: 0.30	 b: -0.50	 L: 39.6714
# Epoch: 964	 w: 0.30	 b: -0.50	 L: 39.6640
# Epoch: 965	 w: 0.30	 b: -0.50	 L: 39.6567
# Epoch: 966	 w: 0.30	 b: -0.50	 L: 39.6494
# Epoch: 967	 w: 0.30	 b: -0.50	 L: 39.6420
# Epoch: 968	 w: 0.30	 b: -0.50	 L: 39.6347
# Epoch: 969	 w: 0.30	 b: -0.50	 L: 39.6274
# Epoch: 970	 w: 0.30	 b: -0.50	 L: 39.6200
# Epoch: 971	 w: 0.30	 b: -0.50	 L: 39.6127
# Epoch: 972	 w: 0.30	 b: -0.51	 L: 39.6054
# Epoch: 973	 w: 0.30	 b: -0.51	 L: 39.5981
# Epoch: 974	 w: 0.30	 b: -0.51	 L: 39.5908
# Epoch: 975	 w: 0.30	 b: -0.51	 L: 39.5835
# Epoch: 976	 w: 0.30	 b: -0.51	 L: 39.5762
# Epoch: 977	 w: 0.30	 b: -0.51	 L: 39.5689
# Epoch: 978	 w: 0.30	 b: -0.51	 L: 39.5616
# Epoch: 979	 w: 0.30	 b: -0.51	 L: 39.5543
# Epoch: 980	 w: 0.30	 b: -0.51	 L: 39.5470
# Epoch: 981	 w: 0.30	 b: -0.51	 L: 39.5397
# Epoch: 982	 w: 0.30	 b: -0.51	 L: 39.5324
# Epoch: 983	 w: 0.30	 b: -0.51	 L: 39.5251
# Epoch: 984	 w: 0.30	 b: -0.51	 L: 39.5178
# Epoch: 985	 w: 0.30	 b: -0.51	 L: 39.5105
# Epoch: 986	 w: 0.30	 b: -0.51	 L: 39.5033
# Epoch: 987	 w: 0.30	 b: -0.51	 L: 39.4960
# Epoch: 988	 w: 0.30	 b: -0.51	 L: 39.4887
# Epoch: 989	 w: 0.30	 b: -0.52	 L: 39.4815
# Epoch: 990	 w: 0.30	 b: -0.52	 L: 39.4742
# Epoch: 991	 w: 0.30	 b: -0.52	 L: 39.4669
# Epoch: 992	 w: 0.30	 b: -0.52	 L: 39.4597
# Epoch: 993	 w: 0.30	 b: -0.52	 L: 39.4524
# Epoch: 994	 w: 0.30	 b: -0.52	 L: 39.4452
# Epoch: 995	 w: 0.30	 b: -0.52	 L: 39.4379
# Epoch: 996	 w: 0.30	 b: -0.52	 L: 39.4307
# Epoch: 997	 w: 0.30	 b: -0.52	 L: 39.4235
# Epoch: 998	 w: 0.30	 b: -0.52	 L: 39.4162
# Epoch: 999	 w: 0.30	 b: -0.52	 L: 39.4090
# Epoch: 1000	 w: 0.30	 b: -0.52	 L: 39.4018
# Epoch: 1001	 w: 0.30	 b: -0.52	 L: 39.3945
# Epoch: 1002	 w: 0.30	 b: -0.52	 L: 39.3873
# Epoch: 1003	 w: 0.30	 b: -0.52	 L: 39.3801
# Epoch: 1004	 w: 0.30	 b: -0.52	 L: 39.3729
# Epoch: 1005	 w: 0.30	 b: -0.52	 L: 39.3656
# Epoch: 1006	 w: 0.30	 b: -0.53	 L: 39.3584
# Epoch: 1007	 w: 0.30	 b: -0.53	 L: 39.3512
# Epoch: 1008	 w: 0.30	 b: -0.53	 L: 39.3440
# Epoch: 1009	 w: 0.30	 b: -0.53	 L: 39.3368
# Epoch: 1010	 w: 0.30	 b: -0.53	 L: 39.3296
# Epoch: 1011	 w: 0.30	 b: -0.53	 L: 39.3224
# Epoch: 1012	 w: 0.30	 b: -0.53	 L: 39.3152
# Epoch: 1013	 w: 0.31	 b: -0.53	 L: 39.3080
# Epoch: 1014	 w: 0.31	 b: -0.53	 L: 39.3008
# Epoch: 1015	 w: 0.31	 b: -0.53	 L: 39.2937
# Epoch: 1016	 w: 0.31	 b: -0.53	 L: 39.2865
# Epoch: 1017	 w: 0.31	 b: -0.53	 L: 39.2793
# Epoch: 1018	 w: 0.31	 b: -0.53	 L: 39.2721
# Epoch: 1019	 w: 0.31	 b: -0.53	 L: 39.2649
# Epoch: 1020	 w: 0.31	 b: -0.53	 L: 39.2578
# Epoch: 1021	 w: 0.31	 b: -0.53	 L: 39.2506
# Epoch: 1022	 w: 0.31	 b: -0.53	 L: 39.2434
# Epoch: 1023	 w: 0.31	 b: -0.54	 L: 39.2363
# Epoch: 1024	 w: 0.31	 b: -0.54	 L: 39.2291
# Epoch: 1025	 w: 0.31	 b: -0.54	 L: 39.2220
# Epoch: 1026	 w: 0.31	 b: -0.54	 L: 39.2148
# Epoch: 1027	 w: 0.31	 b: -0.54	 L: 39.2077
# Epoch: 1028	 w: 0.31	 b: -0.54	 L: 39.2005
# Epoch: 1029	 w: 0.31	 b: -0.54	 L: 39.1934
# Epoch: 1030	 w: 0.31	 b: -0.54	 L: 39.1862
# Epoch: 1031	 w: 0.31	 b: -0.54	 L: 39.1791
# Epoch: 1032	 w: 0.31	 b: -0.54	 L: 39.1720
# Epoch: 1033	 w: 0.31	 b: -0.54	 L: 39.1648
# Epoch: 1034	 w: 0.31	 b: -0.54	 L: 39.1577
# Epoch: 1035	 w: 0.31	 b: -0.54	 L: 39.1506
# Epoch: 1036	 w: 0.31	 b: -0.54	 L: 39.1435
# Epoch: 1037	 w: 0.31	 b: -0.54	 L: 39.1363
# Epoch: 1038	 w: 0.31	 b: -0.54	 L: 39.1292
# Epoch: 1039	 w: 0.31	 b: -0.54	 L: 39.1221
# Epoch: 1040	 w: 0.31	 b: -0.55	 L: 39.1150
# Epoch: 1041	 w: 0.31	 b: -0.55	 L: 39.1079
# Epoch: 1042	 w: 0.31	 b: -0.55	 L: 39.1008
# Epoch: 1043	 w: 0.31	 b: -0.55	 L: 39.0937
# Epoch: 1044	 w: 0.31	 b: -0.55	 L: 39.0866
# Epoch: 1045	 w: 0.31	 b: -0.55	 L: 39.0795
# Epoch: 1046	 w: 0.31	 b: -0.55	 L: 39.0724
# Epoch: 1047	 w: 0.31	 b: -0.55	 L: 39.0653
# Epoch: 1048	 w: 0.31	 b: -0.55	 L: 39.0582
# Epoch: 1049	 w: 0.31	 b: -0.55	 L: 39.0512
# Epoch: 1050	 w: 0.31	 b: -0.55	 L: 39.0441
# Epoch: 1051	 w: 0.31	 b: -0.55	 L: 39.0370
# Epoch: 1052	 w: 0.31	 b: -0.55	 L: 39.0299
# Epoch: 1053	 w: 0.31	 b: -0.55	 L: 39.0229
# Epoch: 1054	 w: 0.31	 b: -0.55	 L: 39.0158
# Epoch: 1055	 w: 0.31	 b: -0.55	 L: 39.0087
# Epoch: 1056	 w: 0.31	 b: -0.55	 L: 39.0017
# Epoch: 1057	 w: 0.31	 b: -0.56	 L: 38.9946
# Epoch: 1058	 w: 0.31	 b: -0.56	 L: 38.9876
# Epoch: 1059	 w: 0.31	 b: -0.56	 L: 38.9805
# Epoch: 1060	 w: 0.31	 b: -0.56	 L: 38.9734
# Epoch: 1061	 w: 0.31	 b: -0.56	 L: 38.9664
# Epoch: 1062	 w: 0.31	 b: -0.56	 L: 38.9594
# Epoch: 1063	 w: 0.31	 b: -0.56	 L: 38.9523
# Epoch: 1064	 w: 0.31	 b: -0.56	 L: 38.9453
# Epoch: 1065	 w: 0.31	 b: -0.56	 L: 38.9382
# Epoch: 1066	 w: 0.31	 b: -0.56	 L: 38.9312
# Epoch: 1067	 w: 0.31	 b: -0.56	 L: 38.9242
# Epoch: 1068	 w: 0.31	 b: -0.56	 L: 38.9172
# Epoch: 1069	 w: 0.31	 b: -0.56	 L: 38.9101
# Epoch: 1070	 w: 0.31	 b: -0.56	 L: 38.9031
# Epoch: 1071	 w: 0.31	 b: -0.56	 L: 38.8961
# Epoch: 1072	 w: 0.31	 b: -0.56	 L: 38.8891
# Epoch: 1073	 w: 0.31	 b: -0.56	 L: 38.8821
# Epoch: 1074	 w: 0.31	 b: -0.57	 L: 38.8751
# Epoch: 1075	 w: 0.31	 b: -0.57	 L: 38.8681
# Epoch: 1076	 w: 0.31	 b: -0.57	 L: 38.8611
# Epoch: 1077	 w: 0.31	 b: -0.57	 L: 38.8541
# Epoch: 1078	 w: 0.31	 b: -0.57	 L: 38.8471
# Epoch: 1079	 w: 0.31	 b: -0.57	 L: 38.8401
# Epoch: 1080	 w: 0.31	 b: -0.57	 L: 38.8331
# Epoch: 1081	 w: 0.31	 b: -0.57	 L: 38.8261
# Epoch: 1082	 w: 0.31	 b: -0.57	 L: 38.8191
# Epoch: 1083	 w: 0.31	 b: -0.57	 L: 38.8121
# Epoch: 1084	 w: 0.31	 b: -0.57	 L: 38.8052
# Epoch: 1085	 w: 0.31	 b: -0.57	 L: 38.7982
# Epoch: 1086	 w: 0.31	 b: -0.57	 L: 38.7912
# Epoch: 1087	 w: 0.31	 b: -0.57	 L: 38.7842
# Epoch: 1088	 w: 0.31	 b: -0.57	 L: 38.7773
# Epoch: 1089	 w: 0.31	 b: -0.57	 L: 38.7703
# Epoch: 1090	 w: 0.31	 b: -0.57	 L: 38.7634
# Epoch: 1091	 w: 0.31	 b: -0.58	 L: 38.7564
# Epoch: 1092	 w: 0.31	 b: -0.58	 L: 38.7494
# Epoch: 1093	 w: 0.31	 b: -0.58	 L: 38.7425
# Epoch: 1094	 w: 0.31	 b: -0.58	 L: 38.7356
# Epoch: 1095	 w: 0.31	 b: -0.58	 L: 38.7286
# Epoch: 1096	 w: 0.31	 b: -0.58	 L: 38.7217
# Epoch: 1097	 w: 0.31	 b: -0.58	 L: 38.7147
# Epoch: 1098	 w: 0.31	 b: -0.58	 L: 38.7078
# Epoch: 1099	 w: 0.31	 b: -0.58	 L: 38.7009
# Epoch: 1100	 w: 0.31	 b: -0.58	 L: 38.6939
# Epoch: 1101	 w: 0.31	 b: -0.58	 L: 38.6870
# Epoch: 1102	 w: 0.31	 b: -0.58	 L: 38.6801
# Epoch: 1103	 w: 0.31	 b: -0.58	 L: 38.6732
# Epoch: 1104	 w: 0.31	 b: -0.58	 L: 38.6662
# Epoch: 1105	 w: 0.31	 b: -0.58	 L: 38.6593
# Epoch: 1106	 w: 0.31	 b: -0.58	 L: 38.6524
# Epoch: 1107	 w: 0.31	 b: -0.58	 L: 38.6455
# Epoch: 1108	 w: 0.31	 b: -0.58	 L: 38.6386
# Epoch: 1109	 w: 0.31	 b: -0.59	 L: 38.6317
# Epoch: 1110	 w: 0.31	 b: -0.59	 L: 38.6248
# Epoch: 1111	 w: 0.31	 b: -0.59	 L: 38.6179
# Epoch: 1112	 w: 0.31	 b: -0.59	 L: 38.6110
# Epoch: 1113	 w: 0.31	 b: -0.59	 L: 38.6041
# Epoch: 1114	 w: 0.31	 b: -0.59	 L: 38.5972
# Epoch: 1115	 w: 0.32	 b: -0.59	 L: 38.5903
# Epoch: 1116	 w: 0.32	 b: -0.59	 L: 38.5834
# Epoch: 1117	 w: 0.32	 b: -0.59	 L: 38.5766
# Epoch: 1118	 w: 0.32	 b: -0.59	 L: 38.5697
# Epoch: 1119	 w: 0.32	 b: -0.59	 L: 38.5628
# Epoch: 1120	 w: 0.32	 b: -0.59	 L: 38.5559
# Epoch: 1121	 w: 0.32	 b: -0.59	 L: 38.5491
# Epoch: 1122	 w: 0.32	 b: -0.59	 L: 38.5422
# Epoch: 1123	 w: 0.32	 b: -0.59	 L: 38.5353
# Epoch: 1124	 w: 0.32	 b: -0.59	 L: 38.5285
# Epoch: 1125	 w: 0.32	 b: -0.59	 L: 38.5216
# Epoch: 1126	 w: 0.32	 b: -0.60	 L: 38.5148
# Epoch: 1127	 w: 0.32	 b: -0.60	 L: 38.5079
# Epoch: 1128	 w: 0.32	 b: -0.60	 L: 38.5011
# Epoch: 1129	 w: 0.32	 b: -0.60	 L: 38.4942
# Epoch: 1130	 w: 0.32	 b: -0.60	 L: 38.4874
# Epoch: 1131	 w: 0.32	 b: -0.60	 L: 38.4805
# Epoch: 1132	 w: 0.32	 b: -0.60	 L: 38.4737
# Epoch: 1133	 w: 0.32	 b: -0.60	 L: 38.4669
# Epoch: 1134	 w: 0.32	 b: -0.60	 L: 38.4600
# Epoch: 1135	 w: 0.32	 b: -0.60	 L: 38.4532
# Epoch: 1136	 w: 0.32	 b: -0.60	 L: 38.4464
# Epoch: 1137	 w: 0.32	 b: -0.60	 L: 38.4396
# Epoch: 1138	 w: 0.32	 b: -0.60	 L: 38.4327
# Epoch: 1139	 w: 0.32	 b: -0.60	 L: 38.4259
# Epoch: 1140	 w: 0.32	 b: -0.60	 L: 38.4191
# Epoch: 1141	 w: 0.32	 b: -0.60	 L: 38.4123
# Epoch: 1142	 w: 0.32	 b: -0.60	 L: 38.4055
# Epoch: 1143	 w: 0.32	 b: -0.61	 L: 38.3987
# Epoch: 1144	 w: 0.32	 b: -0.61	 L: 38.3919
# Epoch: 1145	 w: 0.32	 b: -0.61	 L: 38.3851
# ...
# Epoch: 9628	 w: 0.70	 b: -2.86	 L: 22.8347
# Epoch: 9629	 w: 0.70	 b: -2.86	 L: 22.8345
# Epoch: 9630	 w: 0.70	 b: -2.86	 L: 22.8343
# Epoch: 9631	 w: 0.70	 b: -2.86	 L: 22.8341
# Epoch: 9632	 w: 0.70	 b: -2.87	 L: 22.8340
# Epoch: 9633	 w: 0.70	 b: -2.87	 L: 22.8338
# Epoch: 9634	 w: 0.70	 b: -2.87	 L: 22.8336
# Epoch: 9635	 w: 0.70	 b: -2.87	 L: 22.8334
# Epoch: 9636	 w: 0.70	 b: -2.87	 L: 22.8332
# Epoch: 9637	 w: 0.70	 b: -2.87	 L: 22.8330
# Epoch: 9638	 w: 0.70	 b: -2.87	 L: 22.8329
# Epoch: 9639	 w: 0.70	 b: -2.87	 L: 22.8327
# Epoch: 9640	 w: 0.70	 b: -2.87	 L: 22.8325
# Epoch: 9641	 w: 0.70	 b: -2.87	 L: 22.8323
# Epoch: 9642	 w: 0.70	 b: -2.87	 L: 22.8321
# Epoch: 9643	 w: 0.70	 b: -2.87	 L: 22.8319
# Epoch: 9644	 w: 0.70	 b: -2.87	 L: 22.8318
# Epoch: 9645	 w: 0.70	 b: -2.87	 L: 22.8316
# Epoch: 9646	 w: 0.70	 b: -2.87	 L: 22.8314
# Epoch: 9647	 w: 0.70	 b: -2.87	 L: 22.8312
# Epoch: 9648	 w: 0.70	 b: -2.87	 L: 22.8310
# Epoch: 9649	 w: 0.70	 b: -2.87	 L: 22.8308
# Epoch: 9650	 w: 0.70	 b: -2.87	 L: 22.8307
# Epoch: 9651	 w: 0.70	 b: -2.87	 L: 22.8305
# Epoch: 9652	 w: 0.70	 b: -2.87	 L: 22.8303
# Epoch: 9653	 w: 0.70	 b: -2.87	 L: 22.8301
# Epoch: 9654	 w: 0.70	 b: -2.87	 L: 22.8299
# Epoch: 9655	 w: 0.70	 b: -2.87	 L: 22.8297
# Epoch: 9656	 w: 0.70	 b: -2.87	 L: 22.8296
# Epoch: 9657	 w: 0.70	 b: -2.87	 L: 22.8294
# Epoch: 9658	 w: 0.70	 b: -2.87	 L: 22.8292
# Epoch: 9659	 w: 0.70	 b: -2.87	 L: 22.8290
# Epoch: 9660	 w: 0.70	 b: -2.87	 L: 22.8288
# Epoch: 9661	 w: 0.70	 b: -2.87	 L: 22.8287
# Epoch: 9662	 w: 0.70	 b: -2.87	 L: 22.8285
# Epoch: 9663	 w: 0.70	 b: -2.87	 L: 22.8283
# Epoch: 9664	 w: 0.70	 b: -2.87	 L: 22.8281
# Epoch: 9665	 w: 0.70	 b: -2.87	 L: 22.8279
# Epoch: 9666	 w: 0.70	 b: -2.87	 L: 22.8277
# Epoch: 9667	 w: 0.70	 b: -2.87	 L: 22.8276
# Epoch: 9668	 w: 0.70	 b: -2.87	 L: 22.8274
# Epoch: 9669	 w: 0.70	 b: -2.87	 L: 22.8272
# Epoch: 9670	 w: 0.70	 b: -2.87	 L: 22.8270
# Epoch: 9671	 w: 0.70	 b: -2.87	 L: 22.8268
# Epoch: 9672	 w: 0.70	 b: -2.87	 L: 22.8267
# Epoch: 9673	 w: 0.70	 b: -2.87	 L: 22.8265
# Epoch: 9674	 w: 0.70	 b: -2.87	 L: 22.8263
# Epoch: 9675	 w: 0.70	 b: -2.87	 L: 22.8261
# Epoch: 9676	 w: 0.70	 b: -2.87	 L: 22.8259
# Epoch: 9677	 w: 0.70	 b: -2.87	 L: 22.8258
# Epoch: 9678	 w: 0.70	 b: -2.87	 L: 22.8256
# Epoch: 9679	 w: 0.70	 b: -2.87	 L: 22.8254
# Epoch: 9680	 w: 0.70	 b: -2.87	 L: 22.8252
# Epoch: 9681	 w: 0.70	 b: -2.87	 L: 22.8250
# Epoch: 9682	 w: 0.70	 b: -2.87	 L: 22.8249
# Epoch: 9683	 w: 0.70	 b: -2.87	 L: 22.8247
# Epoch: 9684	 w: 0.70	 b: -2.87	 L: 22.8245
# Epoch: 9685	 w: 0.70	 b: -2.87	 L: 22.8243
# Epoch: 9686	 w: 0.70	 b: -2.87	 L: 22.8241
# Epoch: 9687	 w: 0.70	 b: -2.87	 L: 22.8240
# Epoch: 9688	 w: 0.70	 b: -2.87	 L: 22.8238
# Epoch: 9689	 w: 0.70	 b: -2.87	 L: 22.8236
# Epoch: 9690	 w: 0.70	 b: -2.87	 L: 22.8234
# Epoch: 9691	 w: 0.70	 b: -2.87	 L: 22.8232
# Epoch: 9692	 w: 0.70	 b: -2.87	 L: 22.8231
# Epoch: 9693	 w: 0.70	 b: -2.87	 L: 22.8229
# Epoch: 9694	 w: 0.70	 b: -2.87	 L: 22.8227
# Epoch: 9695	 w: 0.70	 b: -2.87	 L: 22.8225
# Epoch: 9696	 w: 0.70	 b: -2.87	 L: 22.8223
# Epoch: 9697	 w: 0.70	 b: -2.87	 L: 22.8222
# Epoch: 9698	 w: 0.70	 b: -2.87	 L: 22.8220
# Epoch: 9699	 w: 0.70	 b: -2.87	 L: 22.8218
# Epoch: 9700	 w: 0.70	 b: -2.87	 L: 22.8216
# Epoch: 9701	 w: 0.70	 b: -2.87	 L: 22.8214
# Epoch: 9702	 w: 0.70	 b: -2.87	 L: 22.8213
# Epoch: 9703	 w: 0.70	 b: -2.87	 L: 22.8211
# Epoch: 9704	 w: 0.70	 b: -2.87	 L: 22.8209
# Epoch: 9705	 w: 0.70	 b: -2.87	 L: 22.8207
# Epoch: 9706	 w: 0.70	 b: -2.87	 L: 22.8206
# Epoch: 9707	 w: 0.70	 b: -2.87	 L: 22.8204
# Epoch: 9708	 w: 0.70	 b: -2.87	 L: 22.8202
# Epoch: 9709	 w: 0.70	 b: -2.87	 L: 22.8200
# Epoch: 9710	 w: 0.70	 b: -2.87	 L: 22.8198
# Epoch: 9711	 w: 0.70	 b: -2.87	 L: 22.8197
# Epoch: 9712	 w: 0.70	 b: -2.87	 L: 22.8195
# Epoch: 9713	 w: 0.70	 b: -2.87	 L: 22.8193
# Epoch: 9714	 w: 0.70	 b: -2.87	 L: 22.8191
# Epoch: 9715	 w: 0.70	 b: -2.87	 L: 22.8189
# Epoch: 9716	 w: 0.70	 b: -2.87	 L: 22.8188
# Epoch: 9717	 w: 0.70	 b: -2.87	 L: 22.8186
# Epoch: 9718	 w: 0.70	 b: -2.87	 L: 22.8184
# Epoch: 9719	 w: 0.70	 b: -2.87	 L: 22.8182
# Epoch: 9720	 w: 0.70	 b: -2.87	 L: 22.8181
# Epoch: 9721	 w: 0.70	 b: -2.87	 L: 22.8179
# Epoch: 9722	 w: 0.70	 b: -2.87	 L: 22.8177
# Epoch: 9723	 w: 0.70	 b: -2.87	 L: 22.8175
# Epoch: 9724	 w: 0.70	 b: -2.87	 L: 22.8174
# Epoch: 9725	 w: 0.70	 b: -2.87	 L: 22.8172
# Epoch: 9726	 w: 0.70	 b: -2.87	 L: 22.8170
# Epoch: 9727	 w: 0.70	 b: -2.87	 L: 22.8168
# Epoch: 9728	 w: 0.70	 b: -2.87	 L: 22.8166
# Epoch: 9729	 w: 0.70	 b: -2.87	 L: 22.8165
# Epoch: 9730	 w: 0.70	 b: -2.87	 L: 22.8163
# Epoch: 9731	 w: 0.70	 b: -2.87	 L: 22.8161
# Epoch: 9732	 w: 0.70	 b: -2.87	 L: 22.8159
# Epoch: 9733	 w: 0.70	 b: -2.87	 L: 22.8158
# Epoch: 9734	 w: 0.70	 b: -2.87	 L: 22.8156
# Epoch: 9735	 w: 0.70	 b: -2.87	 L: 22.8154
# Epoch: 9736	 w: 0.70	 b: -2.87	 L: 22.8152
# Epoch: 9737	 w: 0.70	 b: -2.87	 L: 22.8151
# Epoch: 9738	 w: 0.70	 b: -2.87	 L: 22.8149
# Epoch: 9739	 w: 0.70	 b: -2.88	 L: 22.8147
# Epoch: 9740	 w: 0.70	 b: -2.88	 L: 22.8145
# Epoch: 9741	 w: 0.70	 b: -2.88	 L: 22.8144
# Epoch: 9742	 w: 0.70	 b: -2.88	 L: 22.8142
# Epoch: 9743	 w: 0.70	 b: -2.88	 L: 22.8140
# Epoch: 9744	 w: 0.70	 b: -2.88	 L: 22.8138
# Epoch: 9745	 w: 0.70	 b: -2.88	 L: 22.8137
# Epoch: 9746	 w: 0.70	 b: -2.88	 L: 22.8135
# Epoch: 9747	 w: 0.70	 b: -2.88	 L: 22.8133
# Epoch: 9748	 w: 0.70	 b: -2.88	 L: 22.8131
# Epoch: 9749	 w: 0.70	 b: -2.88	 L: 22.8130
# Epoch: 9750	 w: 0.70	 b: -2.88	 L: 22.8128
# Epoch: 9751	 w: 0.70	 b: -2.88	 L: 22.8126
# Epoch: 9752	 w: 0.70	 b: -2.88	 L: 22.8124
# Epoch: 9753	 w: 0.70	 b: -2.88	 L: 22.8123
# Epoch: 9754	 w: 0.70	 b: -2.88	 L: 22.8121
# Epoch: 9755	 w: 0.70	 b: -2.88	 L: 22.8119
# Epoch: 9756	 w: 0.70	 b: -2.88	 L: 22.8117
# Epoch: 9757	 w: 0.70	 b: -2.88	 L: 22.8116
# Epoch: 9758	 w: 0.70	 b: -2.88	 L: 22.8114
# Epoch: 9759	 w: 0.70	 b: -2.88	 L: 22.8112
# Epoch: 9760	 w: 0.70	 b: -2.88	 L: 22.8110
# Epoch: 9761	 w: 0.70	 b: -2.88	 L: 22.8109
# Epoch: 9762	 w: 0.70	 b: -2.88	 L: 22.8107
# Epoch: 9763	 w: 0.70	 b: -2.88	 L: 22.8105
# Epoch: 9764	 w: 0.70	 b: -2.88	 L: 22.8103
# Epoch: 9765	 w: 0.70	 b: -2.88	 L: 22.8102
# Epoch: 9766	 w: 0.70	 b: -2.88	 L: 22.8100
# Epoch: 9767	 w: 0.70	 b: -2.88	 L: 22.8098
# Epoch: 9768	 w: 0.70	 b: -2.88	 L: 22.8096
# Epoch: 9769	 w: 0.70	 b: -2.88	 L: 22.8095
# Epoch: 9770	 w: 0.70	 b: -2.88	 L: 22.8093
# Epoch: 9771	 w: 0.70	 b: -2.88	 L: 22.8091
# Epoch: 9772	 w: 0.70	 b: -2.88	 L: 22.8089
# Epoch: 9773	 w: 0.70	 b: -2.88	 L: 22.8088
# Epoch: 9774	 w: 0.70	 b: -2.88	 L: 22.8086
# Epoch: 9775	 w: 0.70	 b: -2.88	 L: 22.8084
# Epoch: 9776	 w: 0.70	 b: -2.88	 L: 22.8083
# Epoch: 9777	 w: 0.70	 b: -2.88	 L: 22.8081
# Epoch: 9778	 w: 0.70	 b: -2.88	 L: 22.8079
# Epoch: 9779	 w: 0.70	 b: -2.88	 L: 22.8077
# Epoch: 9780	 w: 0.70	 b: -2.88	 L: 22.8076
# Epoch: 9781	 w: 0.70	 b: -2.88	 L: 22.8074
# Epoch: 9782	 w: 0.70	 b: -2.88	 L: 22.8072
# Epoch: 9783	 w: 0.70	 b: -2.88	 L: 22.8070
# Epoch: 9784	 w: 0.70	 b: -2.88	 L: 22.8069
# Epoch: 9785	 w: 0.70	 b: -2.88	 L: 22.8067
# Epoch: 9786	 w: 0.70	 b: -2.88	 L: 22.8065
# Epoch: 9787	 w: 0.70	 b: -2.88	 L: 22.8064
# Epoch: 9788	 w: 0.70	 b: -2.88	 L: 22.8062
# Epoch: 9789	 w: 0.70	 b: -2.88	 L: 22.8060
# Epoch: 9790	 w: 0.70	 b: -2.88	 L: 22.8058
# Epoch: 9791	 w: 0.70	 b: -2.88	 L: 22.8057
# Epoch: 9792	 w: 0.70	 b: -2.88	 L: 22.8055
# Epoch: 9793	 w: 0.70	 b: -2.88	 L: 22.8053
# Epoch: 9794	 w: 0.70	 b: -2.88	 L: 22.8051
# Epoch: 9795	 w: 0.70	 b: -2.88	 L: 22.8050
# Epoch: 9796	 w: 0.70	 b: -2.88	 L: 22.8048
# Epoch: 9797	 w: 0.70	 b: -2.88	 L: 22.8046
# Epoch: 9798	 w: 0.70	 b: -2.88	 L: 22.8045
# Epoch: 9799	 w: 0.70	 b: -2.88	 L: 22.8043
# Epoch: 9800	 w: 0.70	 b: -2.88	 L: 22.8041
# Epoch: 9801	 w: 0.70	 b: -2.88	 L: 22.8039
# Epoch: 9802	 w: 0.70	 b: -2.88	 L: 22.8038
# Epoch: 9803	 w: 0.70	 b: -2.88	 L: 22.8036
# Epoch: 9804	 w: 0.70	 b: -2.88	 L: 22.8034
# Epoch: 9805	 w: 0.70	 b: -2.88	 L: 22.8033
# Epoch: 9806	 w: 0.70	 b: -2.88	 L: 22.8031
# Epoch: 9807	 w: 0.70	 b: -2.88	 L: 22.8029
# Epoch: 9808	 w: 0.70	 b: -2.88	 L: 22.8028
# Epoch: 9809	 w: 0.70	 b: -2.88	 L: 22.8026
# Epoch: 9810	 w: 0.70	 b: -2.88	 L: 22.8024
# Epoch: 9811	 w: 0.70	 b: -2.88	 L: 22.8022
# Epoch: 9812	 w: 0.70	 b: -2.88	 L: 22.8021
# Epoch: 9813	 w: 0.70	 b: -2.88	 L: 22.8019
# Epoch: 9814	 w: 0.70	 b: -2.88	 L: 22.8017
# Epoch: 9815	 w: 0.70	 b: -2.88	 L: 22.8016
# Epoch: 9816	 w: 0.70	 b: -2.88	 L: 22.8014
# Epoch: 9817	 w: 0.70	 b: -2.88	 L: 22.8012
# Epoch: 9818	 w: 0.70	 b: -2.88	 L: 22.8010
# Epoch: 9819	 w: 0.70	 b: -2.88	 L: 22.8009
# Epoch: 9820	 w: 0.70	 b: -2.88	 L: 22.8007
# Epoch: 9821	 w: 0.70	 b: -2.88	 L: 22.8005
# Epoch: 9822	 w: 0.70	 b: -2.88	 L: 22.8004
# Epoch: 9823	 w: 0.70	 b: -2.88	 L: 22.8002
# Epoch: 9824	 w: 0.70	 b: -2.88	 L: 22.8000
# Epoch: 9825	 w: 0.70	 b: -2.88	 L: 22.7999
# Epoch: 9826	 w: 0.70	 b: -2.88	 L: 22.7997
# Epoch: 9827	 w: 0.70	 b: -2.88	 L: 22.7995
# Epoch: 9828	 w: 0.70	 b: -2.88	 L: 22.7994
# Epoch: 9829	 w: 0.70	 b: -2.88	 L: 22.7992
# Epoch: 9830	 w: 0.70	 b: -2.88	 L: 22.7990
# Epoch: 9831	 w: 0.70	 b: -2.88	 L: 22.7988
# Epoch: 9832	 w: 0.70	 b: -2.88	 L: 22.7987
# Epoch: 9833	 w: 0.70	 b: -2.88	 L: 22.7985
# Epoch: 9834	 w: 0.70	 b: -2.88	 L: 22.7983
# Epoch: 9835	 w: 0.70	 b: -2.88	 L: 22.7982
# Epoch: 9836	 w: 0.70	 b: -2.88	 L: 22.7980
# Epoch: 9837	 w: 0.70	 b: -2.88	 L: 22.7978
# Epoch: 9838	 w: 0.70	 b: -2.88	 L: 22.7977
# Epoch: 9839	 w: 0.70	 b: -2.88	 L: 22.7975
# Epoch: 9840	 w: 0.70	 b: -2.88	 L: 22.7973
# Epoch: 9841	 w: 0.70	 b: -2.88	 L: 22.7972
# Epoch: 9842	 w: 0.70	 b: -2.88	 L: 22.7970
# Epoch: 9843	 w: 0.70	 b: -2.88	 L: 22.7968
# Epoch: 9844	 w: 0.70	 b: -2.88	 L: 22.7967
# Epoch: 9845	 w: 0.70	 b: -2.88	 L: 22.7965
# Epoch: 9846	 w: 0.70	 b: -2.88	 L: 22.7963
# Epoch: 9847	 w: 0.70	 b: -2.88	 L: 22.7961
# Epoch: 9848	 w: 0.70	 b: -2.88	 L: 22.7960
# Epoch: 9849	 w: 0.70	 b: -2.89	 L: 22.7958
# Epoch: 9850	 w: 0.70	 b: -2.89	 L: 22.7956
# Epoch: 9851	 w: 0.70	 b: -2.89	 L: 22.7955
# Epoch: 9852	 w: 0.70	 b: -2.89	 L: 22.7953
# Epoch: 9853	 w: 0.70	 b: -2.89	 L: 22.7951
# Epoch: 9854	 w: 0.70	 b: -2.89	 L: 22.7950
# Epoch: 9855	 w: 0.70	 b: -2.89	 L: 22.7948
# Epoch: 9856	 w: 0.70	 b: -2.89	 L: 22.7946
# Epoch: 9857	 w: 0.70	 b: -2.89	 L: 22.7945
# Epoch: 9858	 w: 0.70	 b: -2.89	 L: 22.7943
# Epoch: 9859	 w: 0.70	 b: -2.89	 L: 22.7941
# Epoch: 9860	 w: 0.70	 b: -2.89	 L: 22.7940
# Epoch: 9861	 w: 0.70	 b: -2.89	 L: 22.7938
# Epoch: 9862	 w: 0.70	 b: -2.89	 L: 22.7936
# Epoch: 9863	 w: 0.70	 b: -2.89	 L: 22.7935
# Epoch: 9864	 w: 0.70	 b: -2.89	 L: 22.7933
# Epoch: 9865	 w: 0.70	 b: -2.89	 L: 22.7931
# Epoch: 9866	 w: 0.70	 b: -2.89	 L: 22.7930
# Epoch: 9867	 w: 0.70	 b: -2.89	 L: 22.7928
# Epoch: 9868	 w: 0.70	 b: -2.89	 L: 22.7926
# Epoch: 9869	 w: 0.70	 b: -2.89	 L: 22.7925
# Epoch: 9870	 w: 0.70	 b: -2.89	 L: 22.7923
# Epoch: 9871	 w: 0.70	 b: -2.89	 L: 22.7921
# Epoch: 9872	 w: 0.70	 b: -2.89	 L: 22.7920
# Epoch: 9873	 w: 0.70	 b: -2.89	 L: 22.7918
# Epoch: 9874	 w: 0.70	 b: -2.89	 L: 22.7916
# Epoch: 9875	 w: 0.70	 b: -2.89	 L: 22.7915
# Epoch: 9876	 w: 0.70	 b: -2.89	 L: 22.7913
# Epoch: 9877	 w: 0.70	 b: -2.89	 L: 22.7911
# Epoch: 9878	 w: 0.70	 b: -2.89	 L: 22.7910
# Epoch: 9879	 w: 0.70	 b: -2.89	 L: 22.7908
# Epoch: 9880	 w: 0.70	 b: -2.89	 L: 22.7906
# Epoch: 9881	 w: 0.70	 b: -2.89	 L: 22.7905
# Epoch: 9882	 w: 0.70	 b: -2.89	 L: 22.7903
# Epoch: 9883	 w: 0.70	 b: -2.89	 L: 22.7901
# Epoch: 9884	 w: 0.70	 b: -2.89	 L: 22.7900
# Epoch: 9885	 w: 0.70	 b: -2.89	 L: 22.7898
# Epoch: 9886	 w: 0.70	 b: -2.89	 L: 22.7897
# Epoch: 9887	 w: 0.70	 b: -2.89	 L: 22.7895
# Epoch: 9888	 w: 0.70	 b: -2.89	 L: 22.7893
# Epoch: 9889	 w: 0.70	 b: -2.89	 L: 22.7892
# Epoch: 9890	 w: 0.70	 b: -2.89	 L: 22.7890
# Epoch: 9891	 w: 0.70	 b: -2.89	 L: 22.7888
# Epoch: 9892	 w: 0.70	 b: -2.89	 L: 22.7887
# Epoch: 9893	 w: 0.70	 b: -2.89	 L: 22.7885
# Epoch: 9894	 w: 0.70	 b: -2.89	 L: 22.7883
# Epoch: 9895	 w: 0.70	 b: -2.89	 L: 22.7882
# Epoch: 9896	 w: 0.70	 b: -2.89	 L: 22.7880
# Epoch: 9897	 w: 0.70	 b: -2.89	 L: 22.7878
# Epoch: 9898	 w: 0.70	 b: -2.89	 L: 22.7877
# Epoch: 9899	 w: 0.70	 b: -2.89	 L: 22.7875
# Epoch: 9900	 w: 0.70	 b: -2.89	 L: 22.7873
# Epoch: 9901	 w: 0.70	 b: -2.89	 L: 22.7872
# Epoch: 9902	 w: 0.70	 b: -2.89	 L: 22.7870
# Epoch: 9903	 w: 0.70	 b: -2.89	 L: 22.7869
# Epoch: 9904	 w: 0.70	 b: -2.89	 L: 22.7867
# Epoch: 9905	 w: 0.70	 b: -2.89	 L: 22.7865
# Epoch: 9906	 w: 0.70	 b: -2.89	 L: 22.7864
# Epoch: 9907	 w: 0.70	 b: -2.89	 L: 22.7862
# Epoch: 9908	 w: 0.70	 b: -2.89	 L: 22.7860
# Epoch: 9909	 w: 0.70	 b: -2.89	 L: 22.7859
# Epoch: 9910	 w: 0.70	 b: -2.89	 L: 22.7857
# Epoch: 9911	 w: 0.70	 b: -2.89	 L: 22.7855
# Epoch: 9912	 w: 0.70	 b: -2.89	 L: 22.7854
# Epoch: 9913	 w: 0.70	 b: -2.89	 L: 22.7852
# Epoch: 9914	 w: 0.70	 b: -2.89	 L: 22.7851
# Epoch: 9915	 w: 0.70	 b: -2.89	 L: 22.7849
# Epoch: 9916	 w: 0.70	 b: -2.89	 L: 22.7847
# Epoch: 9917	 w: 0.70	 b: -2.89	 L: 22.7846
# Epoch: 9918	 w: 0.70	 b: -2.89	 L: 22.7844
# Epoch: 9919	 w: 0.70	 b: -2.89	 L: 22.7842
# Epoch: 9920	 w: 0.70	 b: -2.89	 L: 22.7841
# Epoch: 9921	 w: 0.70	 b: -2.89	 L: 22.7839
# Epoch: 9922	 w: 0.70	 b: -2.89	 L: 22.7838
# Epoch: 9923	 w: 0.70	 b: -2.89	 L: 22.7836
# Epoch: 9924	 w: 0.70	 b: -2.89	 L: 22.7834
# Epoch: 9925	 w: 0.70	 b: -2.89	 L: 22.7833
# Epoch: 9926	 w: 0.70	 b: -2.89	 L: 22.7831
# Epoch: 9927	 w: 0.70	 b: -2.89	 L: 22.7829
# Epoch: 9928	 w: 0.70	 b: -2.89	 L: 22.7828
# Epoch: 9929	 w: 0.70	 b: -2.89	 L: 22.7826
# Epoch: 9930	 w: 0.70	 b: -2.89	 L: 22.7825
# Epoch: 9931	 w: 0.70	 b: -2.89	 L: 22.7823
# Epoch: 9932	 w: 0.70	 b: -2.89	 L: 22.7821
# Epoch: 9933	 w: 0.70	 b: -2.89	 L: 22.7820
# Epoch: 9934	 w: 0.70	 b: -2.89	 L: 22.7818
# Epoch: 9935	 w: 0.70	 b: -2.89	 L: 22.7816
# Epoch: 9936	 w: 0.70	 b: -2.89	 L: 22.7815
# Epoch: 9937	 w: 0.70	 b: -2.89	 L: 22.7813
# Epoch: 9938	 w: 0.70	 b: -2.89	 L: 22.7812
# Epoch: 9939	 w: 0.70	 b: -2.89	 L: 22.7810
# Epoch: 9940	 w: 0.70	 b: -2.89	 L: 22.7808
# Epoch: 9941	 w: 0.70	 b: -2.89	 L: 22.7807
# Epoch: 9942	 w: 0.70	 b: -2.89	 L: 22.7805
# Epoch: 9943	 w: 0.70	 b: -2.89	 L: 22.7804
# Epoch: 9944	 w: 0.70	 b: -2.89	 L: 22.7802
# Epoch: 9945	 w: 0.70	 b: -2.89	 L: 22.7800
# Epoch: 9946	 w: 0.70	 b: -2.89	 L: 22.7799
# Epoch: 9947	 w: 0.70	 b: -2.89	 L: 22.7797
# Epoch: 9948	 w: 0.70	 b: -2.89	 L: 22.7795
# Epoch: 9949	 w: 0.70	 b: -2.89	 L: 22.7794
# Epoch: 9950	 w: 0.70	 b: -2.89	 L: 22.7792
# Epoch: 9951	 w: 0.70	 b: -2.89	 L: 22.7791
# Epoch: 9952	 w: 0.70	 b: -2.89	 L: 22.7789
# Epoch: 9953	 w: 0.70	 b: -2.89	 L: 22.7787
# Epoch: 9954	 w: 0.70	 b: -2.89	 L: 22.7786
# Epoch: 9955	 w: 0.70	 b: -2.89	 L: 22.7784
# Epoch: 9956	 w: 0.70	 b: -2.89	 L: 22.7783
# Epoch: 9957	 w: 0.70	 b: -2.89	 L: 22.7781
# Epoch: 9958	 w: 0.70	 b: -2.89	 L: 22.7779
# Epoch: 9959	 w: 0.70	 b: -2.89	 L: 22.7778
# Epoch: 9960	 w: 0.70	 b: -2.89	 L: 22.7776
# Epoch: 9961	 w: 0.70	 b: -2.90	 L: 22.7775
# Epoch: 9962	 w: 0.70	 b: -2.90	 L: 22.7773
# Epoch: 9963	 w: 0.70	 b: -2.90	 L: 22.7771
# Epoch: 9964	 w: 0.70	 b: -2.90	 L: 22.7770
# Epoch: 9965	 w: 0.70	 b: -2.90	 L: 22.7768
# Epoch: 9966	 w: 0.70	 b: -2.90	 L: 22.7767
# Epoch: 9967	 w: 0.70	 b: -2.90	 L: 22.7765
# Epoch: 9968	 w: 0.70	 b: -2.90	 L: 22.7763
# Epoch: 9969	 w: 0.70	 b: -2.90	 L: 22.7762
# Epoch: 9970	 w: 0.70	 b: -2.90	 L: 22.7760
# Epoch: 9971	 w: 0.70	 b: -2.90	 L: 22.7759
# Epoch: 9972	 w: 0.70	 b: -2.90	 L: 22.7757
# Epoch: 9973	 w: 0.70	 b: -2.90	 L: 22.7755
# Epoch: 9974	 w: 0.70	 b: -2.90	 L: 22.7754
# Epoch: 9975	 w: 0.70	 b: -2.90	 L: 22.7752
# Epoch: 9976	 w: 0.70	 b: -2.90	 L: 22.7751
# Epoch: 9977	 w: 0.70	 b: -2.90	 L: 22.7749
# Epoch: 9978	 w: 0.70	 b: -2.90	 L: 22.7747
# Epoch: 9979	 w: 0.70	 b: -2.90	 L: 22.7746
# Epoch: 9980	 w: 0.70	 b: -2.90	 L: 22.7744
# Epoch: 9981	 w: 0.70	 b: -2.90	 L: 22.7743
# Epoch: 9982	 w: 0.70	 b: -2.90	 L: 22.7741
# Epoch: 9983	 w: 0.70	 b: -2.90	 L: 22.7740
# Epoch: 9984	 w: 0.70	 b: -2.90	 L: 22.7738
# Epoch: 9985	 w: 0.70	 b: -2.90	 L: 22.7736
# Epoch: 9986	 w: 0.70	 b: -2.90	 L: 22.7735
# Epoch: 9987	 w: 0.70	 b: -2.90	 L: 22.7733
# Epoch: 9988	 w: 0.70	 b: -2.90	 L: 22.7732
# Epoch: 9989	 w: 0.70	 b: -2.90	 L: 22.7730
# Epoch: 9990	 w: 0.70	 b: -2.90	 L: 22.7728
# Epoch: 9991	 w: 0.70	 b: -2.90	 L: 22.7727
# Epoch: 9992	 w: 0.70	 b: -2.90	 L: 22.7725
# Epoch: 9993	 w: 0.70	 b: -2.90	 L: 22.7724
# Epoch: 9994	 w: 0.70	 b: -2.90	 L: 22.7722
# Epoch: 9995	 w: 0.70	 b: -2.90	 L: 22.7721
# Epoch: 9996	 w: 0.70	 b: -2.90	 L: 22.7719
# Epoch: 9997	 w: 0.70	 b: -2.90	 L: 22.7717
# Epoch: 9998	 w: 0.70	 b: -2.90	 L: 22.7716
# Epoch: 9999	 w: 0.70	 b: -2.90	 L: 22.7714

# %% [markdown]
# ### Visualising your trained model
#
# You can visualise your model by plotting the line on the graph.
#
# We will also plot the test instances to get a rough idea of how well we expect it to perform.

# %%
# Plot training instances
plt.figure()
plt.scatter(x_train, y_train, c="blue", edgecolor='k')
plt.xlabel("x")
plt.ylabel("y")

# Draw the line representing the model
xmin = x_train.min()
ymin = model.forward(xmin)
xmax = x_train.max()
ymax = model.forward(xmax)
plt.plot([xmin, xmax], [ymin, ymax], 'r-')

# Plot test instances
plt.scatter(x_test, y_test, c="red", edgecolor='k')

plt.show()

# %% [markdown]
# ### Predictions and evaluation
#
# Finally, predict the test instances given the model.
#
# Then evaluate the model with MSE.

# %%
y_predictions = np.zeros((len(y_test),))
for (i, x) in enumerate(x_test):
    y_predictions[i] = model.forward(x)

print(y_predictions)
print(y_test)

print(mse(y_test, y_predictions))
# Out:
# [1.73646156 1.52578525 1.0342072  2.64939222 0.68308002 0.96398176
#  2.29826504 0.68308002 0.47240371 1.66623612 1.87691243 1.17465807
#  1.45555981 0.75330545 1.45555981 0.54262914 0.19150196 1.94713786
#  1.38533438 1.80668699 1.0342072  1.38533438 1.38533438 0.61285458
#  2.0173633  0.12127653 0.47240371 0.89375632 0.40217827 0.2617274 ]
# [1.4 1.8 1.1 2.  0.2 1.1 1.9 0.4 0.1 1.8 2.3 2.4 1.8 0.2 2.3 0.1 0.2 2.3
#  1.4 1.7 2.  1.2 1.4 1.  1.4 0.1 0.3 0.4 0.2 0.3]
# 0.20755721057573334

# %% [markdown]
# ## Summary
#
# Hopefully you have managed to deepen your understanding about linear regression by implementing the model, loss function, and the gradient descent algorithm, and putting everything together for training and testing.
#
# In the next lab exercise, we will delve a bit deeper at implementation level, and try to extend your model to handle more than one input variable. We will also start making your code a bit more efficient with vectorised implementations so that you can perform computations on multiple training instances simultaneously. This will hopefully help you get started on implementing Neural Networks (which we will unfortunately not cover in these lab exercises as it is part of your second coursework).
